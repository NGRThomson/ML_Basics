# %% [markdown]
# This code is my assignment 5 for my machine learning module at UCL 2017/18. For this assignment I received 100% mark.

# %% [markdown]
# # Training a Neural Network with PyTorch (1.0 points)
#
# In this assignment, your task is to train a Neural Network or Multilayered Perceptron (MLP) classifier on synthetic data using PyTorch. We'll start by creating the same network architecture as in last week's assignment, only using PyTorch instead of our own implementatino. Before you start, make sure you've installed PyTorch in your conda installation: `conda install pytorch torchvision`
#
# Please read the assignment entirely before you start coding. Most of the code that implements the neural network is provided to you. What you are expected to do is fill in certain missing parts that are required and then train 2 different networks using gradient descent (Details below).
#
# - <a href='#question 1'>Question 1</a>
# - <a href='#question 2'>Question 2</a>
# - <a href='#question 3'>Question 3</a>
# - <a href='#question 4'>Question 4</a>

# %% [markdown]
# ## Imports

# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt
from construct_data import construct_data
from numpy.random import RandomState
from numpy import unravel_index


import torch
import torchvision
import torchvision.transforms as transforms

from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import time

# %% [markdown]
# ## Data Generation - Visualization

# %%
prng=RandomState(1)


# %matplotlib inline
plt.rcParams['figure.figsize'] = (5.0, 4.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %load_ext autoreload
# %autoreload 2

training_features, training_labels, posterior = construct_data(300, 'train', 'nonlinear' , plusminus=False)

# Extract features for both classes
features_pos = training_features[training_labels == 1]
features_neg = training_features[training_labels != 1]

# Display data
fig = plt.figure(figsize=plt.figaspect(0.3))
ax = fig.add_subplot(1, 2, 1)
ax.scatter(features_pos[:, 0], features_pos[:, 1], c="red", label="Positive class")
ax.scatter(features_neg[:, 0], features_neg[:, 1], c="blue", label="Negative class")
ax.axis('equal')
ax.set_title("Training data")
ax.set_xlabel("Feature 1")
ax.set_ylabel("Feature 2")
ax.legend()

ax = fig.add_subplot(1, 2, 2)
ax.imshow(posterior, extent=[0, 1, 0, 1], origin='lower')
ax.set_title("Posterior of the positive class $P(y=1 \mid x)$")
ax.set_xlabel("Feature 1")
ax.set_ylabel("Feature 2")
plt.show()

# %% [markdown]
# ## Generate test set

# %%
test_features, test_labels, _ = construct_data(100, 'test', 'nonlinear' , plusminus=False)

# %% [markdown]
# ##  Convert data to Torch tensors
#
# All computations in torch are performed on tensors ( generalizations of a matrix that can be indexed in more than 2 dimensions). Therefore we need to first convert our testing and training data to tensors.

# %%
training_features_tensor = torch.FloatTensor(training_features)
training_labels_tensor = torch.FloatTensor(training_labels)
test_features_tensor = torch.FloatTensor(test_features)
test_labels_tensor = torch.FloatTensor(test_labels)

# %% [markdown]
# Next we'll use the training label and feature tensors to create a TensorDataset as well as a DataLoader that allows us to load batches of our data during each training iteration.

# %%
# loader for training set 
batch_size = 40
trainset = torch.utils.data.TensorDataset(training_features_tensor, training_labels_tensor)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)

# %% [markdown]
# ## Simple Network in PyTorch

# %% [markdown]
# The following cell, demonstrates how to create a very simple network with only one hidded layer with 3 nodes. In the constructor function `__init__()` we create the layers and within function `forward()` we define the structure of the network.

# %%
class SimpleNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(2, 3)
        self.fc2 = nn.Linear(3, 2)
    
    def forward(self, x):
        x = self.fc1(x)
        x = F.sigmoid(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# <a id='question 1'></a>
# ## Train a network with sigmoid non-linearities across all layers
#
# In this assignment we'll create the same neural network we created last week, with [2,10,10,2] nodes (i.e. 2 inputs, 2 layers with 10 nodes and 2 outputs). We'll use sigmoid activations for the hidden layers.
# * Question 1: Use the previous simple network as a guide in order to create the network described. Add the necessary lines inside `__init__` and `forward`.

# %%
class SigmoidNet(nn.Module):
    def __init__(self):
        super().__init__()
        ###### TODO QUESTION 1 ########
        self.fc1 = nn.Linear(2,10)
        self.fc2 = nn.Linear(10,10)
        self.fc3 = nn.Linear(10,2)
        ###### TODO QUESTION 1 ########
    def forward(self, x):
        ###### TODO QUESTION 1 ########
        x = self.fc1(x)
        x = F.sigmoid(x)
        x = self.fc2(x)
        x = F.sigmoid(x)        
        x = self.fc3(x)
        ###### TODO QUESTION 1 ########
        return x

# %%
#Next we'll create an instance of our SigmoidNet class
sigmoid_net = SigmoidNet()

# %%
# Here we define the learning rate and the number of epochs for our training. 
#Hint: start with a small number of epochs (around 500) to check if everything 
# is working and only then run it for 8000 epochs)
learning_rate=0.05 # 
epochs = 4000  ## usually has already converged around that number

## Here we pick the cost function and the optimizer for our training
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(sigmoid_net.parameters(), lr=learning_rate, momentum=0.9)

# %% [markdown]
# ## Training SigmoidNet
# In the next cell the actual training happens. The network is trained for many epochs and for each of the epochs we split our training data into mini batches using the DataLoader that we created previously and iteratively feed them into our network. After each iteration/optimizer step, the parameters are updated in such a way that the loss is minimized.

# %%
start = time.time()

sigmoid_costs=[]  
sigmoid_accuracies = []

for epoch in range(epochs):  # loop over the dataset multiple times

    running_loss = 0.0
    num_of_batches = 0 
    for i, data in enumerate(trainloader, 0):
        # get the inputs
        inputs, labels = data

        # wrap them in Variable
        inputs, labels = Variable(inputs), Variable(labels)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        logits = sigmoid_net(inputs)
        loss = criterion(logits, labels.type(torch.LongTensor))
        
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.data[0]
        num_of_batches +=1
        
    # calculate test accuracy 
    test_logits = sigmoid_net(Variable(test_features_tensor))
    _, test_predictions = torch.max(test_logits.data, 1)    
    correct_predictions = (test_predictions.int() == test_labels_tensor.int()).sum()
    test_length = test_labels_tensor.size()[0]
    accuracy = correct_predictions/test_length
    print('Epoch: %d/%d,  loss: %.3f, test accuracy: %.3f'%(epoch + 1,epochs, running_loss / num_of_batches, accuracy))
    sigmoid_costs.append(running_loss/num_of_batches)
    sigmoid_accuracies.append(accuracy)

    

end = time.time()
duration = end-start
print('Finished Training in %d seconds'%(end-start))
# Out:
# Epoch: 1/4000,  loss: 0.696, test accuracy: 0.500
# Epoch: 2/4000,  loss: 0.696, test accuracy: 0.500
# Epoch: 3/4000,  loss: 0.694, test accuracy: 0.500
# Epoch: 4/4000,  loss: 0.698, test accuracy: 0.500
# Epoch: 5/4000,  loss: 0.698, test accuracy: 0.500
# Epoch: 6/4000,  loss: 0.693, test accuracy: 0.500
# Epoch: 7/4000,  loss: 0.702, test accuracy: 0.500
# Epoch: 8/4000,  loss: 0.699, test accuracy: 0.500
# Epoch: 9/4000,  loss: 0.696, test accuracy: 0.500
# Epoch: 10/4000,  loss: 0.700, test accuracy: 0.500
# Epoch: 11/4000,  loss: 0.696, test accuracy: 0.500
# Epoch: 12/4000,  loss: 0.694, test accuracy: 0.500
# Epoch: 13/4000,  loss: 0.695, test accuracy: 0.500
# Epoch: 14/4000,  loss: 0.697, test accuracy: 0.500
# Epoch: 15/4000,  loss: 0.694, test accuracy: 0.500
# Epoch: 16/4000,  loss: 0.708, test accuracy: 0.500
# Epoch: 17/4000,  loss: 0.698, test accuracy: 0.500
# Epoch: 18/4000,  loss: 0.710, test accuracy: 0.500
# Epoch: 19/4000,  loss: 0.696, test accuracy: 0.500
# Epoch: 20/4000,  loss: 0.694, test accuracy: 0.500
# Epoch: 21/4000,  loss: 0.695, test accuracy: 0.500
# Epoch: 22/4000,  loss: 0.698, test accuracy: 0.500
# Epoch: 23/4000,  loss: 0.705, test accuracy: 0.500
# Epoch: 24/4000,  loss: 0.693, test accuracy: 0.500
# Epoch: 25/4000,  loss: 0.698, test accuracy: 0.500
# Epoch: 26/4000,  loss: 0.693, test accuracy: 0.500
# Epoch: 27/4000,  loss: 0.695, test accuracy: 0.500
# Epoch: 28/4000,  loss: 0.693, test accuracy: 0.500
# Epoch: 29/4000,  loss: 0.693, test accuracy: 0.500
# Epoch: 30/4000,  loss: 0.696, test accuracy: 0.500
# Epoch: 31/4000,  loss: 0.695, test accuracy: 0.500
# Epoch: 32/4000,  loss: 0.695, test accuracy: 0.500
# Epoch: 33/4000,  loss: 0.700, test accuracy: 0.500
# Epoch: 34/4000,  loss: 0.700, test accuracy: 0.500
# Epoch: 35/4000,  loss: 0.698, test accuracy: 0.500
# Epoch: 36/4000,  loss: 0.694, test accuracy: 0.500
# Epoch: 37/4000,  loss: 0.701, test accuracy: 0.500
# Epoch: 38/4000,  loss: 0.693, test accuracy: 0.500
# Epoch: 39/4000,  loss: 0.702, test accuracy: 0.500
# Epoch: 40/4000,  loss: 0.696, test accuracy: 0.500
# Epoch: 41/4000,  loss: 0.696, test accuracy: 0.500
# Epoch: 42/4000,  loss: 0.694, test accuracy: 0.580
# Epoch: 43/4000,  loss: 0.697, test accuracy: 0.500
# Epoch: 44/4000,  loss: 0.697, test accuracy: 0.500
# Epoch: 45/4000,  loss: 0.693, test accuracy: 0.500
# Epoch: 46/4000,  loss: 0.699, test accuracy: 0.500
# Epoch: 47/4000,  loss: 0.693, test accuracy: 0.500
# Epoch: 48/4000,  loss: 0.694, test accuracy: 0.500
# Epoch: 49/4000,  loss: 0.693, test accuracy: 0.500
# Epoch: 50/4000,  loss: 0.694, test accuracy: 0.500
# Epoch: 51/4000,  loss: 0.694, test accuracy: 0.500
# Epoch: 52/4000,  loss: 0.694, test accuracy: 0.500
# Epoch: 53/4000,  loss: 0.693, test accuracy: 0.500
# Epoch: 54/4000,  loss: 0.694, test accuracy: 0.500
# Epoch: 55/4000,  loss: 0.695, test accuracy: 0.500
# Epoch: 56/4000,  loss: 0.696, test accuracy: 0.500
# Epoch: 57/4000,  loss: 0.693, test accuracy: 0.500
# Epoch: 58/4000,  loss: 0.694, test accuracy: 0.500
# Epoch: 59/4000,  loss: 0.697, test accuracy: 0.500
# Epoch: 60/4000,  loss: 0.703, test accuracy: 0.500
# Epoch: 61/4000,  loss: 0.702, test accuracy: 0.500
# Epoch: 62/4000,  loss: 0.694, test accuracy: 0.500
# Epoch: 63/4000,  loss: 0.695, test accuracy: 0.500
# Epoch: 64/4000,  loss: 0.697, test accuracy: 0.510
# Epoch: 65/4000,  loss: 0.695, test accuracy: 0.500
# Epoch: 66/4000,  loss: 0.694, test accuracy: 0.500
# Epoch: 67/4000,  loss: 0.692, test accuracy: 0.500
# Epoch: 68/4000,  loss: 0.694, test accuracy: 0.550
# Epoch: 69/4000,  loss: 0.692, test accuracy: 0.590
# Epoch: 70/4000,  loss: 0.691, test accuracy: 0.640
# Epoch: 71/4000,  loss: 0.692, test accuracy: 0.500
# Epoch: 72/4000,  loss: 0.693, test accuracy: 0.520
# Epoch: 73/4000,  loss: 0.695, test accuracy: 0.520
# Epoch: 74/4000,  loss: 0.691, test accuracy: 0.500
# Epoch: 75/4000,  loss: 0.693, test accuracy: 0.630
# Epoch: 76/4000,  loss: 0.692, test accuracy: 0.520
# Epoch: 77/4000,  loss: 0.692, test accuracy: 0.500
# Epoch: 78/4000,  loss: 0.691, test accuracy: 0.610
# Epoch: 79/4000,  loss: 0.695, test accuracy: 0.500
# Epoch: 80/4000,  loss: 0.689, test accuracy: 0.500
# Epoch: 81/4000,  loss: 0.693, test accuracy: 0.580
# Epoch: 82/4000,  loss: 0.692, test accuracy: 0.520
# Epoch: 83/4000,  loss: 0.691, test accuracy: 0.540
# Epoch: 84/4000,  loss: 0.692, test accuracy: 0.540
# Epoch: 85/4000,  loss: 0.699, test accuracy: 0.500
# Epoch: 86/4000,  loss: 0.695, test accuracy: 0.500
# Epoch: 87/4000,  loss: 0.693, test accuracy: 0.520
# Epoch: 88/4000,  loss: 0.691, test accuracy: 0.560
# Epoch: 89/4000,  loss: 0.690, test accuracy: 0.640
# Epoch: 90/4000,  loss: 0.693, test accuracy: 0.630
# Epoch: 91/4000,  loss: 0.691, test accuracy: 0.500
# Epoch: 92/4000,  loss: 0.696, test accuracy: 0.510
# Epoch: 93/4000,  loss: 0.688, test accuracy: 0.500
# Epoch: 94/4000,  loss: 0.694, test accuracy: 0.500
# Epoch: 95/4000,  loss: 0.687, test accuracy: 0.500
# Epoch: 96/4000,  loss: 0.691, test accuracy: 0.630
# Epoch: 97/4000,  loss: 0.688, test accuracy: 0.500
# Epoch: 98/4000,  loss: 0.699, test accuracy: 0.500
# Epoch: 99/4000,  loss: 0.694, test accuracy: 0.500
# Epoch: 100/4000,  loss: 0.688, test accuracy: 0.500
# Epoch: 101/4000,  loss: 0.689, test accuracy: 0.630
# Epoch: 102/4000,  loss: 0.688, test accuracy: 0.600
# Epoch: 103/4000,  loss: 0.689, test accuracy: 0.520
# Epoch: 104/4000,  loss: 0.693, test accuracy: 0.500
# Epoch: 105/4000,  loss: 0.686, test accuracy: 0.500
# Epoch: 106/4000,  loss: 0.686, test accuracy: 0.600
# Epoch: 107/4000,  loss: 0.687, test accuracy: 0.530
# Epoch: 108/4000,  loss: 0.686, test accuracy: 0.500
# Epoch: 109/4000,  loss: 0.697, test accuracy: 0.650
# Epoch: 110/4000,  loss: 0.686, test accuracy: 0.570
# Epoch: 111/4000,  loss: 0.685, test accuracy: 0.570
# Epoch: 112/4000,  loss: 0.684, test accuracy: 0.600
# Epoch: 113/4000,  loss: 0.683, test accuracy: 0.620
# Epoch: 114/4000,  loss: 0.684, test accuracy: 0.600
# Epoch: 115/4000,  loss: 0.683, test accuracy: 0.550
# Epoch: 116/4000,  loss: 0.682, test accuracy: 0.600
# Epoch: 117/4000,  loss: 0.681, test accuracy: 0.550
# Epoch: 118/4000,  loss: 0.691, test accuracy: 0.610
# Epoch: 119/4000,  loss: 0.685, test accuracy: 0.530
# Epoch: 120/4000,  loss: 0.678, test accuracy: 0.590
# Epoch: 121/4000,  loss: 0.683, test accuracy: 0.600
# Epoch: 122/4000,  loss: 0.680, test accuracy: 0.540
# Epoch: 123/4000,  loss: 0.678, test accuracy: 0.590
# Epoch: 124/4000,  loss: 0.679, test accuracy: 0.600
# Epoch: 125/4000,  loss: 0.676, test accuracy: 0.580
# Epoch: 126/4000,  loss: 0.677, test accuracy: 0.610
# Epoch: 127/4000,  loss: 0.674, test accuracy: 0.550
# Epoch: 128/4000,  loss: 0.673, test accuracy: 0.620
# Epoch: 129/4000,  loss: 0.674, test accuracy: 0.590
# Epoch: 130/4000,  loss: 0.673, test accuracy: 0.620
# Epoch: 131/4000,  loss: 0.672, test accuracy: 0.620
# Epoch: 132/4000,  loss: 0.679, test accuracy: 0.580
# Epoch: 133/4000,  loss: 0.677, test accuracy: 0.600
# Epoch: 134/4000,  loss: 0.665, test accuracy: 0.550
# Epoch: 135/4000,  loss: 0.668, test accuracy: 0.600
# Epoch: 136/4000,  loss: 0.668, test accuracy: 0.600
# Epoch: 137/4000,  loss: 0.671, test accuracy: 0.590
# Epoch: 138/4000,  loss: 0.664, test accuracy: 0.610
# Epoch: 139/4000,  loss: 0.664, test accuracy: 0.610
# Epoch: 140/4000,  loss: 0.663, test accuracy: 0.590
# Epoch: 141/4000,  loss: 0.661, test accuracy: 0.620
# Epoch: 142/4000,  loss: 0.658, test accuracy: 0.570
# Epoch: 143/4000,  loss: 0.659, test accuracy: 0.560
# Epoch: 144/4000,  loss: 0.658, test accuracy: 0.610
# Epoch: 145/4000,  loss: 0.661, test accuracy: 0.590
# Epoch: 146/4000,  loss: 0.656, test accuracy: 0.590
# Epoch: 147/4000,  loss: 0.654, test accuracy: 0.580
# Epoch: 148/4000,  loss: 0.656, test accuracy: 0.590
# Epoch: 149/4000,  loss: 0.653, test accuracy: 0.570
# Epoch: 150/4000,  loss: 0.651, test accuracy: 0.600
# Epoch: 151/4000,  loss: 0.653, test accuracy: 0.580
# Epoch: 152/4000,  loss: 0.657, test accuracy: 0.590
# Epoch: 153/4000,  loss: 0.655, test accuracy: 0.570
# Epoch: 154/4000,  loss: 0.649, test accuracy: 0.590
# Epoch: 155/4000,  loss: 0.661, test accuracy: 0.590
# Epoch: 156/4000,  loss: 0.668, test accuracy: 0.610
# Epoch: 157/4000,  loss: 0.644, test accuracy: 0.590
# Epoch: 158/4000,  loss: 0.645, test accuracy: 0.590
# Epoch: 159/4000,  loss: 0.649, test accuracy: 0.580
# Epoch: 160/4000,  loss: 0.646, test accuracy: 0.600
# Epoch: 161/4000,  loss: 0.643, test accuracy: 0.590
# Epoch: 162/4000,  loss: 0.645, test accuracy: 0.580
# Epoch: 163/4000,  loss: 0.651, test accuracy: 0.590
# Epoch: 164/4000,  loss: 0.640, test accuracy: 0.610
# Epoch: 165/4000,  loss: 0.641, test accuracy: 0.590
# Epoch: 166/4000,  loss: 0.644, test accuracy: 0.610
# Epoch: 167/4000,  loss: 0.640, test accuracy: 0.610
# Epoch: 168/4000,  loss: 0.649, test accuracy: 0.600
# Epoch: 169/4000,  loss: 0.643, test accuracy: 0.590
# Epoch: 170/4000,  loss: 0.642, test accuracy: 0.590
# Epoch: 171/4000,  loss: 0.643, test accuracy: 0.600
# Epoch: 172/4000,  loss: 0.642, test accuracy: 0.610
# Epoch: 173/4000,  loss: 0.646, test accuracy: 0.600
# Epoch: 174/4000,  loss: 0.659, test accuracy: 0.590
# Epoch: 175/4000,  loss: 0.646, test accuracy: 0.580
# Epoch: 176/4000,  loss: 0.654, test accuracy: 0.590
# Epoch: 177/4000,  loss: 0.643, test accuracy: 0.570
# Epoch: 178/4000,  loss: 0.645, test accuracy: 0.590
# Epoch: 179/4000,  loss: 0.644, test accuracy: 0.600
# Epoch: 180/4000,  loss: 0.649, test accuracy: 0.590
# Epoch: 181/4000,  loss: 0.638, test accuracy: 0.610
# Epoch: 182/4000,  loss: 0.642, test accuracy: 0.590
# Epoch: 183/4000,  loss: 0.637, test accuracy: 0.600
# Epoch: 184/4000,  loss: 0.650, test accuracy: 0.590
# Epoch: 185/4000,  loss: 0.650, test accuracy: 0.610
# Epoch: 186/4000,  loss: 0.639, test accuracy: 0.590
# Epoch: 187/4000,  loss: 0.643, test accuracy: 0.590
# Epoch: 188/4000,  loss: 0.636, test accuracy: 0.600
# Epoch: 189/4000,  loss: 0.641, test accuracy: 0.600
# Epoch: 190/4000,  loss: 0.641, test accuracy: 0.590
# Epoch: 191/4000,  loss: 0.642, test accuracy: 0.610
# Epoch: 192/4000,  loss: 0.642, test accuracy: 0.610
# Epoch: 193/4000,  loss: 0.640, test accuracy: 0.600
# Epoch: 194/4000,  loss: 0.639, test accuracy: 0.580
# Epoch: 195/4000,  loss: 0.643, test accuracy: 0.590
# Epoch: 196/4000,  loss: 0.641, test accuracy: 0.580
# Epoch: 197/4000,  loss: 0.640, test accuracy: 0.610
# Epoch: 198/4000,  loss: 0.639, test accuracy: 0.600
# Epoch: 199/4000,  loss: 0.642, test accuracy: 0.590
# Epoch: 200/4000,  loss: 0.639, test accuracy: 0.610
# Epoch: 201/4000,  loss: 0.638, test accuracy: 0.600
# Epoch: 202/4000,  loss: 0.649, test accuracy: 0.600
# Epoch: 203/4000,  loss: 0.639, test accuracy: 0.580
# Epoch: 204/4000,  loss: 0.647, test accuracy: 0.590
# Epoch: 205/4000,  loss: 0.642, test accuracy: 0.590
# Epoch: 206/4000,  loss: 0.648, test accuracy: 0.590
# Epoch: 207/4000,  loss: 0.635, test accuracy: 0.610
# Epoch: 208/4000,  loss: 0.639, test accuracy: 0.580
# Epoch: 209/4000,  loss: 0.653, test accuracy: 0.590
# Epoch: 210/4000,  loss: 0.644, test accuracy: 0.580
# Epoch: 211/4000,  loss: 0.645, test accuracy: 0.590
# Epoch: 212/4000,  loss: 0.639, test accuracy: 0.600
# Epoch: 213/4000,  loss: 0.643, test accuracy: 0.590
# Epoch: 214/4000,  loss: 0.642, test accuracy: 0.600
# Epoch: 215/4000,  loss: 0.633, test accuracy: 0.600
# Epoch: 216/4000,  loss: 0.644, test accuracy: 0.600
# Epoch: 217/4000,  loss: 0.645, test accuracy: 0.590
# Epoch: 218/4000,  loss: 0.640, test accuracy: 0.580
# Epoch: 219/4000,  loss: 0.643, test accuracy: 0.610
# Epoch: 220/4000,  loss: 0.642, test accuracy: 0.590
# Epoch: 221/4000,  loss: 0.647, test accuracy: 0.610
# Epoch: 222/4000,  loss: 0.638, test accuracy: 0.600
# Epoch: 223/4000,  loss: 0.640, test accuracy: 0.590
# Epoch: 224/4000,  loss: 0.645, test accuracy: 0.590
# Epoch: 225/4000,  loss: 0.644, test accuracy: 0.600
# Epoch: 226/4000,  loss: 0.637, test accuracy: 0.590
# Epoch: 227/4000,  loss: 0.651, test accuracy: 0.590
# Epoch: 228/4000,  loss: 0.653, test accuracy: 0.580
# Epoch: 229/4000,  loss: 0.631, test accuracy: 0.590
# Epoch: 230/4000,  loss: 0.631, test accuracy: 0.590
# Epoch: 231/4000,  loss: 0.635, test accuracy: 0.590
# Epoch: 232/4000,  loss: 0.639, test accuracy: 0.600
# Epoch: 233/4000,  loss: 0.639, test accuracy: 0.620
# Epoch: 234/4000,  loss: 0.633, test accuracy: 0.600
# Epoch: 235/4000,  loss: 0.635, test accuracy: 0.610
# Epoch: 236/4000,  loss: 0.636, test accuracy: 0.610
# Epoch: 237/4000,  loss: 0.651, test accuracy: 0.590
# Epoch: 238/4000,  loss: 0.650, test accuracy: 0.600
# Epoch: 239/4000,  loss: 0.645, test accuracy: 0.620
# Epoch: 240/4000,  loss: 0.648, test accuracy: 0.580
# Epoch: 241/4000,  loss: 0.662, test accuracy: 0.590
# Epoch: 242/4000,  loss: 0.658, test accuracy: 0.600
# Epoch: 243/4000,  loss: 0.649, test accuracy: 0.610
# Epoch: 244/4000,  loss: 0.647, test accuracy: 0.600
# Epoch: 245/4000,  loss: 0.637, test accuracy: 0.590
# Epoch: 246/4000,  loss: 0.640, test accuracy: 0.590
# Epoch: 247/4000,  loss: 0.631, test accuracy: 0.620
# Epoch: 248/4000,  loss: 0.640, test accuracy: 0.600
# Epoch: 249/4000,  loss: 0.638, test accuracy: 0.600
# Epoch: 250/4000,  loss: 0.650, test accuracy: 0.610
# Epoch: 251/4000,  loss: 0.644, test accuracy: 0.610
# Epoch: 252/4000,  loss: 0.646, test accuracy: 0.590
# Epoch: 253/4000,  loss: 0.630, test accuracy: 0.600
# Epoch: 254/4000,  loss: 0.638, test accuracy: 0.620
# Epoch: 255/4000,  loss: 0.635, test accuracy: 0.610
# Epoch: 256/4000,  loss: 0.635, test accuracy: 0.620
# Epoch: 257/4000,  loss: 0.631, test accuracy: 0.620
# Epoch: 258/4000,  loss: 0.639, test accuracy: 0.590
# Epoch: 259/4000,  loss: 0.636, test accuracy: 0.600
# Epoch: 260/4000,  loss: 0.641, test accuracy: 0.620
# Epoch: 261/4000,  loss: 0.642, test accuracy: 0.600
# Epoch: 262/4000,  loss: 0.635, test accuracy: 0.610
# Epoch: 263/4000,  loss: 0.647, test accuracy: 0.600
# Epoch: 264/4000,  loss: 0.639, test accuracy: 0.610
# Epoch: 265/4000,  loss: 0.625, test accuracy: 0.590
# Epoch: 266/4000,  loss: 0.635, test accuracy: 0.610
# Epoch: 267/4000,  loss: 0.637, test accuracy: 0.600
# Epoch: 268/4000,  loss: 0.629, test accuracy: 0.620
# Epoch: 269/4000,  loss: 0.635, test accuracy: 0.610
# Epoch: 270/4000,  loss: 0.633, test accuracy: 0.590
# Epoch: 271/4000,  loss: 0.633, test accuracy: 0.620
# Epoch: 272/4000,  loss: 0.639, test accuracy: 0.620
# Epoch: 273/4000,  loss: 0.627, test accuracy: 0.610
# Epoch: 274/4000,  loss: 0.635, test accuracy: 0.610
# Epoch: 275/4000,  loss: 0.665, test accuracy: 0.620
# Epoch: 276/4000,  loss: 0.643, test accuracy: 0.610
# Epoch: 277/4000,  loss: 0.636, test accuracy: 0.610
# Epoch: 278/4000,  loss: 0.633, test accuracy: 0.600
# Epoch: 279/4000,  loss: 0.622, test accuracy: 0.610
# Epoch: 280/4000,  loss: 0.636, test accuracy: 0.600
# Epoch: 281/4000,  loss: 0.654, test accuracy: 0.620
# Epoch: 282/4000,  loss: 0.643, test accuracy: 0.610
# Epoch: 283/4000,  loss: 0.661, test accuracy: 0.620
# Epoch: 284/4000,  loss: 0.634, test accuracy: 0.620
# Epoch: 285/4000,  loss: 0.641, test accuracy: 0.610
# Epoch: 286/4000,  loss: 0.637, test accuracy: 0.600
# Epoch: 287/4000,  loss: 0.637, test accuracy: 0.600
# Epoch: 288/4000,  loss: 0.642, test accuracy: 0.610
# Epoch: 289/4000,  loss: 0.628, test accuracy: 0.610
# Epoch: 290/4000,  loss: 0.632, test accuracy: 0.610
# Epoch: 291/4000,  loss: 0.643, test accuracy: 0.620
# Epoch: 292/4000,  loss: 0.644, test accuracy: 0.620
# Epoch: 293/4000,  loss: 0.622, test accuracy: 0.600
# Epoch: 294/4000,  loss: 0.626, test accuracy: 0.620
# Epoch: 295/4000,  loss: 0.618, test accuracy: 0.610
# Epoch: 296/4000,  loss: 0.631, test accuracy: 0.630
# Epoch: 297/4000,  loss: 0.643, test accuracy: 0.620
# Epoch: 298/4000,  loss: 0.660, test accuracy: 0.600
# Epoch: 299/4000,  loss: 0.665, test accuracy: 0.610
# Epoch: 300/4000,  loss: 0.643, test accuracy: 0.590
# Epoch: 301/4000,  loss: 0.664, test accuracy: 0.610
# Epoch: 302/4000,  loss: 0.637, test accuracy: 0.600
# Epoch: 303/4000,  loss: 0.639, test accuracy: 0.620
# Epoch: 304/4000,  loss: 0.640, test accuracy: 0.600
# Epoch: 305/4000,  loss: 0.625, test accuracy: 0.620
# Epoch: 306/4000,  loss: 0.627, test accuracy: 0.600
# Epoch: 307/4000,  loss: 0.620, test accuracy: 0.630
# Epoch: 308/4000,  loss: 0.642, test accuracy: 0.620
# Epoch: 309/4000,  loss: 0.626, test accuracy: 0.610
# Epoch: 310/4000,  loss: 0.622, test accuracy: 0.620
# Epoch: 311/4000,  loss: 0.628, test accuracy: 0.640
# Epoch: 312/4000,  loss: 0.623, test accuracy: 0.610
# Epoch: 313/4000,  loss: 0.640, test accuracy: 0.630
# Epoch: 314/4000,  loss: 0.636, test accuracy: 0.630
# Epoch: 315/4000,  loss: 0.643, test accuracy: 0.610
# Epoch: 316/4000,  loss: 0.638, test accuracy: 0.590
# Epoch: 317/4000,  loss: 0.630, test accuracy: 0.620
# Epoch: 318/4000,  loss: 0.621, test accuracy: 0.590
# Epoch: 319/4000,  loss: 0.631, test accuracy: 0.630
# Epoch: 320/4000,  loss: 0.623, test accuracy: 0.640
# Epoch: 321/4000,  loss: 0.625, test accuracy: 0.640
# Epoch: 322/4000,  loss: 0.624, test accuracy: 0.620
# Epoch: 323/4000,  loss: 0.626, test accuracy: 0.640
# Epoch: 324/4000,  loss: 0.626, test accuracy: 0.630
# Epoch: 325/4000,  loss: 0.631, test accuracy: 0.620
# Epoch: 326/4000,  loss: 0.635, test accuracy: 0.620
# Epoch: 327/4000,  loss: 0.649, test accuracy: 0.610
# Epoch: 328/4000,  loss: 0.622, test accuracy: 0.630
# Epoch: 329/4000,  loss: 0.619, test accuracy: 0.630
# Epoch: 330/4000,  loss: 0.624, test accuracy: 0.610
# Epoch: 331/4000,  loss: 0.639, test accuracy: 0.620
# Epoch: 332/4000,  loss: 0.623, test accuracy: 0.630
# Epoch: 333/4000,  loss: 0.619, test accuracy: 0.650
# Epoch: 334/4000,  loss: 0.621, test accuracy: 0.620
# Epoch: 335/4000,  loss: 0.617, test accuracy: 0.630
# Epoch: 336/4000,  loss: 0.627, test accuracy: 0.620
# Epoch: 337/4000,  loss: 0.618, test accuracy: 0.640
# Epoch: 338/4000,  loss: 0.621, test accuracy: 0.640
# Epoch: 339/4000,  loss: 0.616, test accuracy: 0.620
# Epoch: 340/4000,  loss: 0.622, test accuracy: 0.620
# Epoch: 341/4000,  loss: 0.613, test accuracy: 0.660
# Epoch: 342/4000,  loss: 0.620, test accuracy: 0.630
# Epoch: 343/4000,  loss: 0.619, test accuracy: 0.650
# Epoch: 344/4000,  loss: 0.605, test accuracy: 0.650
# Epoch: 345/4000,  loss: 0.625, test accuracy: 0.630
# Epoch: 346/4000,  loss: 0.641, test accuracy: 0.620
# Epoch: 347/4000,  loss: 0.630, test accuracy: 0.640
# Epoch: 348/4000,  loss: 0.616, test accuracy: 0.630
# Epoch: 349/4000,  loss: 0.616, test accuracy: 0.660
# Epoch: 350/4000,  loss: 0.609, test accuracy: 0.640
# Epoch: 351/4000,  loss: 0.616, test accuracy: 0.630
# Epoch: 352/4000,  loss: 0.623, test accuracy: 0.630
# Epoch: 353/4000,  loss: 0.619, test accuracy: 0.640
# Epoch: 354/4000,  loss: 0.609, test accuracy: 0.660
# Epoch: 355/4000,  loss: 0.614, test accuracy: 0.650
# Epoch: 356/4000,  loss: 0.609, test accuracy: 0.660
# Epoch: 357/4000,  loss: 0.604, test accuracy: 0.670
# Epoch: 358/4000,  loss: 0.607, test accuracy: 0.650
# Epoch: 359/4000,  loss: 0.617, test accuracy: 0.650
# Epoch: 360/4000,  loss: 0.608, test accuracy: 0.650
# Epoch: 361/4000,  loss: 0.606, test accuracy: 0.670
# Epoch: 362/4000,  loss: 0.604, test accuracy: 0.650
# Epoch: 363/4000,  loss: 0.609, test accuracy: 0.660
# Epoch: 364/4000,  loss: 0.611, test accuracy: 0.660
# Epoch: 365/4000,  loss: 0.601, test accuracy: 0.660
# Epoch: 366/4000,  loss: 0.618, test accuracy: 0.670
# Epoch: 367/4000,  loss: 0.607, test accuracy: 0.660
# Epoch: 368/4000,  loss: 0.604, test accuracy: 0.670
# Epoch: 369/4000,  loss: 0.602, test accuracy: 0.660
# Epoch: 370/4000,  loss: 0.599, test accuracy: 0.680
# Epoch: 371/4000,  loss: 0.612, test accuracy: 0.690
# Epoch: 372/4000,  loss: 0.630, test accuracy: 0.690
# Epoch: 373/4000,  loss: 0.615, test accuracy: 0.660
# Epoch: 374/4000,  loss: 0.598, test accuracy: 0.690
# Epoch: 375/4000,  loss: 0.606, test accuracy: 0.690
# Epoch: 376/4000,  loss: 0.601, test accuracy: 0.680
# Epoch: 377/4000,  loss: 0.604, test accuracy: 0.680
# Epoch: 378/4000,  loss: 0.606, test accuracy: 0.670
# Epoch: 379/4000,  loss: 0.593, test accuracy: 0.690
# Epoch: 380/4000,  loss: 0.609, test accuracy: 0.680
# Epoch: 381/4000,  loss: 0.600, test accuracy: 0.670
# Epoch: 382/4000,  loss: 0.597, test accuracy: 0.700
# Epoch: 383/4000,  loss: 0.593, test accuracy: 0.690
# Epoch: 384/4000,  loss: 0.590, test accuracy: 0.680
# Epoch: 385/4000,  loss: 0.601, test accuracy: 0.680
# Epoch: 386/4000,  loss: 0.615, test accuracy: 0.700
# Epoch: 387/4000,  loss: 0.594, test accuracy: 0.660
# Epoch: 388/4000,  loss: 0.597, test accuracy: 0.650
# Epoch: 389/4000,  loss: 0.594, test accuracy: 0.680
# Epoch: 390/4000,  loss: 0.583, test accuracy: 0.660
# Epoch: 391/4000,  loss: 0.594, test accuracy: 0.690
# Epoch: 392/4000,  loss: 0.589, test accuracy: 0.710
# Epoch: 393/4000,  loss: 0.584, test accuracy: 0.720
# Epoch: 394/4000,  loss: 0.597, test accuracy: 0.710
# Epoch: 395/4000,  loss: 0.583, test accuracy: 0.720
# Epoch: 396/4000,  loss: 0.581, test accuracy: 0.710
# Epoch: 397/4000,  loss: 0.579, test accuracy: 0.730
# Epoch: 398/4000,  loss: 0.596, test accuracy: 0.680
# Epoch: 399/4000,  loss: 0.592, test accuracy: 0.730
# Epoch: 400/4000,  loss: 0.594, test accuracy: 0.730
# Epoch: 401/4000,  loss: 0.583, test accuracy: 0.730
# Epoch: 402/4000,  loss: 0.575, test accuracy: 0.730
# Epoch: 403/4000,  loss: 0.584, test accuracy: 0.730
# Epoch: 404/4000,  loss: 0.580, test accuracy: 0.740
# Epoch: 405/4000,  loss: 0.586, test accuracy: 0.720
# Epoch: 406/4000,  loss: 0.584, test accuracy: 0.740
# Epoch: 407/4000,  loss: 0.579, test accuracy: 0.750
# Epoch: 408/4000,  loss: 0.580, test accuracy: 0.740
# Epoch: 409/4000,  loss: 0.577, test accuracy: 0.750
# Epoch: 410/4000,  loss: 0.582, test accuracy: 0.740
# Epoch: 411/4000,  loss: 0.602, test accuracy: 0.670
# Epoch: 412/4000,  loss: 0.581, test accuracy: 0.760
# Epoch: 413/4000,  loss: 0.578, test accuracy: 0.720
# Epoch: 414/4000,  loss: 0.579, test accuracy: 0.750
# Epoch: 415/4000,  loss: 0.579, test accuracy: 0.740
# Epoch: 416/4000,  loss: 0.572, test accuracy: 0.740
# Epoch: 417/4000,  loss: 0.573, test accuracy: 0.740
# Epoch: 418/4000,  loss: 0.574, test accuracy: 0.780
# Epoch: 419/4000,  loss: 0.555, test accuracy: 0.750
# Epoch: 420/4000,  loss: 0.579, test accuracy: 0.790
# Epoch: 421/4000,  loss: 0.562, test accuracy: 0.710
# Epoch: 422/4000,  loss: 0.558, test accuracy: 0.810
# Epoch: 423/4000,  loss: 0.576, test accuracy: 0.760
# Epoch: 424/4000,  loss: 0.580, test accuracy: 0.660
# Epoch: 425/4000,  loss: 0.597, test accuracy: 0.740
# Epoch: 426/4000,  loss: 0.585, test accuracy: 0.710
# Epoch: 427/4000,  loss: 0.563, test accuracy: 0.790
# Epoch: 428/4000,  loss: 0.558, test accuracy: 0.770
# Epoch: 429/4000,  loss: 0.569, test accuracy: 0.740
# Epoch: 430/4000,  loss: 0.568, test accuracy: 0.820
# Epoch: 431/4000,  loss: 0.561, test accuracy: 0.690
# Epoch: 432/4000,  loss: 0.566, test accuracy: 0.830
# Epoch: 433/4000,  loss: 0.557, test accuracy: 0.710
# Epoch: 434/4000,  loss: 0.550, test accuracy: 0.800
# Epoch: 435/4000,  loss: 0.549, test accuracy: 0.770
# Epoch: 436/4000,  loss: 0.545, test accuracy: 0.780
# Epoch: 437/4000,  loss: 0.539, test accuracy: 0.810
# Epoch: 438/4000,  loss: 0.549, test accuracy: 0.820
# Epoch: 439/4000,  loss: 0.540, test accuracy: 0.810
# Epoch: 440/4000,  loss: 0.533, test accuracy: 0.810
# Epoch: 441/4000,  loss: 0.531, test accuracy: 0.790
# Epoch: 442/4000,  loss: 0.547, test accuracy: 0.820
# Epoch: 443/4000,  loss: 0.544, test accuracy: 0.820
# Epoch: 444/4000,  loss: 0.539, test accuracy: 0.830
# Epoch: 445/4000,  loss: 0.533, test accuracy: 0.750
# Epoch: 446/4000,  loss: 0.526, test accuracy: 0.820
# Epoch: 447/4000,  loss: 0.527, test accuracy: 0.820
# Epoch: 448/4000,  loss: 0.530, test accuracy: 0.830
# Epoch: 449/4000,  loss: 0.533, test accuracy: 0.790
# Epoch: 450/4000,  loss: 0.521, test accuracy: 0.840
# Epoch: 451/4000,  loss: 0.531, test accuracy: 0.680
# Epoch: 452/4000,  loss: 0.538, test accuracy: 0.830
# Epoch: 453/4000,  loss: 0.533, test accuracy: 0.630
# Epoch: 454/4000,  loss: 0.560, test accuracy: 0.820
# Epoch: 455/4000,  loss: 0.528, test accuracy: 0.810
# Epoch: 456/4000,  loss: 0.526, test accuracy: 0.830
# Epoch: 457/4000,  loss: 0.536, test accuracy: 0.840
# Epoch: 458/4000,  loss: 0.525, test accuracy: 0.700
# Epoch: 459/4000,  loss: 0.564, test accuracy: 0.830
# Epoch: 460/4000,  loss: 0.535, test accuracy: 0.810
# Epoch: 461/4000,  loss: 0.539, test accuracy: 0.750
# Epoch: 462/4000,  loss: 0.545, test accuracy: 0.820
# Epoch: 463/4000,  loss: 0.536, test accuracy: 0.640
# Epoch: 464/4000,  loss: 0.539, test accuracy: 0.820
# Epoch: 465/4000,  loss: 0.535, test accuracy: 0.810
# Epoch: 466/4000,  loss: 0.540, test accuracy: 0.840
# Epoch: 467/4000,  loss: 0.527, test accuracy: 0.820
# Epoch: 468/4000,  loss: 0.532, test accuracy: 0.750
# Epoch: 469/4000,  loss: 0.505, test accuracy: 0.830
# Epoch: 470/4000,  loss: 0.531, test accuracy: 0.670
# Epoch: 471/4000,  loss: 0.610, test accuracy: 0.780
# Epoch: 472/4000,  loss: 0.545, test accuracy: 0.750
# Epoch: 473/4000,  loss: 0.500, test accuracy: 0.810
# Epoch: 474/4000,  loss: 0.521, test accuracy: 0.740
# Epoch: 475/4000,  loss: 0.508, test accuracy: 0.820
# Epoch: 476/4000,  loss: 0.510, test accuracy: 0.750
# Epoch: 477/4000,  loss: 0.513, test accuracy: 0.840
# Epoch: 478/4000,  loss: 0.502, test accuracy: 0.810
# Epoch: 479/4000,  loss: 0.521, test accuracy: 0.850
# Epoch: 480/4000,  loss: 0.519, test accuracy: 0.790
# Epoch: 481/4000,  loss: 0.519, test accuracy: 0.800
# Epoch: 482/4000,  loss: 0.508, test accuracy: 0.820
# Epoch: 483/4000,  loss: 0.516, test accuracy: 0.830
# Epoch: 484/4000,  loss: 0.522, test accuracy: 0.750
# Epoch: 485/4000,  loss: 0.509, test accuracy: 0.810
# Epoch: 486/4000,  loss: 0.514, test accuracy: 0.770
# Epoch: 487/4000,  loss: 0.509, test accuracy: 0.820
# Epoch: 488/4000,  loss: 0.516, test accuracy: 0.820
# Epoch: 489/4000,  loss: 0.520, test accuracy: 0.810
# Epoch: 490/4000,  loss: 0.497, test accuracy: 0.820
# Epoch: 491/4000,  loss: 0.512, test accuracy: 0.770
# Epoch: 492/4000,  loss: 0.505, test accuracy: 0.820
# Epoch: 493/4000,  loss: 0.530, test accuracy: 0.810
# Epoch: 494/4000,  loss: 0.508, test accuracy: 0.810
# Epoch: 495/4000,  loss: 0.505, test accuracy: 0.840
# Epoch: 496/4000,  loss: 0.505, test accuracy: 0.840
# Epoch: 497/4000,  loss: 0.510, test accuracy: 0.810
# Epoch: 498/4000,  loss: 0.521, test accuracy: 0.830
# Epoch: 499/4000,  loss: 0.502, test accuracy: 0.840
# Epoch: 500/4000,  loss: 0.509, test accuracy: 0.820
# Epoch: 501/4000,  loss: 0.532, test accuracy: 0.810
# Epoch: 502/4000,  loss: 0.517, test accuracy: 0.820
# Epoch: 503/4000,  loss: 0.508, test accuracy: 0.840
# Epoch: 504/4000,  loss: 0.504, test accuracy: 0.810
# Epoch: 505/4000,  loss: 0.523, test accuracy: 0.760
# Epoch: 506/4000,  loss: 0.546, test accuracy: 0.790
# Epoch: 507/4000,  loss: 0.555, test accuracy: 0.760
# Epoch: 508/4000,  loss: 0.506, test accuracy: 0.810
# Epoch: 509/4000,  loss: 0.506, test accuracy: 0.810
# Epoch: 510/4000,  loss: 0.504, test accuracy: 0.840
# Epoch: 511/4000,  loss: 0.505, test accuracy: 0.840
# Epoch: 512/4000,  loss: 0.495, test accuracy: 0.830
# Epoch: 513/4000,  loss: 0.501, test accuracy: 0.830
# Epoch: 514/4000,  loss: 0.503, test accuracy: 0.780
# Epoch: 515/4000,  loss: 0.515, test accuracy: 0.840
# Epoch: 516/4000,  loss: 0.506, test accuracy: 0.830
# Epoch: 517/4000,  loss: 0.525, test accuracy: 0.790
# Epoch: 518/4000,  loss: 0.516, test accuracy: 0.800
# Epoch: 519/4000,  loss: 0.499, test accuracy: 0.830
# Epoch: 520/4000,  loss: 0.484, test accuracy: 0.830
# Epoch: 521/4000,  loss: 0.494, test accuracy: 0.810
# Epoch: 522/4000,  loss: 0.505, test accuracy: 0.800
# Epoch: 523/4000,  loss: 0.498, test accuracy: 0.810
# Epoch: 524/4000,  loss: 0.515, test accuracy: 0.830
# Epoch: 525/4000,  loss: 0.522, test accuracy: 0.800
# Epoch: 526/4000,  loss: 0.508, test accuracy: 0.820
# Epoch: 527/4000,  loss: 0.527, test accuracy: 0.810
# Epoch: 528/4000,  loss: 0.509, test accuracy: 0.790
# Epoch: 529/4000,  loss: 0.509, test accuracy: 0.810
# Epoch: 530/4000,  loss: 0.502, test accuracy: 0.810
# Epoch: 531/4000,  loss: 0.521, test accuracy: 0.830
# Epoch: 532/4000,  loss: 0.506, test accuracy: 0.840
# Epoch: 533/4000,  loss: 0.507, test accuracy: 0.840
# Epoch: 534/4000,  loss: 0.501, test accuracy: 0.840
# Epoch: 535/4000,  loss: 0.510, test accuracy: 0.820
# Epoch: 536/4000,  loss: 0.519, test accuracy: 0.800
# Epoch: 537/4000,  loss: 0.499, test accuracy: 0.820
# Epoch: 538/4000,  loss: 0.511, test accuracy: 0.840
# Epoch: 539/4000,  loss: 0.496, test accuracy: 0.840
# Epoch: 540/4000,  loss: 0.495, test accuracy: 0.840
# Epoch: 541/4000,  loss: 0.492, test accuracy: 0.840
# Epoch: 542/4000,  loss: 0.497, test accuracy: 0.830
# Epoch: 543/4000,  loss: 0.508, test accuracy: 0.810
# Epoch: 544/4000,  loss: 0.498, test accuracy: 0.790
# Epoch: 545/4000,  loss: 0.506, test accuracy: 0.800
# Epoch: 546/4000,  loss: 0.512, test accuracy: 0.800
# Epoch: 547/4000,  loss: 0.507, test accuracy: 0.800
# Epoch: 548/4000,  loss: 0.499, test accuracy: 0.820
# Epoch: 549/4000,  loss: 0.486, test accuracy: 0.810
# Epoch: 550/4000,  loss: 0.518, test accuracy: 0.820
# Epoch: 551/4000,  loss: 0.512, test accuracy: 0.830
# Epoch: 552/4000,  loss: 0.497, test accuracy: 0.830
# Epoch: 553/4000,  loss: 0.506, test accuracy: 0.840
# Epoch: 554/4000,  loss: 0.492, test accuracy: 0.820
# Epoch: 555/4000,  loss: 0.492, test accuracy: 0.840
# Epoch: 556/4000,  loss: 0.513, test accuracy: 0.840
# Epoch: 557/4000,  loss: 0.507, test accuracy: 0.840
# Epoch: 558/4000,  loss: 0.501, test accuracy: 0.830
# Epoch: 559/4000,  loss: 0.503, test accuracy: 0.820
# Epoch: 560/4000,  loss: 0.519, test accuracy: 0.820
# Epoch: 561/4000,  loss: 0.494, test accuracy: 0.820
# Epoch: 562/4000,  loss: 0.511, test accuracy: 0.800
# Epoch: 563/4000,  loss: 0.504, test accuracy: 0.820
# Epoch: 564/4000,  loss: 0.497, test accuracy: 0.830
# Epoch: 565/4000,  loss: 0.509, test accuracy: 0.840
# Epoch: 566/4000,  loss: 0.492, test accuracy: 0.840
# Epoch: 567/4000,  loss: 0.496, test accuracy: 0.840
# Epoch: 568/4000,  loss: 0.493, test accuracy: 0.820
# Epoch: 569/4000,  loss: 0.488, test accuracy: 0.830
# Epoch: 570/4000,  loss: 0.493, test accuracy: 0.830
# Epoch: 571/4000,  loss: 0.493, test accuracy: 0.840
# Epoch: 572/4000,  loss: 0.489, test accuracy: 0.840
# Epoch: 573/4000,  loss: 0.502, test accuracy: 0.820
# Epoch: 574/4000,  loss: 0.511, test accuracy: 0.840
# Epoch: 575/4000,  loss: 0.536, test accuracy: 0.780
# Epoch: 576/4000,  loss: 0.518, test accuracy: 0.820
# Epoch: 577/4000,  loss: 0.556, test accuracy: 0.780
# Epoch: 578/4000,  loss: 0.518, test accuracy: 0.810
# Epoch: 579/4000,  loss: 0.528, test accuracy: 0.820
# Epoch: 580/4000,  loss: 0.515, test accuracy: 0.820
# Epoch: 581/4000,  loss: 0.505, test accuracy: 0.840
# Epoch: 582/4000,  loss: 0.496, test accuracy: 0.840
# Epoch: 583/4000,  loss: 0.495, test accuracy: 0.840
# Epoch: 584/4000,  loss: 0.489, test accuracy: 0.800
# Epoch: 585/4000,  loss: 0.520, test accuracy: 0.810
# Epoch: 586/4000,  loss: 0.520, test accuracy: 0.800
# Epoch: 587/4000,  loss: 0.536, test accuracy: 0.790
# Epoch: 588/4000,  loss: 0.511, test accuracy: 0.810
# Epoch: 589/4000,  loss: 0.502, test accuracy: 0.840
# Epoch: 590/4000,  loss: 0.500, test accuracy: 0.810
# Epoch: 591/4000,  loss: 0.496, test accuracy: 0.820
# Epoch: 592/4000,  loss: 0.484, test accuracy: 0.810
# Epoch: 593/4000,  loss: 0.502, test accuracy: 0.810
# Epoch: 594/4000,  loss: 0.505, test accuracy: 0.810
# Epoch: 595/4000,  loss: 0.505, test accuracy: 0.830
# Epoch: 596/4000,  loss: 0.506, test accuracy: 0.840
# Epoch: 597/4000,  loss: 0.492, test accuracy: 0.820
# Epoch: 598/4000,  loss: 0.498, test accuracy: 0.830
# Epoch: 599/4000,  loss: 0.503, test accuracy: 0.820
# Epoch: 600/4000,  loss: 0.494, test accuracy: 0.840
# Epoch: 601/4000,  loss: 0.497, test accuracy: 0.820
# Epoch: 602/4000,  loss: 0.514, test accuracy: 0.830
# Epoch: 603/4000,  loss: 0.505, test accuracy: 0.830
# Epoch: 604/4000,  loss: 0.495, test accuracy: 0.820
# Epoch: 605/4000,  loss: 0.509, test accuracy: 0.810
# Epoch: 606/4000,  loss: 0.498, test accuracy: 0.840
# Epoch: 607/4000,  loss: 0.493, test accuracy: 0.840
# Epoch: 608/4000,  loss: 0.501, test accuracy: 0.840
# Epoch: 609/4000,  loss: 0.504, test accuracy: 0.820
# Epoch: 610/4000,  loss: 0.501, test accuracy: 0.840
# Epoch: 611/4000,  loss: 0.493, test accuracy: 0.840
# Epoch: 612/4000,  loss: 0.502, test accuracy: 0.840
# Epoch: 613/4000,  loss: 0.503, test accuracy: 0.820
# Epoch: 614/4000,  loss: 0.513, test accuracy: 0.810
# Epoch: 615/4000,  loss: 0.500, test accuracy: 0.830
# Epoch: 616/4000,  loss: 0.504, test accuracy: 0.820
# Epoch: 617/4000,  loss: 0.524, test accuracy: 0.800
# Epoch: 618/4000,  loss: 0.498, test accuracy: 0.820
# Epoch: 619/4000,  loss: 0.484, test accuracy: 0.830
# Epoch: 620/4000,  loss: 0.485, test accuracy: 0.840
# Epoch: 621/4000,  loss: 0.488, test accuracy: 0.820
# Epoch: 622/4000,  loss: 0.489, test accuracy: 0.840
# Epoch: 623/4000,  loss: 0.489, test accuracy: 0.840
# Epoch: 624/4000,  loss: 0.498, test accuracy: 0.830
# Epoch: 625/4000,  loss: 0.502, test accuracy: 0.840
# Epoch: 626/4000,  loss: 0.499, test accuracy: 0.840
# Epoch: 627/4000,  loss: 0.490, test accuracy: 0.820
# Epoch: 628/4000,  loss: 0.488, test accuracy: 0.830
# Epoch: 629/4000,  loss: 0.496, test accuracy: 0.840
# Epoch: 630/4000,  loss: 0.495, test accuracy: 0.830
# Epoch: 631/4000,  loss: 0.491, test accuracy: 0.840
# Epoch: 632/4000,  loss: 0.484, test accuracy: 0.840
# Epoch: 633/4000,  loss: 0.488, test accuracy: 0.840
# Epoch: 634/4000,  loss: 0.500, test accuracy: 0.820
# Epoch: 635/4000,  loss: 0.497, test accuracy: 0.830
# Epoch: 636/4000,  loss: 0.491, test accuracy: 0.830
# Epoch: 637/4000,  loss: 0.490, test accuracy: 0.840
# Epoch: 638/4000,  loss: 0.513, test accuracy: 0.810
# Epoch: 639/4000,  loss: 0.495, test accuracy: 0.830
# Epoch: 640/4000,  loss: 0.504, test accuracy: 0.820
# Epoch: 641/4000,  loss: 0.485, test accuracy: 0.820
# Epoch: 642/4000,  loss: 0.488, test accuracy: 0.820
# Epoch: 643/4000,  loss: 0.506, test accuracy: 0.820
# Epoch: 644/4000,  loss: 0.492, test accuracy: 0.830
# Epoch: 645/4000,  loss: 0.486, test accuracy: 0.820
# Epoch: 646/4000,  loss: 0.487, test accuracy: 0.830
# Epoch: 647/4000,  loss: 0.487, test accuracy: 0.840
# Epoch: 648/4000,  loss: 0.492, test accuracy: 0.820
# Epoch: 649/4000,  loss: 0.489, test accuracy: 0.820
# Epoch: 650/4000,  loss: 0.490, test accuracy: 0.840
# Epoch: 651/4000,  loss: 0.479, test accuracy: 0.820
# Epoch: 652/4000,  loss: 0.481, test accuracy: 0.830
# Epoch: 653/4000,  loss: 0.495, test accuracy: 0.840
# Epoch: 654/4000,  loss: 0.492, test accuracy: 0.820
# Epoch: 655/4000,  loss: 0.492, test accuracy: 0.820
# Epoch: 656/4000,  loss: 0.486, test accuracy: 0.830
# Epoch: 657/4000,  loss: 0.497, test accuracy: 0.840
# Epoch: 658/4000,  loss: 0.486, test accuracy: 0.820
# Epoch: 659/4000,  loss: 0.488, test accuracy: 0.830
# Epoch: 660/4000,  loss: 0.482, test accuracy: 0.830
# Epoch: 661/4000,  loss: 0.478, test accuracy: 0.820
# Epoch: 662/4000,  loss: 0.506, test accuracy: 0.830
# Epoch: 663/4000,  loss: 0.486, test accuracy: 0.810
# Epoch: 664/4000,  loss: 0.525, test accuracy: 0.820
# Epoch: 665/4000,  loss: 0.516, test accuracy: 0.810
# Epoch: 666/4000,  loss: 0.489, test accuracy: 0.820
# Epoch: 667/4000,  loss: 0.477, test accuracy: 0.820
# Epoch: 668/4000,  loss: 0.483, test accuracy: 0.820
# Epoch: 669/4000,  loss: 0.484, test accuracy: 0.830
# Epoch: 670/4000,  loss: 0.489, test accuracy: 0.810
# Epoch: 671/4000,  loss: 0.503, test accuracy: 0.820
# Epoch: 672/4000,  loss: 0.488, test accuracy: 0.820
# Epoch: 673/4000,  loss: 0.497, test accuracy: 0.840
# Epoch: 674/4000,  loss: 0.479, test accuracy: 0.840
# Epoch: 675/4000,  loss: 0.481, test accuracy: 0.840
# Epoch: 676/4000,  loss: 0.497, test accuracy: 0.820
# Epoch: 677/4000,  loss: 0.495, test accuracy: 0.820
# Epoch: 678/4000,  loss: 0.489, test accuracy: 0.830
# Epoch: 679/4000,  loss: 0.484, test accuracy: 0.820
# Epoch: 680/4000,  loss: 0.475, test accuracy: 0.820
# Epoch: 681/4000,  loss: 0.479, test accuracy: 0.840
# Epoch: 682/4000,  loss: 0.491, test accuracy: 0.820
# Epoch: 683/4000,  loss: 0.494, test accuracy: 0.820
# Epoch: 684/4000,  loss: 0.490, test accuracy: 0.820
# Epoch: 685/4000,  loss: 0.488, test accuracy: 0.840
# Epoch: 686/4000,  loss: 0.493, test accuracy: 0.810
# Epoch: 687/4000,  loss: 0.481, test accuracy: 0.830
# Epoch: 688/4000,  loss: 0.489, test accuracy: 0.820
# Epoch: 689/4000,  loss: 0.490, test accuracy: 0.820
# Epoch: 690/4000,  loss: 0.509, test accuracy: 0.820
# Epoch: 691/4000,  loss: 0.506, test accuracy: 0.830
# Epoch: 692/4000,  loss: 0.525, test accuracy: 0.810
# Epoch: 693/4000,  loss: 0.510, test accuracy: 0.840
# Epoch: 694/4000,  loss: 0.484, test accuracy: 0.810
# Epoch: 695/4000,  loss: 0.492, test accuracy: 0.830
# Epoch: 696/4000,  loss: 0.493, test accuracy: 0.810
# Epoch: 697/4000,  loss: 0.506, test accuracy: 0.830
# Epoch: 698/4000,  loss: 0.488, test accuracy: 0.830
# Epoch: 699/4000,  loss: 0.481, test accuracy: 0.830
# Epoch: 700/4000,  loss: 0.496, test accuracy: 0.840
# Epoch: 701/4000,  loss: 0.496, test accuracy: 0.840
# Epoch: 702/4000,  loss: 0.499, test accuracy: 0.810
# Epoch: 703/4000,  loss: 0.536, test accuracy: 0.810
# Epoch: 704/4000,  loss: 0.492, test accuracy: 0.820
# Epoch: 705/4000,  loss: 0.495, test accuracy: 0.810
# Epoch: 706/4000,  loss: 0.497, test accuracy: 0.830
# Epoch: 707/4000,  loss: 0.487, test accuracy: 0.820
# Epoch: 708/4000,  loss: 0.486, test accuracy: 0.830
# Epoch: 709/4000,  loss: 0.502, test accuracy: 0.820
# Epoch: 710/4000,  loss: 0.479, test accuracy: 0.810
# Epoch: 711/4000,  loss: 0.501, test accuracy: 0.810
# Epoch: 712/4000,  loss: 0.485, test accuracy: 0.830
# Epoch: 713/4000,  loss: 0.493, test accuracy: 0.820
# Epoch: 714/4000,  loss: 0.483, test accuracy: 0.820
# Epoch: 715/4000,  loss: 0.500, test accuracy: 0.840
# Epoch: 716/4000,  loss: 0.470, test accuracy: 0.820
# Epoch: 717/4000,  loss: 0.494, test accuracy: 0.820
# Epoch: 718/4000,  loss: 0.502, test accuracy: 0.820
# Epoch: 719/4000,  loss: 0.493, test accuracy: 0.830
# Epoch: 720/4000,  loss: 0.475, test accuracy: 0.830
# Epoch: 721/4000,  loss: 0.497, test accuracy: 0.820
# Epoch: 722/4000,  loss: 0.484, test accuracy: 0.820
# Epoch: 723/4000,  loss: 0.487, test accuracy: 0.820
# Epoch: 724/4000,  loss: 0.487, test accuracy: 0.820
# Epoch: 725/4000,  loss: 0.506, test accuracy: 0.830
# Epoch: 726/4000,  loss: 0.498, test accuracy: 0.830
# Epoch: 727/4000,  loss: 0.493, test accuracy: 0.820
# Epoch: 728/4000,  loss: 0.488, test accuracy: 0.820
# Epoch: 729/4000,  loss: 0.488, test accuracy: 0.810
# Epoch: 730/4000,  loss: 0.486, test accuracy: 0.820
# Epoch: 731/4000,  loss: 0.477, test accuracy: 0.820
# Epoch: 732/4000,  loss: 0.482, test accuracy: 0.820
# Epoch: 733/4000,  loss: 0.494, test accuracy: 0.820
# Epoch: 734/4000,  loss: 0.493, test accuracy: 0.830
# Epoch: 735/4000,  loss: 0.488, test accuracy: 0.820
# Epoch: 736/4000,  loss: 0.488, test accuracy: 0.820
# Epoch: 737/4000,  loss: 0.508, test accuracy: 0.820
# Epoch: 738/4000,  loss: 0.493, test accuracy: 0.830
# Epoch: 739/4000,  loss: 0.509, test accuracy: 0.830
# Epoch: 740/4000,  loss: 0.489, test accuracy: 0.830
# Epoch: 741/4000,  loss: 0.487, test accuracy: 0.820
# Epoch: 742/4000,  loss: 0.493, test accuracy: 0.820
# Epoch: 743/4000,  loss: 0.490, test accuracy: 0.830
# Epoch: 744/4000,  loss: 0.486, test accuracy: 0.820
# Epoch: 745/4000,  loss: 0.479, test accuracy: 0.810
# Epoch: 746/4000,  loss: 0.490, test accuracy: 0.840
# Epoch: 747/4000,  loss: 0.486, test accuracy: 0.820
# Epoch: 748/4000,  loss: 0.477, test accuracy: 0.820
# Epoch: 749/4000,  loss: 0.492, test accuracy: 0.820
# Epoch: 750/4000,  loss: 0.487, test accuracy: 0.820
# Epoch: 751/4000,  loss: 0.478, test accuracy: 0.820
# Epoch: 752/4000,  loss: 0.500, test accuracy: 0.840
# Epoch: 753/4000,  loss: 0.487, test accuracy: 0.820
# Epoch: 754/4000,  loss: 0.501, test accuracy: 0.840
# Epoch: 755/4000,  loss: 0.498, test accuracy: 0.840
# Epoch: 756/4000,  loss: 0.482, test accuracy: 0.810
# Epoch: 757/4000,  loss: 0.487, test accuracy: 0.820
# Epoch: 758/4000,  loss: 0.487, test accuracy: 0.820
# Epoch: 759/4000,  loss: 0.477, test accuracy: 0.840
# Epoch: 760/4000,  loss: 0.485, test accuracy: 0.810
# Epoch: 761/4000,  loss: 0.491, test accuracy: 0.820
# Epoch: 762/4000,  loss: 0.500, test accuracy: 0.840
# Epoch: 763/4000,  loss: 0.476, test accuracy: 0.820
# Epoch: 764/4000,  loss: 0.482, test accuracy: 0.820
# Epoch: 765/4000,  loss: 0.491, test accuracy: 0.840
# Epoch: 766/4000,  loss: 0.497, test accuracy: 0.830
# Epoch: 767/4000,  loss: 0.497, test accuracy: 0.840
# Epoch: 768/4000,  loss: 0.495, test accuracy: 0.820
# Epoch: 769/4000,  loss: 0.488, test accuracy: 0.810
# Epoch: 770/4000,  loss: 0.491, test accuracy: 0.830
# Epoch: 771/4000,  loss: 0.486, test accuracy: 0.810
# Epoch: 772/4000,  loss: 0.493, test accuracy: 0.830
# Epoch: 773/4000,  loss: 0.484, test accuracy: 0.820
# Epoch: 774/4000,  loss: 0.487, test accuracy: 0.830
# Epoch: 775/4000,  loss: 0.479, test accuracy: 0.820
# Epoch: 776/4000,  loss: 0.498, test accuracy: 0.820
# Epoch: 777/4000,  loss: 0.486, test accuracy: 0.820
# Epoch: 778/4000,  loss: 0.496, test accuracy: 0.820
# Epoch: 779/4000,  loss: 0.498, test accuracy: 0.820
# Epoch: 780/4000,  loss: 0.489, test accuracy: 0.820
# Epoch: 781/4000,  loss: 0.490, test accuracy: 0.820
# Epoch: 782/4000,  loss: 0.485, test accuracy: 0.820
# Epoch: 783/4000,  loss: 0.487, test accuracy: 0.840
# Epoch: 784/4000,  loss: 0.500, test accuracy: 0.830
# Epoch: 785/4000,  loss: 0.478, test accuracy: 0.820
# Epoch: 786/4000,  loss: 0.476, test accuracy: 0.820
# Epoch: 787/4000,  loss: 0.486, test accuracy: 0.820
# Epoch: 788/4000,  loss: 0.500, test accuracy: 0.840
# Epoch: 789/4000,  loss: 0.480, test accuracy: 0.830
# Epoch: 790/4000,  loss: 0.492, test accuracy: 0.820
# Epoch: 791/4000,  loss: 0.490, test accuracy: 0.830
# Epoch: 792/4000,  loss: 0.494, test accuracy: 0.820
# Epoch: 793/4000,  loss: 0.489, test accuracy: 0.810
# Epoch: 794/4000,  loss: 0.488, test accuracy: 0.820
# Epoch: 795/4000,  loss: 0.491, test accuracy: 0.820
# Epoch: 796/4000,  loss: 0.492, test accuracy: 0.830
# Epoch: 797/4000,  loss: 0.487, test accuracy: 0.840
# Epoch: 798/4000,  loss: 0.496, test accuracy: 0.830
# Epoch: 799/4000,  loss: 0.481, test accuracy: 0.840
# Epoch: 800/4000,  loss: 0.493, test accuracy: 0.820
# Epoch: 801/4000,  loss: 0.486, test accuracy: 0.820
# Epoch: 802/4000,  loss: 0.500, test accuracy: 0.830
# Epoch: 803/4000,  loss: 0.490, test accuracy: 0.820
# Epoch: 804/4000,  loss: 0.482, test accuracy: 0.820
# Epoch: 805/4000,  loss: 0.494, test accuracy: 0.820
# Epoch: 806/4000,  loss: 0.483, test accuracy: 0.810
# Epoch: 807/4000,  loss: 0.467, test accuracy: 0.820
# Epoch: 808/4000,  loss: 0.481, test accuracy: 0.820
# Epoch: 809/4000,  loss: 0.487, test accuracy: 0.830
# Epoch: 810/4000,  loss: 0.505, test accuracy: 0.820
# Epoch: 811/4000,  loss: 0.500, test accuracy: 0.820
# Epoch: 812/4000,  loss: 0.494, test accuracy: 0.840
# Epoch: 813/4000,  loss: 0.493, test accuracy: 0.810
# Epoch: 814/4000,  loss: 0.470, test accuracy: 0.820
# Epoch: 815/4000,  loss: 0.500, test accuracy: 0.820
# Epoch: 816/4000,  loss: 0.499, test accuracy: 0.830
# Epoch: 817/4000,  loss: 0.503, test accuracy: 0.810
# Epoch: 818/4000,  loss: 0.529, test accuracy: 0.840
# Epoch: 819/4000,  loss: 0.505, test accuracy: 0.810
# Epoch: 820/4000,  loss: 0.483, test accuracy: 0.840
# Epoch: 821/4000,  loss: 0.501, test accuracy: 0.820
# Epoch: 822/4000,  loss: 0.475, test accuracy: 0.820
# Epoch: 823/4000,  loss: 0.486, test accuracy: 0.810
# Epoch: 824/4000,  loss: 0.485, test accuracy: 0.830
# Epoch: 825/4000,  loss: 0.481, test accuracy: 0.820
# Epoch: 826/4000,  loss: 0.481, test accuracy: 0.820
# Epoch: 827/4000,  loss: 0.491, test accuracy: 0.820
# Epoch: 828/4000,  loss: 0.484, test accuracy: 0.820
# Epoch: 829/4000,  loss: 0.493, test accuracy: 0.820
# Epoch: 830/4000,  loss: 0.493, test accuracy: 0.820
# Epoch: 831/4000,  loss: 0.475, test accuracy: 0.820
# Epoch: 832/4000,  loss: 0.472, test accuracy: 0.830
# Epoch: 833/4000,  loss: 0.484, test accuracy: 0.840
# Epoch: 834/4000,  loss: 0.484, test accuracy: 0.820
# Epoch: 835/4000,  loss: 0.489, test accuracy: 0.830
# Epoch: 836/4000,  loss: 0.491, test accuracy: 0.820
# Epoch: 837/4000,  loss: 0.505, test accuracy: 0.810
# Epoch: 838/4000,  loss: 0.484, test accuracy: 0.830
# Epoch: 839/4000,  loss: 0.471, test accuracy: 0.810
# Epoch: 840/4000,  loss: 0.485, test accuracy: 0.810
# Epoch: 841/4000,  loss: 0.494, test accuracy: 0.820
# Epoch: 842/4000,  loss: 0.503, test accuracy: 0.820
# Epoch: 843/4000,  loss: 0.492, test accuracy: 0.820
# Epoch: 844/4000,  loss: 0.492, test accuracy: 0.810
# Epoch: 845/4000,  loss: 0.492, test accuracy: 0.840
# Epoch: 846/4000,  loss: 0.483, test accuracy: 0.820
# Epoch: 847/4000,  loss: 0.485, test accuracy: 0.810
# Epoch: 848/4000,  loss: 0.475, test accuracy: 0.810
# Epoch: 849/4000,  loss: 0.492, test accuracy: 0.820
# Epoch: 850/4000,  loss: 0.477, test accuracy: 0.820
# Epoch: 851/4000,  loss: 0.493, test accuracy: 0.820
# Epoch: 852/4000,  loss: 0.484, test accuracy: 0.820
# Epoch: 853/4000,  loss: 0.486, test accuracy: 0.820
# Epoch: 854/4000,  loss: 0.490, test accuracy: 0.810
# Epoch: 855/4000,  loss: 0.481, test accuracy: 0.820
# Epoch: 856/4000,  loss: 0.482, test accuracy: 0.820
# Epoch: 857/4000,  loss: 0.479, test accuracy: 0.820
# Epoch: 858/4000,  loss: 0.491, test accuracy: 0.820
# Epoch: 859/4000,  loss: 0.493, test accuracy: 0.820
# Epoch: 860/4000,  loss: 0.491, test accuracy: 0.820
# Epoch: 861/4000,  loss: 0.487, test accuracy: 0.820
# Epoch: 862/4000,  loss: 0.490, test accuracy: 0.830
# Epoch: 863/4000,  loss: 0.504, test accuracy: 0.820
# Epoch: 864/4000,  loss: 0.483, test accuracy: 0.830
# Epoch: 865/4000,  loss: 0.472, test accuracy: 0.810
# Epoch: 866/4000,  loss: 0.476, test accuracy: 0.820
# Epoch: 867/4000,  loss: 0.471, test accuracy: 0.820
# Epoch: 868/4000,  loss: 0.472, test accuracy: 0.820
# Epoch: 869/4000,  loss: 0.481, test accuracy: 0.820
# Epoch: 870/4000,  loss: 0.488, test accuracy: 0.830
# Epoch: 871/4000,  loss: 0.489, test accuracy: 0.810
# Epoch: 872/4000,  loss: 0.483, test accuracy: 0.820
# Epoch: 873/4000,  loss: 0.487, test accuracy: 0.800
# Epoch: 874/4000,  loss: 0.475, test accuracy: 0.820
# Epoch: 875/4000,  loss: 0.486, test accuracy: 0.820
# Epoch: 876/4000,  loss: 0.470, test accuracy: 0.820
# Epoch: 877/4000,  loss: 0.489, test accuracy: 0.830
# Epoch: 878/4000,  loss: 0.487, test accuracy: 0.820
# Epoch: 879/4000,  loss: 0.486, test accuracy: 0.820
# Epoch: 880/4000,  loss: 0.469, test accuracy: 0.820
# Epoch: 881/4000,  loss: 0.488, test accuracy: 0.810
# Epoch: 882/4000,  loss: 0.491, test accuracy: 0.820
# Epoch: 883/4000,  loss: 0.482, test accuracy: 0.830
# Epoch: 884/4000,  loss: 0.477, test accuracy: 0.810
# Epoch: 885/4000,  loss: 0.489, test accuracy: 0.820
# Epoch: 886/4000,  loss: 0.491, test accuracy: 0.820
# Epoch: 887/4000,  loss: 0.476, test accuracy: 0.810
# Epoch: 888/4000,  loss: 0.514, test accuracy: 0.810
# Epoch: 889/4000,  loss: 0.494, test accuracy: 0.820
# Epoch: 890/4000,  loss: 0.471, test accuracy: 0.790
# Epoch: 891/4000,  loss: 0.492, test accuracy: 0.810
# Epoch: 892/4000,  loss: 0.473, test accuracy: 0.820
# Epoch: 893/4000,  loss: 0.489, test accuracy: 0.820
# Epoch: 894/4000,  loss: 0.485, test accuracy: 0.820
# Epoch: 895/4000,  loss: 0.482, test accuracy: 0.820
# Epoch: 896/4000,  loss: 0.479, test accuracy: 0.810
# Epoch: 897/4000,  loss: 0.490, test accuracy: 0.820
# Epoch: 898/4000,  loss: 0.477, test accuracy: 0.810
# Epoch: 899/4000,  loss: 0.497, test accuracy: 0.820
# Epoch: 900/4000,  loss: 0.498, test accuracy: 0.820
# Epoch: 901/4000,  loss: 0.488, test accuracy: 0.810
# Epoch: 902/4000,  loss: 0.488, test accuracy: 0.830
# Epoch: 903/4000,  loss: 0.495, test accuracy: 0.820
# Epoch: 904/4000,  loss: 0.483, test accuracy: 0.820
# Epoch: 905/4000,  loss: 0.488, test accuracy: 0.820
# Epoch: 906/4000,  loss: 0.483, test accuracy: 0.820
# Epoch: 907/4000,  loss: 0.486, test accuracy: 0.820
# Epoch: 908/4000,  loss: 0.483, test accuracy: 0.830
# Epoch: 909/4000,  loss: 0.502, test accuracy: 0.810
# Epoch: 910/4000,  loss: 0.494, test accuracy: 0.820
# Epoch: 911/4000,  loss: 0.495, test accuracy: 0.800
# Epoch: 912/4000,  loss: 0.477, test accuracy: 0.820
# Epoch: 913/4000,  loss: 0.480, test accuracy: 0.810
# Epoch: 914/4000,  loss: 0.497, test accuracy: 0.830
# Epoch: 915/4000,  loss: 0.484, test accuracy: 0.820
# Epoch: 916/4000,  loss: 0.493, test accuracy: 0.820
# Epoch: 917/4000,  loss: 0.485, test accuracy: 0.820
# Epoch: 918/4000,  loss: 0.474, test accuracy: 0.810
# Epoch: 919/4000,  loss: 0.490, test accuracy: 0.830
# Epoch: 920/4000,  loss: 0.467, test accuracy: 0.810
# Epoch: 921/4000,  loss: 0.500, test accuracy: 0.820
# Epoch: 922/4000,  loss: 0.496, test accuracy: 0.820
# Epoch: 923/4000,  loss: 0.476, test accuracy: 0.810
# Epoch: 924/4000,  loss: 0.484, test accuracy: 0.810
# Epoch: 925/4000,  loss: 0.485, test accuracy: 0.820
# ...
# Epoch: 3700/4000,  loss: 0.352, test accuracy: 0.890
# Epoch: 3701/4000,  loss: 0.340, test accuracy: 0.880
# Epoch: 3702/4000,  loss: 0.340, test accuracy: 0.880
# Epoch: 3703/4000,  loss: 0.361, test accuracy: 0.880
# Epoch: 3704/4000,  loss: 0.367, test accuracy: 0.870
# Epoch: 3705/4000,  loss: 0.356, test accuracy: 0.900
# Epoch: 3706/4000,  loss: 0.358, test accuracy: 0.880
# Epoch: 3707/4000,  loss: 0.352, test accuracy: 0.860
# Epoch: 3708/4000,  loss: 0.341, test accuracy: 0.880
# Epoch: 3709/4000,  loss: 0.343, test accuracy: 0.880
# Epoch: 3710/4000,  loss: 0.343, test accuracy: 0.880
# Epoch: 3711/4000,  loss: 0.340, test accuracy: 0.890
# Epoch: 3712/4000,  loss: 0.351, test accuracy: 0.890
# Epoch: 3713/4000,  loss: 0.336, test accuracy: 0.880
# Epoch: 3714/4000,  loss: 0.346, test accuracy: 0.880
# Epoch: 3715/4000,  loss: 0.349, test accuracy: 0.880
# Epoch: 3716/4000,  loss: 0.340, test accuracy: 0.850
# Epoch: 3717/4000,  loss: 0.347, test accuracy: 0.880
# Epoch: 3718/4000,  loss: 0.334, test accuracy: 0.870
# Epoch: 3719/4000,  loss: 0.351, test accuracy: 0.870
# Epoch: 3720/4000,  loss: 0.339, test accuracy: 0.890
# Epoch: 3721/4000,  loss: 0.348, test accuracy: 0.880
# Epoch: 3722/4000,  loss: 0.343, test accuracy: 0.870
# Epoch: 3723/4000,  loss: 0.354, test accuracy: 0.890
# Epoch: 3724/4000,  loss: 0.347, test accuracy: 0.860
# Epoch: 3725/4000,  loss: 0.351, test accuracy: 0.880
# Epoch: 3726/4000,  loss: 0.350, test accuracy: 0.880
# Epoch: 3727/4000,  loss: 0.356, test accuracy: 0.880
# Epoch: 3728/4000,  loss: 0.349, test accuracy: 0.880
# Epoch: 3729/4000,  loss: 0.350, test accuracy: 0.880
# Epoch: 3730/4000,  loss: 0.356, test accuracy: 0.880
# Epoch: 3731/4000,  loss: 0.365, test accuracy: 0.890
# Epoch: 3732/4000,  loss: 0.347, test accuracy: 0.870
# Epoch: 3733/4000,  loss: 0.357, test accuracy: 0.880
# Epoch: 3734/4000,  loss: 0.352, test accuracy: 0.890
# Epoch: 3735/4000,  loss: 0.346, test accuracy: 0.880
# Epoch: 3736/4000,  loss: 0.366, test accuracy: 0.870
# Epoch: 3737/4000,  loss: 0.349, test accuracy: 0.890
# Epoch: 3738/4000,  loss: 0.355, test accuracy: 0.850
# Epoch: 3739/4000,  loss: 0.354, test accuracy: 0.870
# Epoch: 3740/4000,  loss: 0.347, test accuracy: 0.880
# Epoch: 3741/4000,  loss: 0.359, test accuracy: 0.870
# Epoch: 3742/4000,  loss: 0.355, test accuracy: 0.880
# Epoch: 3743/4000,  loss: 0.335, test accuracy: 0.890
# Epoch: 3744/4000,  loss: 0.346, test accuracy: 0.880
# Epoch: 3745/4000,  loss: 0.355, test accuracy: 0.880
# Epoch: 3746/4000,  loss: 0.342, test accuracy: 0.860
# Epoch: 3747/4000,  loss: 0.343, test accuracy: 0.880
# Epoch: 3748/4000,  loss: 0.353, test accuracy: 0.890
# Epoch: 3749/4000,  loss: 0.347, test accuracy: 0.880
# Epoch: 3750/4000,  loss: 0.345, test accuracy: 0.880
# Epoch: 3751/4000,  loss: 0.336, test accuracy: 0.880
# Epoch: 3752/4000,  loss: 0.343, test accuracy: 0.880
# Epoch: 3753/4000,  loss: 0.354, test accuracy: 0.880
# Epoch: 3754/4000,  loss: 0.344, test accuracy: 0.880
# Epoch: 3755/4000,  loss: 0.340, test accuracy: 0.890
# Epoch: 3756/4000,  loss: 0.348, test accuracy: 0.880
# Epoch: 3757/4000,  loss: 0.341, test accuracy: 0.880
# Epoch: 3758/4000,  loss: 0.349, test accuracy: 0.880
# Epoch: 3759/4000,  loss: 0.350, test accuracy: 0.880
# Epoch: 3760/4000,  loss: 0.354, test accuracy: 0.880
# Epoch: 3761/4000,  loss: 0.341, test accuracy: 0.870
# Epoch: 3762/4000,  loss: 0.347, test accuracy: 0.880
# Epoch: 3763/4000,  loss: 0.343, test accuracy: 0.880
# Epoch: 3764/4000,  loss: 0.359, test accuracy: 0.890
# Epoch: 3765/4000,  loss: 0.344, test accuracy: 0.840
# Epoch: 3766/4000,  loss: 0.341, test accuracy: 0.880
# Epoch: 3767/4000,  loss: 0.344, test accuracy: 0.890
# Epoch: 3768/4000,  loss: 0.340, test accuracy: 0.880
# Epoch: 3769/4000,  loss: 0.348, test accuracy: 0.880
# Epoch: 3770/4000,  loss: 0.341, test accuracy: 0.880
# Epoch: 3771/4000,  loss: 0.351, test accuracy: 0.880
# Epoch: 3772/4000,  loss: 0.351, test accuracy: 0.880
# Epoch: 3773/4000,  loss: 0.344, test accuracy: 0.880
# Epoch: 3774/4000,  loss: 0.350, test accuracy: 0.890
# Epoch: 3775/4000,  loss: 0.333, test accuracy: 0.880
# Epoch: 3776/4000,  loss: 0.348, test accuracy: 0.880
# Epoch: 3777/4000,  loss: 0.347, test accuracy: 0.890
# Epoch: 3778/4000,  loss: 0.343, test accuracy: 0.860
# Epoch: 3779/4000,  loss: 0.354, test accuracy: 0.870
# Epoch: 3780/4000,  loss: 0.369, test accuracy: 0.890
# Epoch: 3781/4000,  loss: 0.356, test accuracy: 0.860
# Epoch: 3782/4000,  loss: 0.358, test accuracy: 0.890
# Epoch: 3783/4000,  loss: 0.365, test accuracy: 0.880
# Epoch: 3784/4000,  loss: 0.358, test accuracy: 0.850
# Epoch: 3785/4000,  loss: 0.356, test accuracy: 0.900
# Epoch: 3786/4000,  loss: 0.358, test accuracy: 0.880
# Epoch: 3787/4000,  loss: 0.344, test accuracy: 0.870
# Epoch: 3788/4000,  loss: 0.361, test accuracy: 0.880
# Epoch: 3789/4000,  loss: 0.356, test accuracy: 0.880
# Epoch: 3790/4000,  loss: 0.342, test accuracy: 0.870
# Epoch: 3791/4000,  loss: 0.348, test accuracy: 0.880
# Epoch: 3792/4000,  loss: 0.338, test accuracy: 0.870
# Epoch: 3793/4000,  loss: 0.339, test accuracy: 0.880
# Epoch: 3794/4000,  loss: 0.337, test accuracy: 0.880
# Epoch: 3795/4000,  loss: 0.341, test accuracy: 0.890
# Epoch: 3796/4000,  loss: 0.340, test accuracy: 0.880
# Epoch: 3797/4000,  loss: 0.352, test accuracy: 0.880
# Epoch: 3798/4000,  loss: 0.348, test accuracy: 0.870
# Epoch: 3799/4000,  loss: 0.332, test accuracy: 0.890
# Epoch: 3800/4000,  loss: 0.344, test accuracy: 0.880
# Epoch: 3801/4000,  loss: 0.341, test accuracy: 0.890
# Epoch: 3802/4000,  loss: 0.352, test accuracy: 0.880
# Epoch: 3803/4000,  loss: 0.346, test accuracy: 0.880
# Epoch: 3804/4000,  loss: 0.345, test accuracy: 0.870
# Epoch: 3805/4000,  loss: 0.342, test accuracy: 0.890
# Epoch: 3806/4000,  loss: 0.344, test accuracy: 0.880
# Epoch: 3807/4000,  loss: 0.345, test accuracy: 0.870
# Epoch: 3808/4000,  loss: 0.351, test accuracy: 0.890
# Epoch: 3809/4000,  loss: 0.362, test accuracy: 0.880
# Epoch: 3810/4000,  loss: 0.348, test accuracy: 0.860
# Epoch: 3811/4000,  loss: 0.338, test accuracy: 0.890
# Epoch: 3812/4000,  loss: 0.349, test accuracy: 0.890
# Epoch: 3813/4000,  loss: 0.342, test accuracy: 0.880
# Epoch: 3814/4000,  loss: 0.339, test accuracy: 0.880
# Epoch: 3815/4000,  loss: 0.340, test accuracy: 0.880
# Epoch: 3816/4000,  loss: 0.342, test accuracy: 0.880
# Epoch: 3817/4000,  loss: 0.350, test accuracy: 0.890
# Epoch: 3818/4000,  loss: 0.352, test accuracy: 0.870
# Epoch: 3819/4000,  loss: 0.348, test accuracy: 0.880
# Epoch: 3820/4000,  loss: 0.351, test accuracy: 0.880
# Epoch: 3821/4000,  loss: 0.356, test accuracy: 0.880
# Epoch: 3822/4000,  loss: 0.343, test accuracy: 0.880
# Epoch: 3823/4000,  loss: 0.347, test accuracy: 0.890
# Epoch: 3824/4000,  loss: 0.362, test accuracy: 0.880
# Epoch: 3825/4000,  loss: 0.355, test accuracy: 0.860
# Epoch: 3826/4000,  loss: 0.343, test accuracy: 0.890
# Epoch: 3827/4000,  loss: 0.347, test accuracy: 0.880
# Epoch: 3828/4000,  loss: 0.334, test accuracy: 0.880
# Epoch: 3829/4000,  loss: 0.346, test accuracy: 0.880
# Epoch: 3830/4000,  loss: 0.352, test accuracy: 0.890
# Epoch: 3831/4000,  loss: 0.342, test accuracy: 0.860
# Epoch: 3832/4000,  loss: 0.351, test accuracy: 0.870
# Epoch: 3833/4000,  loss: 0.360, test accuracy: 0.880
# Epoch: 3834/4000,  loss: 0.357, test accuracy: 0.880
# Epoch: 3835/4000,  loss: 0.341, test accuracy: 0.870
# Epoch: 3836/4000,  loss: 0.352, test accuracy: 0.890
# Epoch: 3837/4000,  loss: 0.367, test accuracy: 0.880
# Epoch: 3838/4000,  loss: 0.345, test accuracy: 0.860
# Epoch: 3839/4000,  loss: 0.364, test accuracy: 0.890
# Epoch: 3840/4000,  loss: 0.334, test accuracy: 0.870
# Epoch: 3841/4000,  loss: 0.337, test accuracy: 0.890
# Epoch: 3842/4000,  loss: 0.345, test accuracy: 0.880
# Epoch: 3843/4000,  loss: 0.343, test accuracy: 0.880
# Epoch: 3844/4000,  loss: 0.347, test accuracy: 0.890
# Epoch: 3845/4000,  loss: 0.340, test accuracy: 0.880
# Epoch: 3846/4000,  loss: 0.353, test accuracy: 0.880
# Epoch: 3847/4000,  loss: 0.356, test accuracy: 0.870
# Epoch: 3848/4000,  loss: 0.365, test accuracy: 0.880
# Epoch: 3849/4000,  loss: 0.347, test accuracy: 0.890
# Epoch: 3850/4000,  loss: 0.354, test accuracy: 0.880
# Epoch: 3851/4000,  loss: 0.351, test accuracy: 0.880
# Epoch: 3852/4000,  loss: 0.356, test accuracy: 0.880
# Epoch: 3853/4000,  loss: 0.343, test accuracy: 0.880
# Epoch: 3854/4000,  loss: 0.339, test accuracy: 0.890
# Epoch: 3855/4000,  loss: 0.356, test accuracy: 0.880
# Epoch: 3856/4000,  loss: 0.357, test accuracy: 0.890
# Epoch: 3857/4000,  loss: 0.351, test accuracy: 0.870
# Epoch: 3858/4000,  loss: 0.343, test accuracy: 0.880
# Epoch: 3859/4000,  loss: 0.366, test accuracy: 0.880
# Epoch: 3860/4000,  loss: 0.347, test accuracy: 0.840
# Epoch: 3861/4000,  loss: 0.348, test accuracy: 0.880
# Epoch: 3862/4000,  loss: 0.342, test accuracy: 0.860
# Epoch: 3863/4000,  loss: 0.349, test accuracy: 0.880
# Epoch: 3864/4000,  loss: 0.339, test accuracy: 0.880
# Epoch: 3865/4000,  loss: 0.346, test accuracy: 0.890
# Epoch: 3866/4000,  loss: 0.354, test accuracy: 0.880
# Epoch: 3867/4000,  loss: 0.350, test accuracy: 0.850
# Epoch: 3868/4000,  loss: 0.347, test accuracy: 0.880
# Epoch: 3869/4000,  loss: 0.346, test accuracy: 0.890
# Epoch: 3870/4000,  loss: 0.348, test accuracy: 0.840
# Epoch: 3871/4000,  loss: 0.356, test accuracy: 0.890
# Epoch: 3872/4000,  loss: 0.352, test accuracy: 0.880
# Epoch: 3873/4000,  loss: 0.344, test accuracy: 0.890
# Epoch: 3874/4000,  loss: 0.338, test accuracy: 0.880
# Epoch: 3875/4000,  loss: 0.329, test accuracy: 0.870
# Epoch: 3876/4000,  loss: 0.360, test accuracy: 0.880
# Epoch: 3877/4000,  loss: 0.347, test accuracy: 0.880
# Epoch: 3878/4000,  loss: 0.354, test accuracy: 0.880
# Epoch: 3879/4000,  loss: 0.340, test accuracy: 0.880
# Epoch: 3880/4000,  loss: 0.345, test accuracy: 0.880
# Epoch: 3881/4000,  loss: 0.344, test accuracy: 0.880
# Epoch: 3882/4000,  loss: 0.343, test accuracy: 0.890
# Epoch: 3883/4000,  loss: 0.340, test accuracy: 0.880
# Epoch: 3884/4000,  loss: 0.344, test accuracy: 0.890
# Epoch: 3885/4000,  loss: 0.346, test accuracy: 0.880
# Epoch: 3886/4000,  loss: 0.349, test accuracy: 0.880
# Epoch: 3887/4000,  loss: 0.356, test accuracy: 0.880
# Epoch: 3888/4000,  loss: 0.356, test accuracy: 0.870
# Epoch: 3889/4000,  loss: 0.346, test accuracy: 0.880
# Epoch: 3890/4000,  loss: 0.332, test accuracy: 0.880
# Epoch: 3891/4000,  loss: 0.348, test accuracy: 0.880
# Epoch: 3892/4000,  loss: 0.339, test accuracy: 0.880
# Epoch: 3893/4000,  loss: 0.346, test accuracy: 0.880
# Epoch: 3894/4000,  loss: 0.344, test accuracy: 0.880
# Epoch: 3895/4000,  loss: 0.338, test accuracy: 0.880
# Epoch: 3896/4000,  loss: 0.344, test accuracy: 0.890
# Epoch: 3897/4000,  loss: 0.344, test accuracy: 0.890
# Epoch: 3898/4000,  loss: 0.342, test accuracy: 0.880
# Epoch: 3899/4000,  loss: 0.338, test accuracy: 0.880
# Epoch: 3900/4000,  loss: 0.346, test accuracy: 0.860
# Epoch: 3901/4000,  loss: 0.356, test accuracy: 0.880
# Epoch: 3902/4000,  loss: 0.348, test accuracy: 0.890
# Epoch: 3903/4000,  loss: 0.344, test accuracy: 0.880
# Epoch: 3904/4000,  loss: 0.340, test accuracy: 0.880
# Epoch: 3905/4000,  loss: 0.342, test accuracy: 0.880
# Epoch: 3906/4000,  loss: 0.350, test accuracy: 0.870
# Epoch: 3907/4000,  loss: 0.362, test accuracy: 0.890
# Epoch: 3908/4000,  loss: 0.348, test accuracy: 0.880
# Epoch: 3909/4000,  loss: 0.345, test accuracy: 0.880
# Epoch: 3910/4000,  loss: 0.352, test accuracy: 0.880
# Epoch: 3911/4000,  loss: 0.342, test accuracy: 0.880
# Epoch: 3912/4000,  loss: 0.345, test accuracy: 0.880
# Epoch: 3913/4000,  loss: 0.363, test accuracy: 0.890
# Epoch: 3914/4000,  loss: 0.341, test accuracy: 0.880
# Epoch: 3915/4000,  loss: 0.344, test accuracy: 0.880
# Epoch: 3916/4000,  loss: 0.345, test accuracy: 0.890
# Epoch: 3917/4000,  loss: 0.342, test accuracy: 0.870
# Epoch: 3918/4000,  loss: 0.361, test accuracy: 0.890
# Epoch: 3919/4000,  loss: 0.350, test accuracy: 0.890
# Epoch: 3920/4000,  loss: 0.344, test accuracy: 0.890
# Epoch: 3921/4000,  loss: 0.361, test accuracy: 0.870
# Epoch: 3922/4000,  loss: 0.345, test accuracy: 0.900
# Epoch: 3923/4000,  loss: 0.346, test accuracy: 0.880
# Epoch: 3924/4000,  loss: 0.340, test accuracy: 0.890
# Epoch: 3925/4000,  loss: 0.352, test accuracy: 0.890
# Epoch: 3926/4000,  loss: 0.346, test accuracy: 0.870
# Epoch: 3927/4000,  loss: 0.343, test accuracy: 0.880
# Epoch: 3928/4000,  loss: 0.350, test accuracy: 0.890
# Epoch: 3929/4000,  loss: 0.367, test accuracy: 0.880
# Epoch: 3930/4000,  loss: 0.345, test accuracy: 0.880
# Epoch: 3931/4000,  loss: 0.344, test accuracy: 0.880
# Epoch: 3932/4000,  loss: 0.343, test accuracy: 0.890
# Epoch: 3933/4000,  loss: 0.350, test accuracy: 0.880
# Epoch: 3934/4000,  loss: 0.342, test accuracy: 0.870
# Epoch: 3935/4000,  loss: 0.341, test accuracy: 0.890
# Epoch: 3936/4000,  loss: 0.347, test accuracy: 0.870
# Epoch: 3937/4000,  loss: 0.342, test accuracy: 0.890
# Epoch: 3938/4000,  loss: 0.343, test accuracy: 0.880
# Epoch: 3939/4000,  loss: 0.335, test accuracy: 0.880
# Epoch: 3940/4000,  loss: 0.353, test accuracy: 0.880
# Epoch: 3941/4000,  loss: 0.334, test accuracy: 0.880
# Epoch: 3942/4000,  loss: 0.355, test accuracy: 0.880
# Epoch: 3943/4000,  loss: 0.339, test accuracy: 0.870
# Epoch: 3944/4000,  loss: 0.362, test accuracy: 0.880
# Epoch: 3945/4000,  loss: 0.353, test accuracy: 0.880
# Epoch: 3946/4000,  loss: 0.340, test accuracy: 0.880
# Epoch: 3947/4000,  loss: 0.336, test accuracy: 0.870
# Epoch: 3948/4000,  loss: 0.349, test accuracy: 0.880
# Epoch: 3949/4000,  loss: 0.338, test accuracy: 0.880
# Epoch: 3950/4000,  loss: 0.343, test accuracy: 0.870
# Epoch: 3951/4000,  loss: 0.355, test accuracy: 0.890
# Epoch: 3952/4000,  loss: 0.377, test accuracy: 0.890
# Epoch: 3953/4000,  loss: 0.339, test accuracy: 0.840
# Epoch: 3954/4000,  loss: 0.357, test accuracy: 0.880
# Epoch: 3955/4000,  loss: 0.359, test accuracy: 0.890
# Epoch: 3956/4000,  loss: 0.344, test accuracy: 0.880
# Epoch: 3957/4000,  loss: 0.344, test accuracy: 0.880
# Epoch: 3958/4000,  loss: 0.349, test accuracy: 0.880
# Epoch: 3959/4000,  loss: 0.356, test accuracy: 0.880
# Epoch: 3960/4000,  loss: 0.353, test accuracy: 0.880
# Epoch: 3961/4000,  loss: 0.336, test accuracy: 0.890
# Epoch: 3962/4000,  loss: 0.333, test accuracy: 0.880
# Epoch: 3963/4000,  loss: 0.337, test accuracy: 0.880
# Epoch: 3964/4000,  loss: 0.345, test accuracy: 0.880
# Epoch: 3965/4000,  loss: 0.359, test accuracy: 0.870
# Epoch: 3966/4000,  loss: 0.357, test accuracy: 0.880
# Epoch: 3967/4000,  loss: 0.339, test accuracy: 0.880
# Epoch: 3968/4000,  loss: 0.346, test accuracy: 0.880
# Epoch: 3969/4000,  loss: 0.359, test accuracy: 0.890
# Epoch: 3970/4000,  loss: 0.337, test accuracy: 0.880
# Epoch: 3971/4000,  loss: 0.339, test accuracy: 0.880
# Epoch: 3972/4000,  loss: 0.341, test accuracy: 0.890
# Epoch: 3973/4000,  loss: 0.348, test accuracy: 0.890
# Epoch: 3974/4000,  loss: 0.347, test accuracy: 0.880
# Epoch: 3975/4000,  loss: 0.355, test accuracy: 0.890
# Epoch: 3976/4000,  loss: 0.348, test accuracy: 0.880
# Epoch: 3977/4000,  loss: 0.353, test accuracy: 0.870
# Epoch: 3978/4000,  loss: 0.348, test accuracy: 0.880
# Epoch: 3979/4000,  loss: 0.350, test accuracy: 0.890
# Epoch: 3980/4000,  loss: 0.337, test accuracy: 0.840
# Epoch: 3981/4000,  loss: 0.344, test accuracy: 0.890
# Epoch: 3982/4000,  loss: 0.351, test accuracy: 0.880
# Epoch: 3983/4000,  loss: 0.345, test accuracy: 0.880
# Epoch: 3984/4000,  loss: 0.343, test accuracy: 0.870
# Epoch: 3985/4000,  loss: 0.350, test accuracy: 0.880
# Epoch: 3986/4000,  loss: 0.352, test accuracy: 0.880
# Epoch: 3987/4000,  loss: 0.341, test accuracy: 0.890
# Epoch: 3988/4000,  loss: 0.352, test accuracy: 0.880
# Epoch: 3989/4000,  loss: 0.353, test accuracy: 0.880
# Epoch: 3990/4000,  loss: 0.344, test accuracy: 0.880
# Epoch: 3991/4000,  loss: 0.351, test accuracy: 0.880
# Epoch: 3992/4000,  loss: 0.342, test accuracy: 0.840
# Epoch: 3993/4000,  loss: 0.344, test accuracy: 0.880
# Epoch: 3994/4000,  loss: 0.347, test accuracy: 0.890
# Epoch: 3995/4000,  loss: 0.351, test accuracy: 0.840
# Epoch: 3996/4000,  loss: 0.361, test accuracy: 0.890
# Epoch: 3997/4000,  loss: 0.361, test accuracy: 0.890
# Epoch: 3998/4000,  loss: 0.344, test accuracy: 0.880
# Epoch: 3999/4000,  loss: 0.358, test accuracy: 0.890
# Epoch: 4000/4000,  loss: 0.337, test accuracy: 0.870
# Finished Training in 447 seconds

# %%
def plot_cost_accuracy(costs, accuracies):
    # Plots the cost and accuracy evolution during training 
    fig = plt.figure(figsize=plt.figaspect(0.2))
    ax1 = fig.add_subplot(1, 2, 1)
    ax1.plot(costs,'r')
    plt.xlabel('epoch')
    plt.ylabel('Cost')
    ax1 = fig.add_subplot(1, 2, 2)
    ax1.plot(accuracies)
    plt.xlabel('epoch')
    plt.ylabel('Accuracy')
    plt.show()
    A=np.array(accuracies)
    best_epoch=np.argmax(A)
    best_accuracy = max(accuracies)
    print('best_accuracy:',best_accuracy,'achieved at epoch:',best_epoch)
    
    return best_accuracy

# %%
plot_cost_accuracy(sigmoid_costs, sigmoid_accuracies)
# Out:
# best_accuracy: 0.91 achieved at epoch: 1980
# 0.91

# %% [markdown]
# #### Visualize the posterior of the network trained above

# %%
def visualize_posterior(gt_posterior, network):
    #### RUN this after training is done
    x_rng = y_rng = np.linspace(0, 1, 50)
    gridx,gridy = np.meshgrid(x_rng, y_rng)

    grid_features = np.concatenate((gridx.reshape((-1,1)), gridy.reshape((-1,1))),axis=1)
    grid_tensor = torch.FloatTensor(grid_features)
    logits = network(Variable(grid_tensor))
    soft_max = torch.nn.Softmax()
    softmax_outputs = soft_max(logits)

    posterior_0 = softmax_outputs[:,0].data.numpy()
    posterior_1 = softmax_outputs[:,1].data.numpy()
    posterior_0 = posterior_0.reshape(50,50)
    posterior_1 = posterior_1.reshape(50,50)


    fig = plt.figure(figsize=plt.figaspect(0.2))
    ax1 = fig.add_subplot(1, 3, 1)
    ax1.imshow(posterior_1, extent=[0, 1, 0, 1], origin='lower')
    ax1.set_title(" Estimated $P(y=1 \mid x)$")
    ax1.set_xlabel("Feature 1")
    ax1.set_ylabel("Feature 2")

    ax1 = fig.add_subplot(1, 3, 2)
    ax1.imshow(gt_posterior, extent=[0, 1, 0, 1], origin='lower')
    ax1.set_title(" Ground Truth of the positive class $")
    ax1.set_xlabel("Feature 1")
    ax1.set_ylabel("Feature 2")

    ax1 = fig.add_subplot(1, 3, 3)
    ax1.imshow(posterior_1-gt_posterior, extent=[0, 1, 0, 1], origin='lower')
    ax1.set_title("Difference between the estimation and ground truth")
    ax1.set_xlabel("Feature 1")
    ax1.set_ylabel("Feature 2")
    plt.show()

# %%
visualize_posterior(posterior,sigmoid_net)
# Out:
# /home/nick/.local/lib/python3.5/site-packages/ipykernel_launcher.py:10: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# <a id='question 2'></a>
# ## Train a network with ReLU non-linearities across all layers
#
# In this assignment we'll create the same neural network as previously, but we'll use relu activations for the hidden layers instead. ( Hint: relu activations can be called as `F.relu()` in this notebook and as `torch.nn.functional.relu()` in general.
# * Question 2: Add the necessary lines inside `__init__` and `forward`.

# %%
class ReluNet(nn.Module):
    def __init__(self):
        super().__init__()
        ###### TODO QUESTION 2 ########
        self.fc1 = nn.Linear(2, 10)
        self.fc2 = nn.Linear(10, 10)
        self.fc3 = nn.Linear(10, 2)
        ###### TODO QUESTION 2 ########
    
    def forward(self, x):
        ###### TODO QUESTION 2 ########
        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)
        x = F.relu(x)
        x = self.fc3(x)
        
        
        ###### TODO QUESTION 2 ########
        return x

# %%
#Next we'll create an instance of our ReluNet class
relu_net = ReluNet()

# %%
# Here we define the learning rate and the number of epochs for our training. 
learning_rate=0.05 # 
epochs = 1000  ## usually has already converged around that number

## Here we pick the cost function and the optimizer for our training
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(relu_net.parameters(), lr=learning_rate, momentum=0.9)

# %% [markdown]
# ## Training ReluNet
# In the next cell the actual training happens. The network is trained for many epochs and for each of the epochs we split our training data into mini batches using the DataLoader that we created previously and iteratively feed them into our network. After each iteration/optimizer step, the parameters are updated in such a way that the loss is minimized.

# %%
start = time.time()

relu_costs=[]  
relu_accuracies = []

for epoch in range(epochs):  # loop over the dataset multiple times

    running_loss = 0.0
    num_of_batches = 0 
    for i, data in enumerate(trainloader, 0):
        # get the inputs
        inputs, labels = data
#         print(inputs.shape)
#         print(labels.shape)

        # wrap them in Variable
        inputs, labels = Variable(inputs), Variable(labels)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        logits = relu_net(inputs)
        loss = criterion(logits, labels.type(torch.LongTensor))
        
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.data[0]
        num_of_batches +=1
        
    # calculate test accuracy 
    test_logits = relu_net(Variable(test_features_tensor))
    _, test_predictions = torch.max(test_logits.data, 1)    
    correct_predictions = (test_predictions.int() == test_labels_tensor.int()).sum()
    test_length = test_labels_tensor.size()[0]
    accuracy = correct_predictions/test_length
    print('Epoch: %d/%d,  loss: %.3f, test accuracy: %.3f'%(epoch + 1,epochs, running_loss / num_of_batches, accuracy))
    relu_costs.append(running_loss/num_of_batches)
    relu_accuracies.append(accuracy)

    
end = time.time()
duration = end-start
print('Finished Training in %d seconds'%(end-start))
# Out:
# Epoch: 1/1000,  loss: 0.690, test accuracy: 0.590
# Epoch: 2/1000,  loss: 0.688, test accuracy: 0.560
# Epoch: 3/1000,  loss: 0.685, test accuracy: 0.580
# Epoch: 4/1000,  loss: 0.685, test accuracy: 0.630
# Epoch: 5/1000,  loss: 0.672, test accuracy: 0.540
# Epoch: 6/1000,  loss: 0.669, test accuracy: 0.590
# Epoch: 7/1000,  loss: 0.664, test accuracy: 0.610
# Epoch: 8/1000,  loss: 0.659, test accuracy: 0.590
# Epoch: 9/1000,  loss: 0.648, test accuracy: 0.610
# Epoch: 10/1000,  loss: 0.641, test accuracy: 0.640
# Epoch: 11/1000,  loss: 0.641, test accuracy: 0.600
# Epoch: 12/1000,  loss: 0.633, test accuracy: 0.600
# Epoch: 13/1000,  loss: 0.639, test accuracy: 0.600
# Epoch: 14/1000,  loss: 0.632, test accuracy: 0.600
# Epoch: 15/1000,  loss: 0.635, test accuracy: 0.580
# Epoch: 16/1000,  loss: 0.636, test accuracy: 0.610
# Epoch: 17/1000,  loss: 0.651, test accuracy: 0.660
# Epoch: 18/1000,  loss: 0.665, test accuracy: 0.550
# Epoch: 19/1000,  loss: 0.643, test accuracy: 0.620
# Epoch: 20/1000,  loss: 0.614, test accuracy: 0.630
# Epoch: 21/1000,  loss: 0.632, test accuracy: 0.630
# Epoch: 22/1000,  loss: 0.620, test accuracy: 0.660
# Epoch: 23/1000,  loss: 0.604, test accuracy: 0.640
# Epoch: 24/1000,  loss: 0.618, test accuracy: 0.690
# Epoch: 25/1000,  loss: 0.606, test accuracy: 0.700
# Epoch: 26/1000,  loss: 0.600, test accuracy: 0.720
# Epoch: 27/1000,  loss: 0.607, test accuracy: 0.700
# Epoch: 28/1000,  loss: 0.610, test accuracy: 0.670
# Epoch: 29/1000,  loss: 0.600, test accuracy: 0.580
# Epoch: 30/1000,  loss: 0.623, test accuracy: 0.680
# Epoch: 31/1000,  loss: 0.579, test accuracy: 0.690
# Epoch: 32/1000,  loss: 0.572, test accuracy: 0.730
# Epoch: 33/1000,  loss: 0.548, test accuracy: 0.750
# Epoch: 34/1000,  loss: 0.534, test accuracy: 0.800
# Epoch: 35/1000,  loss: 0.533, test accuracy: 0.820
# Epoch: 36/1000,  loss: 0.519, test accuracy: 0.760
# Epoch: 37/1000,  loss: 0.521, test accuracy: 0.820
# Epoch: 38/1000,  loss: 0.517, test accuracy: 0.800
# Epoch: 39/1000,  loss: 0.509, test accuracy: 0.820
# Epoch: 40/1000,  loss: 0.511, test accuracy: 0.760
# Epoch: 41/1000,  loss: 0.509, test accuracy: 0.780
# Epoch: 42/1000,  loss: 0.487, test accuracy: 0.760
# Epoch: 43/1000,  loss: 0.480, test accuracy: 0.760
# Epoch: 44/1000,  loss: 0.503, test accuracy: 0.790
# Epoch: 45/1000,  loss: 0.521, test accuracy: 0.760
# Epoch: 46/1000,  loss: 0.487, test accuracy: 0.800
# Epoch: 47/1000,  loss: 0.496, test accuracy: 0.820
# Epoch: 48/1000,  loss: 0.488, test accuracy: 0.810
# Epoch: 49/1000,  loss: 0.476, test accuracy: 0.760
# Epoch: 50/1000,  loss: 0.512, test accuracy: 0.800
# Epoch: 51/1000,  loss: 0.492, test accuracy: 0.840
# Epoch: 52/1000,  loss: 0.478, test accuracy: 0.780
# Epoch: 53/1000,  loss: 0.498, test accuracy: 0.770
# Epoch: 54/1000,  loss: 0.594, test accuracy: 0.660
# Epoch: 55/1000,  loss: 0.524, test accuracy: 0.800
# Epoch: 56/1000,  loss: 0.493, test accuracy: 0.810
# Epoch: 57/1000,  loss: 0.464, test accuracy: 0.780
# Epoch: 58/1000,  loss: 0.478, test accuracy: 0.800
# Epoch: 59/1000,  loss: 0.468, test accuracy: 0.830
# Epoch: 60/1000,  loss: 0.456, test accuracy: 0.780
# Epoch: 61/1000,  loss: 0.443, test accuracy: 0.860
# Epoch: 62/1000,  loss: 0.420, test accuracy: 0.840
# Epoch: 63/1000,  loss: 0.441, test accuracy: 0.900
# Epoch: 64/1000,  loss: 0.431, test accuracy: 0.870
# Epoch: 65/1000,  loss: 0.442, test accuracy: 0.850
# Epoch: 66/1000,  loss: 0.480, test accuracy: 0.770
# Epoch: 67/1000,  loss: 0.494, test accuracy: 0.820
# Epoch: 68/1000,  loss: 0.446, test accuracy: 0.770
# Epoch: 69/1000,  loss: 0.445, test accuracy: 0.860
# Epoch: 70/1000,  loss: 0.474, test accuracy: 0.870
# Epoch: 71/1000,  loss: 0.459, test accuracy: 0.790
# Epoch: 72/1000,  loss: 0.454, test accuracy: 0.800
# Epoch: 73/1000,  loss: 0.431, test accuracy: 0.870
# Epoch: 74/1000,  loss: 0.443, test accuracy: 0.860
# Epoch: 75/1000,  loss: 0.395, test accuracy: 0.880
# Epoch: 76/1000,  loss: 0.433, test accuracy: 0.880
# Epoch: 77/1000,  loss: 0.458, test accuracy: 0.820
# Epoch: 78/1000,  loss: 0.443, test accuracy: 0.880
# Epoch: 79/1000,  loss: 0.425, test accuracy: 0.810
# Epoch: 80/1000,  loss: 0.428, test accuracy: 0.860
# Epoch: 81/1000,  loss: 0.411, test accuracy: 0.850
# Epoch: 82/1000,  loss: 0.449, test accuracy: 0.850
# Epoch: 83/1000,  loss: 0.413, test accuracy: 0.890
# Epoch: 84/1000,  loss: 0.392, test accuracy: 0.860
# Epoch: 85/1000,  loss: 0.412, test accuracy: 0.780
# Epoch: 86/1000,  loss: 0.427, test accuracy: 0.890
# Epoch: 87/1000,  loss: 0.396, test accuracy: 0.890
# Epoch: 88/1000,  loss: 0.392, test accuracy: 0.810
# Epoch: 89/1000,  loss: 0.386, test accuracy: 0.910
# Epoch: 90/1000,  loss: 0.373, test accuracy: 0.850
# Epoch: 91/1000,  loss: 0.364, test accuracy: 0.870
# Epoch: 92/1000,  loss: 0.370, test accuracy: 0.880
# Epoch: 93/1000,  loss: 0.381, test accuracy: 0.850
# Epoch: 94/1000,  loss: 0.408, test accuracy: 0.850
# Epoch: 95/1000,  loss: 0.409, test accuracy: 0.880
# Epoch: 96/1000,  loss: 0.404, test accuracy: 0.880
# Epoch: 97/1000,  loss: 0.417, test accuracy: 0.880
# Epoch: 98/1000,  loss: 0.381, test accuracy: 0.890
# Epoch: 99/1000,  loss: 0.396, test accuracy: 0.860
# Epoch: 100/1000,  loss: 0.380, test accuracy: 0.870
# Epoch: 101/1000,  loss: 0.435, test accuracy: 0.780
# Epoch: 102/1000,  loss: 0.445, test accuracy: 0.900
# Epoch: 103/1000,  loss: 0.442, test accuracy: 0.850
# Epoch: 104/1000,  loss: 0.429, test accuracy: 0.870
# Epoch: 105/1000,  loss: 0.410, test accuracy: 0.900
# Epoch: 106/1000,  loss: 0.380, test accuracy: 0.850
# Epoch: 107/1000,  loss: 0.378, test accuracy: 0.880
# Epoch: 108/1000,  loss: 0.374, test accuracy: 0.850
# Epoch: 109/1000,  loss: 0.359, test accuracy: 0.860
# Epoch: 110/1000,  loss: 0.365, test accuracy: 0.860
# Epoch: 111/1000,  loss: 0.409, test accuracy: 0.870
# Epoch: 112/1000,  loss: 0.376, test accuracy: 0.860
# Epoch: 113/1000,  loss: 0.377, test accuracy: 0.840
# Epoch: 114/1000,  loss: 0.375, test accuracy: 0.870
# Epoch: 115/1000,  loss: 0.396, test accuracy: 0.880
# Epoch: 116/1000,  loss: 0.449, test accuracy: 0.860
# Epoch: 117/1000,  loss: 0.422, test accuracy: 0.910
# Epoch: 118/1000,  loss: 0.386, test accuracy: 0.860
# Epoch: 119/1000,  loss: 0.365, test accuracy: 0.870
# Epoch: 120/1000,  loss: 0.374, test accuracy: 0.890
# Epoch: 121/1000,  loss: 0.393, test accuracy: 0.850
# Epoch: 122/1000,  loss: 0.380, test accuracy: 0.890
# Epoch: 123/1000,  loss: 0.354, test accuracy: 0.840
# Epoch: 124/1000,  loss: 0.425, test accuracy: 0.860
# Epoch: 125/1000,  loss: 0.413, test accuracy: 0.910
# Epoch: 126/1000,  loss: 0.393, test accuracy: 0.820
# Epoch: 127/1000,  loss: 0.371, test accuracy: 0.880
# Epoch: 128/1000,  loss: 0.364, test accuracy: 0.840
# Epoch: 129/1000,  loss: 0.383, test accuracy: 0.900
# Epoch: 130/1000,  loss: 0.394, test accuracy: 0.870
# Epoch: 131/1000,  loss: 0.406, test accuracy: 0.850
# Epoch: 132/1000,  loss: 0.411, test accuracy: 0.760
# Epoch: 133/1000,  loss: 0.490, test accuracy: 0.850
# Epoch: 134/1000,  loss: 0.396, test accuracy: 0.880
# Epoch: 135/1000,  loss: 0.373, test accuracy: 0.860
# Epoch: 136/1000,  loss: 0.389, test accuracy: 0.870
# Epoch: 137/1000,  loss: 0.383, test accuracy: 0.840
# Epoch: 138/1000,  loss: 0.375, test accuracy: 0.880
# Epoch: 139/1000,  loss: 0.379, test accuracy: 0.890
# Epoch: 140/1000,  loss: 0.360, test accuracy: 0.880
# Epoch: 141/1000,  loss: 0.369, test accuracy: 0.850
# Epoch: 142/1000,  loss: 0.351, test accuracy: 0.850
# Epoch: 143/1000,  loss: 0.365, test accuracy: 0.870
# Epoch: 144/1000,  loss: 0.378, test accuracy: 0.870
# Epoch: 145/1000,  loss: 0.376, test accuracy: 0.880
# Epoch: 146/1000,  loss: 0.394, test accuracy: 0.850
# Epoch: 147/1000,  loss: 0.359, test accuracy: 0.870
# Epoch: 148/1000,  loss: 0.365, test accuracy: 0.870
# Epoch: 149/1000,  loss: 0.383, test accuracy: 0.850
# Epoch: 150/1000,  loss: 0.403, test accuracy: 0.840
# Epoch: 151/1000,  loss: 0.363, test accuracy: 0.850
# Epoch: 152/1000,  loss: 0.364, test accuracy: 0.880
# Epoch: 153/1000,  loss: 0.371, test accuracy: 0.850
# Epoch: 154/1000,  loss: 0.361, test accuracy: 0.850
# Epoch: 155/1000,  loss: 0.399, test accuracy: 0.830
# Epoch: 156/1000,  loss: 0.376, test accuracy: 0.860
# Epoch: 157/1000,  loss: 0.403, test accuracy: 0.870
# Epoch: 158/1000,  loss: 0.358, test accuracy: 0.850
# Epoch: 159/1000,  loss: 0.353, test accuracy: 0.890
# Epoch: 160/1000,  loss: 0.387, test accuracy: 0.880
# Epoch: 161/1000,  loss: 0.382, test accuracy: 0.880
# Epoch: 162/1000,  loss: 0.392, test accuracy: 0.880
# Epoch: 163/1000,  loss: 0.367, test accuracy: 0.880
# Epoch: 164/1000,  loss: 0.372, test accuracy: 0.860
# Epoch: 165/1000,  loss: 0.356, test accuracy: 0.910
# Epoch: 166/1000,  loss: 0.354, test accuracy: 0.860
# Epoch: 167/1000,  loss: 0.388, test accuracy: 0.880
# Epoch: 168/1000,  loss: 0.367, test accuracy: 0.850
# Epoch: 169/1000,  loss: 0.389, test accuracy: 0.860
# Epoch: 170/1000,  loss: 0.361, test accuracy: 0.880
# Epoch: 171/1000,  loss: 0.354, test accuracy: 0.880
# Epoch: 172/1000,  loss: 0.362, test accuracy: 0.870
# Epoch: 173/1000,  loss: 0.366, test accuracy: 0.850
# Epoch: 174/1000,  loss: 0.375, test accuracy: 0.880
# Epoch: 175/1000,  loss: 0.358, test accuracy: 0.880
# Epoch: 176/1000,  loss: 0.355, test accuracy: 0.870
# Epoch: 177/1000,  loss: 0.360, test accuracy: 0.900
# Epoch: 178/1000,  loss: 0.365, test accuracy: 0.890
# Epoch: 179/1000,  loss: 0.358, test accuracy: 0.860
# Epoch: 180/1000,  loss: 0.402, test accuracy: 0.850
# Epoch: 181/1000,  loss: 0.379, test accuracy: 0.850
# Epoch: 182/1000,  loss: 0.387, test accuracy: 0.850
# Epoch: 183/1000,  loss: 0.396, test accuracy: 0.840
# Epoch: 184/1000,  loss: 0.379, test accuracy: 0.920
# Epoch: 185/1000,  loss: 0.404, test accuracy: 0.840
# Epoch: 186/1000,  loss: 0.363, test accuracy: 0.860
# Epoch: 187/1000,  loss: 0.391, test accuracy: 0.880
# Epoch: 188/1000,  loss: 0.354, test accuracy: 0.880
# Epoch: 189/1000,  loss: 0.350, test accuracy: 0.870
# Epoch: 190/1000,  loss: 0.348, test accuracy: 0.880
# Epoch: 191/1000,  loss: 0.367, test accuracy: 0.840
# Epoch: 192/1000,  loss: 0.371, test accuracy: 0.870
# Epoch: 193/1000,  loss: 0.354, test accuracy: 0.850
# Epoch: 194/1000,  loss: 0.365, test accuracy: 0.880
# Epoch: 195/1000,  loss: 0.396, test accuracy: 0.850
# Epoch: 196/1000,  loss: 0.357, test accuracy: 0.860
# Epoch: 197/1000,  loss: 0.362, test accuracy: 0.840
# Epoch: 198/1000,  loss: 0.377, test accuracy: 0.850
# Epoch: 199/1000,  loss: 0.373, test accuracy: 0.880
# Epoch: 200/1000,  loss: 0.380, test accuracy: 0.840
# Epoch: 201/1000,  loss: 0.358, test accuracy: 0.880
# Epoch: 202/1000,  loss: 0.353, test accuracy: 0.870
# Epoch: 203/1000,  loss: 0.347, test accuracy: 0.860
# Epoch: 204/1000,  loss: 0.372, test accuracy: 0.880
# Epoch: 205/1000,  loss: 0.355, test accuracy: 0.880
# Epoch: 206/1000,  loss: 0.352, test accuracy: 0.890
# Epoch: 207/1000,  loss: 0.369, test accuracy: 0.850
# Epoch: 208/1000,  loss: 0.352, test accuracy: 0.860
# Epoch: 209/1000,  loss: 0.360, test accuracy: 0.870
# Epoch: 210/1000,  loss: 0.377, test accuracy: 0.840
# Epoch: 211/1000,  loss: 0.364, test accuracy: 0.860
# Epoch: 212/1000,  loss: 0.358, test accuracy: 0.850
# Epoch: 213/1000,  loss: 0.372, test accuracy: 0.850
# Epoch: 214/1000,  loss: 0.362, test accuracy: 0.830
# Epoch: 215/1000,  loss: 0.366, test accuracy: 0.870
# Epoch: 216/1000,  loss: 0.369, test accuracy: 0.890
# Epoch: 217/1000,  loss: 0.359, test accuracy: 0.820
# Epoch: 218/1000,  loss: 0.378, test accuracy: 0.870
# Epoch: 219/1000,  loss: 0.380, test accuracy: 0.890
# Epoch: 220/1000,  loss: 0.400, test accuracy: 0.900
# Epoch: 221/1000,  loss: 0.371, test accuracy: 0.880
# Epoch: 222/1000,  loss: 0.371, test accuracy: 0.840
# Epoch: 223/1000,  loss: 0.359, test accuracy: 0.880
# Epoch: 224/1000,  loss: 0.343, test accuracy: 0.870
# Epoch: 225/1000,  loss: 0.357, test accuracy: 0.860
# Epoch: 226/1000,  loss: 0.365, test accuracy: 0.850
# Epoch: 227/1000,  loss: 0.374, test accuracy: 0.860
# Epoch: 228/1000,  loss: 0.369, test accuracy: 0.890
# Epoch: 229/1000,  loss: 0.380, test accuracy: 0.850
# Epoch: 230/1000,  loss: 0.380, test accuracy: 0.880
# Epoch: 231/1000,  loss: 0.353, test accuracy: 0.840
# Epoch: 232/1000,  loss: 0.351, test accuracy: 0.880
# Epoch: 233/1000,  loss: 0.396, test accuracy: 0.880
# Epoch: 234/1000,  loss: 0.370, test accuracy: 0.870
# Epoch: 235/1000,  loss: 0.376, test accuracy: 0.880
# Epoch: 236/1000,  loss: 0.356, test accuracy: 0.850
# Epoch: 237/1000,  loss: 0.335, test accuracy: 0.850
# Epoch: 238/1000,  loss: 0.374, test accuracy: 0.870
# Epoch: 239/1000,  loss: 0.353, test accuracy: 0.870
# Epoch: 240/1000,  loss: 0.357, test accuracy: 0.870
# Epoch: 241/1000,  loss: 0.354, test accuracy: 0.870
# Epoch: 242/1000,  loss: 0.367, test accuracy: 0.900
# Epoch: 243/1000,  loss: 0.356, test accuracy: 0.870
# Epoch: 244/1000,  loss: 0.365, test accuracy: 0.890
# Epoch: 245/1000,  loss: 0.378, test accuracy: 0.880
# Epoch: 246/1000,  loss: 0.380, test accuracy: 0.820
# Epoch: 247/1000,  loss: 0.367, test accuracy: 0.890
# Epoch: 248/1000,  loss: 0.339, test accuracy: 0.830
# Epoch: 249/1000,  loss: 0.380, test accuracy: 0.860
# Epoch: 250/1000,  loss: 0.378, test accuracy: 0.880
# Epoch: 251/1000,  loss: 0.352, test accuracy: 0.830
# Epoch: 252/1000,  loss: 0.372, test accuracy: 0.870
# Epoch: 253/1000,  loss: 0.390, test accuracy: 0.900
# Epoch: 254/1000,  loss: 0.370, test accuracy: 0.850
# Epoch: 255/1000,  loss: 0.353, test accuracy: 0.860
# Epoch: 256/1000,  loss: 0.347, test accuracy: 0.870
# Epoch: 257/1000,  loss: 0.356, test accuracy: 0.830
# Epoch: 258/1000,  loss: 0.357, test accuracy: 0.910
# Epoch: 259/1000,  loss: 0.390, test accuracy: 0.860
# Epoch: 260/1000,  loss: 0.363, test accuracy: 0.870
# Epoch: 261/1000,  loss: 0.365, test accuracy: 0.820
# Epoch: 262/1000,  loss: 0.360, test accuracy: 0.890
# Epoch: 263/1000,  loss: 0.371, test accuracy: 0.850
# Epoch: 264/1000,  loss: 0.362, test accuracy: 0.880
# Epoch: 265/1000,  loss: 0.364, test accuracy: 0.870
# Epoch: 266/1000,  loss: 0.370, test accuracy: 0.860
# Epoch: 267/1000,  loss: 0.348, test accuracy: 0.880
# Epoch: 268/1000,  loss: 0.358, test accuracy: 0.870
# Epoch: 269/1000,  loss: 0.359, test accuracy: 0.890
# Epoch: 270/1000,  loss: 0.346, test accuracy: 0.890
# Epoch: 271/1000,  loss: 0.362, test accuracy: 0.840
# Epoch: 272/1000,  loss: 0.355, test accuracy: 0.870
# Epoch: 273/1000,  loss: 0.367, test accuracy: 0.870
# Epoch: 274/1000,  loss: 0.370, test accuracy: 0.840
# Epoch: 275/1000,  loss: 0.367, test accuracy: 0.870
# Epoch: 276/1000,  loss: 0.351, test accuracy: 0.830
# Epoch: 277/1000,  loss: 0.371, test accuracy: 0.860
# Epoch: 278/1000,  loss: 0.374, test accuracy: 0.900
# Epoch: 279/1000,  loss: 0.352, test accuracy: 0.830
# Epoch: 280/1000,  loss: 0.380, test accuracy: 0.880
# Epoch: 281/1000,  loss: 0.348, test accuracy: 0.890
# Epoch: 282/1000,  loss: 0.353, test accuracy: 0.840
# Epoch: 283/1000,  loss: 0.364, test accuracy: 0.860
# Epoch: 284/1000,  loss: 0.353, test accuracy: 0.880
# Epoch: 285/1000,  loss: 0.344, test accuracy: 0.830
# Epoch: 286/1000,  loss: 0.369, test accuracy: 0.880
# Epoch: 287/1000,  loss: 0.366, test accuracy: 0.870
# Epoch: 288/1000,  loss: 0.367, test accuracy: 0.860
# Epoch: 289/1000,  loss: 0.356, test accuracy: 0.880
# Epoch: 290/1000,  loss: 0.352, test accuracy: 0.880
# Epoch: 291/1000,  loss: 0.379, test accuracy: 0.880
# Epoch: 292/1000,  loss: 0.360, test accuracy: 0.850
# Epoch: 293/1000,  loss: 0.354, test accuracy: 0.880
# Epoch: 294/1000,  loss: 0.368, test accuracy: 0.890
# Epoch: 295/1000,  loss: 0.359, test accuracy: 0.880
# Epoch: 296/1000,  loss: 0.375, test accuracy: 0.820
# Epoch: 297/1000,  loss: 0.351, test accuracy: 0.880
# Epoch: 298/1000,  loss: 0.376, test accuracy: 0.870
# Epoch: 299/1000,  loss: 0.345, test accuracy: 0.840
# Epoch: 300/1000,  loss: 0.354, test accuracy: 0.870
# Epoch: 301/1000,  loss: 0.357, test accuracy: 0.890
# Epoch: 302/1000,  loss: 0.358, test accuracy: 0.830
# Epoch: 303/1000,  loss: 0.367, test accuracy: 0.880
# Epoch: 304/1000,  loss: 0.359, test accuracy: 0.880
# Epoch: 305/1000,  loss: 0.360, test accuracy: 0.870
# Epoch: 306/1000,  loss: 0.350, test accuracy: 0.830
# Epoch: 307/1000,  loss: 0.342, test accuracy: 0.860
# Epoch: 308/1000,  loss: 0.391, test accuracy: 0.880
# Epoch: 309/1000,  loss: 0.376, test accuracy: 0.860
# Epoch: 310/1000,  loss: 0.375, test accuracy: 0.850
# Epoch: 311/1000,  loss: 0.378, test accuracy: 0.850
# Epoch: 312/1000,  loss: 0.344, test accuracy: 0.860
# Epoch: 313/1000,  loss: 0.346, test accuracy: 0.870
# Epoch: 314/1000,  loss: 0.344, test accuracy: 0.850
# Epoch: 315/1000,  loss: 0.361, test accuracy: 0.880
# Epoch: 316/1000,  loss: 0.362, test accuracy: 0.830
# Epoch: 317/1000,  loss: 0.361, test accuracy: 0.890
# Epoch: 318/1000,  loss: 0.352, test accuracy: 0.860
# Epoch: 319/1000,  loss: 0.354, test accuracy: 0.870
# Epoch: 320/1000,  loss: 0.345, test accuracy: 0.860
# Epoch: 321/1000,  loss: 0.356, test accuracy: 0.870
# Epoch: 322/1000,  loss: 0.386, test accuracy: 0.850
# Epoch: 323/1000,  loss: 0.349, test accuracy: 0.870
# Epoch: 324/1000,  loss: 0.363, test accuracy: 0.870
# Epoch: 325/1000,  loss: 0.355, test accuracy: 0.880
# Epoch: 326/1000,  loss: 0.364, test accuracy: 0.880
# Epoch: 327/1000,  loss: 0.359, test accuracy: 0.860
# Epoch: 328/1000,  loss: 0.357, test accuracy: 0.870
# Epoch: 329/1000,  loss: 0.360, test accuracy: 0.860
# Epoch: 330/1000,  loss: 0.345, test accuracy: 0.880
# Epoch: 331/1000,  loss: 0.351, test accuracy: 0.850
# Epoch: 332/1000,  loss: 0.351, test accuracy: 0.900
# Epoch: 333/1000,  loss: 0.342, test accuracy: 0.850
# Epoch: 334/1000,  loss: 0.335, test accuracy: 0.840
# Epoch: 335/1000,  loss: 0.352, test accuracy: 0.880
# Epoch: 336/1000,  loss: 0.344, test accuracy: 0.860
# Epoch: 337/1000,  loss: 0.351, test accuracy: 0.870
# Epoch: 338/1000,  loss: 0.348, test accuracy: 0.850
# Epoch: 339/1000,  loss: 0.357, test accuracy: 0.890
# Epoch: 340/1000,  loss: 0.339, test accuracy: 0.840
# Epoch: 341/1000,  loss: 0.349, test accuracy: 0.870
# Epoch: 342/1000,  loss: 0.336, test accuracy: 0.880
# Epoch: 343/1000,  loss: 0.353, test accuracy: 0.880
# Epoch: 344/1000,  loss: 0.353, test accuracy: 0.850
# Epoch: 345/1000,  loss: 0.365, test accuracy: 0.870
# Epoch: 346/1000,  loss: 0.384, test accuracy: 0.850
# Epoch: 347/1000,  loss: 0.379, test accuracy: 0.870
# Epoch: 348/1000,  loss: 0.381, test accuracy: 0.850
# Epoch: 349/1000,  loss: 0.352, test accuracy: 0.880
# Epoch: 350/1000,  loss: 0.354, test accuracy: 0.860
# Epoch: 351/1000,  loss: 0.362, test accuracy: 0.870
# Epoch: 352/1000,  loss: 0.351, test accuracy: 0.860
# Epoch: 353/1000,  loss: 0.338, test accuracy: 0.880
# Epoch: 354/1000,  loss: 0.386, test accuracy: 0.860
# Epoch: 355/1000,  loss: 0.383, test accuracy: 0.880
# Epoch: 356/1000,  loss: 0.377, test accuracy: 0.880
# Epoch: 357/1000,  loss: 0.374, test accuracy: 0.850
# Epoch: 358/1000,  loss: 0.359, test accuracy: 0.850
# Epoch: 359/1000,  loss: 0.346, test accuracy: 0.880
# Epoch: 360/1000,  loss: 0.375, test accuracy: 0.860
# Epoch: 361/1000,  loss: 0.345, test accuracy: 0.900
# Epoch: 362/1000,  loss: 0.363, test accuracy: 0.820
# Epoch: 363/1000,  loss: 0.349, test accuracy: 0.890
# Epoch: 364/1000,  loss: 0.362, test accuracy: 0.860
# Epoch: 365/1000,  loss: 0.352, test accuracy: 0.880
# Epoch: 366/1000,  loss: 0.366, test accuracy: 0.840
# Epoch: 367/1000,  loss: 0.362, test accuracy: 0.890
# Epoch: 368/1000,  loss: 0.349, test accuracy: 0.830
# Epoch: 369/1000,  loss: 0.345, test accuracy: 0.880
# Epoch: 370/1000,  loss: 0.338, test accuracy: 0.850
# Epoch: 371/1000,  loss: 0.342, test accuracy: 0.850
# Epoch: 372/1000,  loss: 0.337, test accuracy: 0.880
# Epoch: 373/1000,  loss: 0.365, test accuracy: 0.850
# Epoch: 374/1000,  loss: 0.348, test accuracy: 0.890
# Epoch: 375/1000,  loss: 0.357, test accuracy: 0.870
# Epoch: 376/1000,  loss: 0.356, test accuracy: 0.890
# Epoch: 377/1000,  loss: 0.360, test accuracy: 0.860
# Epoch: 378/1000,  loss: 0.353, test accuracy: 0.840
# Epoch: 379/1000,  loss: 0.345, test accuracy: 0.870
# Epoch: 380/1000,  loss: 0.354, test accuracy: 0.870
# Epoch: 381/1000,  loss: 0.352, test accuracy: 0.860
# Epoch: 382/1000,  loss: 0.355, test accuracy: 0.880
# Epoch: 383/1000,  loss: 0.356, test accuracy: 0.890
# Epoch: 384/1000,  loss: 0.345, test accuracy: 0.880
# Epoch: 385/1000,  loss: 0.345, test accuracy: 0.840
# Epoch: 386/1000,  loss: 0.361, test accuracy: 0.880
# Epoch: 387/1000,  loss: 0.345, test accuracy: 0.850
# Epoch: 388/1000,  loss: 0.345, test accuracy: 0.880
# Epoch: 389/1000,  loss: 0.328, test accuracy: 0.850
# Epoch: 390/1000,  loss: 0.358, test accuracy: 0.890
# Epoch: 391/1000,  loss: 0.345, test accuracy: 0.860
# Epoch: 392/1000,  loss: 0.342, test accuracy: 0.830
# Epoch: 393/1000,  loss: 0.355, test accuracy: 0.870
# Epoch: 394/1000,  loss: 0.352, test accuracy: 0.860
# Epoch: 395/1000,  loss: 0.337, test accuracy: 0.850
# Epoch: 396/1000,  loss: 0.337, test accuracy: 0.850
# Epoch: 397/1000,  loss: 0.348, test accuracy: 0.880
# Epoch: 398/1000,  loss: 0.365, test accuracy: 0.840
# Epoch: 399/1000,  loss: 0.360, test accuracy: 0.870
# Epoch: 400/1000,  loss: 0.373, test accuracy: 0.860
# Epoch: 401/1000,  loss: 0.350, test accuracy: 0.890
# Epoch: 402/1000,  loss: 0.345, test accuracy: 0.840
# Epoch: 403/1000,  loss: 0.355, test accuracy: 0.870
# Epoch: 404/1000,  loss: 0.356, test accuracy: 0.840
# Epoch: 405/1000,  loss: 0.356, test accuracy: 0.850
# Epoch: 406/1000,  loss: 0.370, test accuracy: 0.900
# Epoch: 407/1000,  loss: 0.361, test accuracy: 0.830
# Epoch: 408/1000,  loss: 0.350, test accuracy: 0.890
# Epoch: 409/1000,  loss: 0.373, test accuracy: 0.830
# Epoch: 410/1000,  loss: 0.377, test accuracy: 0.880
# Epoch: 411/1000,  loss: 0.352, test accuracy: 0.910
# Epoch: 412/1000,  loss: 0.392, test accuracy: 0.850
# Epoch: 413/1000,  loss: 0.358, test accuracy: 0.890
# Epoch: 414/1000,  loss: 0.363, test accuracy: 0.830
# Epoch: 415/1000,  loss: 0.387, test accuracy: 0.880
# Epoch: 416/1000,  loss: 0.394, test accuracy: 0.850
# Epoch: 417/1000,  loss: 0.366, test accuracy: 0.830
# Epoch: 418/1000,  loss: 0.367, test accuracy: 0.880
# Epoch: 419/1000,  loss: 0.375, test accuracy: 0.870
# Epoch: 420/1000,  loss: 0.371, test accuracy: 0.850
# Epoch: 421/1000,  loss: 0.380, test accuracy: 0.860
# Epoch: 422/1000,  loss: 0.363, test accuracy: 0.840
# Epoch: 423/1000,  loss: 0.355, test accuracy: 0.880
# Epoch: 424/1000,  loss: 0.350, test accuracy: 0.840
# Epoch: 425/1000,  loss: 0.346, test accuracy: 0.900
# Epoch: 426/1000,  loss: 0.380, test accuracy: 0.860
# Epoch: 427/1000,  loss: 0.335, test accuracy: 0.860
# Epoch: 428/1000,  loss: 0.342, test accuracy: 0.870
# Epoch: 429/1000,  loss: 0.348, test accuracy: 0.880
# Epoch: 430/1000,  loss: 0.345, test accuracy: 0.880
# Epoch: 431/1000,  loss: 0.352, test accuracy: 0.830
# Epoch: 432/1000,  loss: 0.354, test accuracy: 0.900
# Epoch: 433/1000,  loss: 0.346, test accuracy: 0.830
# Epoch: 434/1000,  loss: 0.357, test accuracy: 0.880
# Epoch: 435/1000,  loss: 0.391, test accuracy: 0.860
# Epoch: 436/1000,  loss: 0.349, test accuracy: 0.870
# Epoch: 437/1000,  loss: 0.340, test accuracy: 0.850
# Epoch: 438/1000,  loss: 0.355, test accuracy: 0.880
# Epoch: 439/1000,  loss: 0.363, test accuracy: 0.880
# Epoch: 440/1000,  loss: 0.342, test accuracy: 0.880
# Epoch: 441/1000,  loss: 0.356, test accuracy: 0.880
# Epoch: 442/1000,  loss: 0.361, test accuracy: 0.830
# Epoch: 443/1000,  loss: 0.354, test accuracy: 0.900
# Epoch: 444/1000,  loss: 0.349, test accuracy: 0.830
# Epoch: 445/1000,  loss: 0.356, test accuracy: 0.880
# Epoch: 446/1000,  loss: 0.351, test accuracy: 0.870
# Epoch: 447/1000,  loss: 0.345, test accuracy: 0.840
# Epoch: 448/1000,  loss: 0.362, test accuracy: 0.840
# Epoch: 449/1000,  loss: 0.355, test accuracy: 0.850
# Epoch: 450/1000,  loss: 0.374, test accuracy: 0.870
# Epoch: 451/1000,  loss: 0.360, test accuracy: 0.870
# Epoch: 452/1000,  loss: 0.349, test accuracy: 0.840
# Epoch: 453/1000,  loss: 0.344, test accuracy: 0.880
# Epoch: 454/1000,  loss: 0.350, test accuracy: 0.860
# Epoch: 455/1000,  loss: 0.337, test accuracy: 0.840
# Epoch: 456/1000,  loss: 0.374, test accuracy: 0.860
# Epoch: 457/1000,  loss: 0.371, test accuracy: 0.890
# Epoch: 458/1000,  loss: 0.363, test accuracy: 0.870
# Epoch: 459/1000,  loss: 0.367, test accuracy: 0.860
# Epoch: 460/1000,  loss: 0.372, test accuracy: 0.870
# Epoch: 461/1000,  loss: 0.350, test accuracy: 0.870
# Epoch: 462/1000,  loss: 0.350, test accuracy: 0.830
# Epoch: 463/1000,  loss: 0.360, test accuracy: 0.890
# Epoch: 464/1000,  loss: 0.344, test accuracy: 0.880
# Epoch: 465/1000,  loss: 0.350, test accuracy: 0.860
# Epoch: 466/1000,  loss: 0.355, test accuracy: 0.880
# Epoch: 467/1000,  loss: 0.375, test accuracy: 0.860
# Epoch: 468/1000,  loss: 0.347, test accuracy: 0.890
# Epoch: 469/1000,  loss: 0.367, test accuracy: 0.860
# Epoch: 470/1000,  loss: 0.360, test accuracy: 0.870
# Epoch: 471/1000,  loss: 0.359, test accuracy: 0.850
# Epoch: 472/1000,  loss: 0.369, test accuracy: 0.880
# Epoch: 473/1000,  loss: 0.354, test accuracy: 0.850
# Epoch: 474/1000,  loss: 0.377, test accuracy: 0.880
# Epoch: 475/1000,  loss: 0.340, test accuracy: 0.840
# Epoch: 476/1000,  loss: 0.383, test accuracy: 0.880
# Epoch: 477/1000,  loss: 0.406, test accuracy: 0.890
# Epoch: 478/1000,  loss: 0.366, test accuracy: 0.850
# Epoch: 479/1000,  loss: 0.377, test accuracy: 0.870
# Epoch: 480/1000,  loss: 0.370, test accuracy: 0.840
# Epoch: 481/1000,  loss: 0.352, test accuracy: 0.870
# Epoch: 482/1000,  loss: 0.351, test accuracy: 0.850
# Epoch: 483/1000,  loss: 0.355, test accuracy: 0.880
# Epoch: 484/1000,  loss: 0.340, test accuracy: 0.840
# Epoch: 485/1000,  loss: 0.359, test accuracy: 0.880
# Epoch: 486/1000,  loss: 0.348, test accuracy: 0.870
# Epoch: 487/1000,  loss: 0.349, test accuracy: 0.840
# Epoch: 488/1000,  loss: 0.360, test accuracy: 0.880
# Epoch: 489/1000,  loss: 0.362, test accuracy: 0.880
# Epoch: 490/1000,  loss: 0.354, test accuracy: 0.850
# Epoch: 491/1000,  loss: 0.370, test accuracy: 0.880
# Epoch: 492/1000,  loss: 0.375, test accuracy: 0.850
# Epoch: 493/1000,  loss: 0.386, test accuracy: 0.880
# Epoch: 494/1000,  loss: 0.368, test accuracy: 0.870
# Epoch: 495/1000,  loss: 0.342, test accuracy: 0.830
# Epoch: 496/1000,  loss: 0.365, test accuracy: 0.850
# Epoch: 497/1000,  loss: 0.354, test accuracy: 0.870
# Epoch: 498/1000,  loss: 0.348, test accuracy: 0.850
# Epoch: 499/1000,  loss: 0.350, test accuracy: 0.850
# Epoch: 500/1000,  loss: 0.338, test accuracy: 0.900
# Epoch: 501/1000,  loss: 0.352, test accuracy: 0.850
# Epoch: 502/1000,  loss: 0.349, test accuracy: 0.850
# Epoch: 503/1000,  loss: 0.344, test accuracy: 0.880
# Epoch: 504/1000,  loss: 0.355, test accuracy: 0.860
# Epoch: 505/1000,  loss: 0.351, test accuracy: 0.850
# Epoch: 506/1000,  loss: 0.362, test accuracy: 0.870
# Epoch: 507/1000,  loss: 0.343, test accuracy: 0.860
# Epoch: 508/1000,  loss: 0.356, test accuracy: 0.850
# Epoch: 509/1000,  loss: 0.353, test accuracy: 0.830
# Epoch: 510/1000,  loss: 0.352, test accuracy: 0.870
# Epoch: 511/1000,  loss: 0.373, test accuracy: 0.870
# Epoch: 512/1000,  loss: 0.359, test accuracy: 0.900
# Epoch: 513/1000,  loss: 0.363, test accuracy: 0.850
# Epoch: 514/1000,  loss: 0.359, test accuracy: 0.890
# Epoch: 515/1000,  loss: 0.362, test accuracy: 0.830
# Epoch: 516/1000,  loss: 0.361, test accuracy: 0.830
# Epoch: 517/1000,  loss: 0.346, test accuracy: 0.890
# Epoch: 518/1000,  loss: 0.342, test accuracy: 0.860
# Epoch: 519/1000,  loss: 0.355, test accuracy: 0.850
# Epoch: 520/1000,  loss: 0.368, test accuracy: 0.870
# Epoch: 521/1000,  loss: 0.338, test accuracy: 0.860
# Epoch: 522/1000,  loss: 0.352, test accuracy: 0.850
# Epoch: 523/1000,  loss: 0.338, test accuracy: 0.870
# Epoch: 524/1000,  loss: 0.347, test accuracy: 0.850
# Epoch: 525/1000,  loss: 0.349, test accuracy: 0.860
# Epoch: 526/1000,  loss: 0.347, test accuracy: 0.870
# Epoch: 527/1000,  loss: 0.344, test accuracy: 0.840
# Epoch: 528/1000,  loss: 0.377, test accuracy: 0.880
# Epoch: 529/1000,  loss: 0.388, test accuracy: 0.860
# Epoch: 530/1000,  loss: 0.378, test accuracy: 0.880
# Epoch: 531/1000,  loss: 0.368, test accuracy: 0.860
# Epoch: 532/1000,  loss: 0.344, test accuracy: 0.830
# Epoch: 533/1000,  loss: 0.348, test accuracy: 0.850
# Epoch: 534/1000,  loss: 0.347, test accuracy: 0.840
# Epoch: 535/1000,  loss: 0.362, test accuracy: 0.840
# Epoch: 536/1000,  loss: 0.347, test accuracy: 0.900
# Epoch: 537/1000,  loss: 0.350, test accuracy: 0.850
# Epoch: 538/1000,  loss: 0.343, test accuracy: 0.830
# Epoch: 539/1000,  loss: 0.362, test accuracy: 0.900
# Epoch: 540/1000,  loss: 0.346, test accuracy: 0.840
# Epoch: 541/1000,  loss: 0.350, test accuracy: 0.880
# Epoch: 542/1000,  loss: 0.330, test accuracy: 0.870
# Epoch: 543/1000,  loss: 0.352, test accuracy: 0.860
# Epoch: 544/1000,  loss: 0.337, test accuracy: 0.880
# Epoch: 545/1000,  loss: 0.337, test accuracy: 0.880
# Epoch: 546/1000,  loss: 0.352, test accuracy: 0.850
# Epoch: 547/1000,  loss: 0.370, test accuracy: 0.880
# Epoch: 548/1000,  loss: 0.348, test accuracy: 0.830
# Epoch: 549/1000,  loss: 0.354, test accuracy: 0.900
# Epoch: 550/1000,  loss: 0.354, test accuracy: 0.840
# Epoch: 551/1000,  loss: 0.346, test accuracy: 0.880
# Epoch: 552/1000,  loss: 0.346, test accuracy: 0.870
# Epoch: 553/1000,  loss: 0.357, test accuracy: 0.860
# Epoch: 554/1000,  loss: 0.355, test accuracy: 0.860
# Epoch: 555/1000,  loss: 0.348, test accuracy: 0.880
# Epoch: 556/1000,  loss: 0.339, test accuracy: 0.840
# Epoch: 557/1000,  loss: 0.339, test accuracy: 0.890
# Epoch: 558/1000,  loss: 0.338, test accuracy: 0.860
# Epoch: 559/1000,  loss: 0.345, test accuracy: 0.880
# Epoch: 560/1000,  loss: 0.345, test accuracy: 0.840
# Epoch: 561/1000,  loss: 0.338, test accuracy: 0.870
# Epoch: 562/1000,  loss: 0.330, test accuracy: 0.850
# Epoch: 563/1000,  loss: 0.323, test accuracy: 0.880
# Epoch: 564/1000,  loss: 0.368, test accuracy: 0.860
# Epoch: 565/1000,  loss: 0.407, test accuracy: 0.900
# Epoch: 566/1000,  loss: 0.372, test accuracy: 0.840
# Epoch: 567/1000,  loss: 0.360, test accuracy: 0.890
# Epoch: 568/1000,  loss: 0.358, test accuracy: 0.850
# Epoch: 569/1000,  loss: 0.379, test accuracy: 0.890
# Epoch: 570/1000,  loss: 0.362, test accuracy: 0.860
# Epoch: 571/1000,  loss: 0.359, test accuracy: 0.880
# Epoch: 572/1000,  loss: 0.351, test accuracy: 0.860
# Epoch: 573/1000,  loss: 0.339, test accuracy: 0.870
# Epoch: 574/1000,  loss: 0.343, test accuracy: 0.880
# Epoch: 575/1000,  loss: 0.346, test accuracy: 0.870
# Epoch: 576/1000,  loss: 0.345, test accuracy: 0.880
# Epoch: 577/1000,  loss: 0.336, test accuracy: 0.890
# Epoch: 578/1000,  loss: 0.352, test accuracy: 0.840
# Epoch: 579/1000,  loss: 0.358, test accuracy: 0.880
# Epoch: 580/1000,  loss: 0.368, test accuracy: 0.870
# Epoch: 581/1000,  loss: 0.335, test accuracy: 0.870
# Epoch: 582/1000,  loss: 0.340, test accuracy: 0.850
# Epoch: 583/1000,  loss: 0.346, test accuracy: 0.840
# Epoch: 584/1000,  loss: 0.343, test accuracy: 0.890
# Epoch: 585/1000,  loss: 0.335, test accuracy: 0.870
# Epoch: 586/1000,  loss: 0.351, test accuracy: 0.840
# Epoch: 587/1000,  loss: 0.349, test accuracy: 0.830
# Epoch: 588/1000,  loss: 0.361, test accuracy: 0.900
# Epoch: 589/1000,  loss: 0.345, test accuracy: 0.840
# Epoch: 590/1000,  loss: 0.369, test accuracy: 0.880
# Epoch: 591/1000,  loss: 0.371, test accuracy: 0.880
# Epoch: 592/1000,  loss: 0.356, test accuracy: 0.870
# Epoch: 593/1000,  loss: 0.343, test accuracy: 0.840
# Epoch: 594/1000,  loss: 0.353, test accuracy: 0.880
# Epoch: 595/1000,  loss: 0.361, test accuracy: 0.870
# Epoch: 596/1000,  loss: 0.360, test accuracy: 0.880
# Epoch: 597/1000,  loss: 0.335, test accuracy: 0.880
# Epoch: 598/1000,  loss: 0.354, test accuracy: 0.840
# Epoch: 599/1000,  loss: 0.350, test accuracy: 0.860
# Epoch: 600/1000,  loss: 0.371, test accuracy: 0.880
# Epoch: 601/1000,  loss: 0.366, test accuracy: 0.850
# Epoch: 602/1000,  loss: 0.367, test accuracy: 0.880
# Epoch: 603/1000,  loss: 0.346, test accuracy: 0.870
# Epoch: 604/1000,  loss: 0.338, test accuracy: 0.910
# Epoch: 605/1000,  loss: 0.386, test accuracy: 0.840
# Epoch: 606/1000,  loss: 0.342, test accuracy: 0.870
# Epoch: 607/1000,  loss: 0.348, test accuracy: 0.850
# Epoch: 608/1000,  loss: 0.351, test accuracy: 0.860
# Epoch: 609/1000,  loss: 0.361, test accuracy: 0.890
# Epoch: 610/1000,  loss: 0.344, test accuracy: 0.860
# Epoch: 611/1000,  loss: 0.342, test accuracy: 0.880
# Epoch: 612/1000,  loss: 0.359, test accuracy: 0.880
# Epoch: 613/1000,  loss: 0.356, test accuracy: 0.820
# Epoch: 614/1000,  loss: 0.347, test accuracy: 0.900
# Epoch: 615/1000,  loss: 0.371, test accuracy: 0.890
# Epoch: 616/1000,  loss: 0.373, test accuracy: 0.820
# Epoch: 617/1000,  loss: 0.375, test accuracy: 0.900
# Epoch: 618/1000,  loss: 0.346, test accuracy: 0.870
# Epoch: 619/1000,  loss: 0.347, test accuracy: 0.840
# Epoch: 620/1000,  loss: 0.346, test accuracy: 0.890
# Epoch: 621/1000,  loss: 0.346, test accuracy: 0.860
# Epoch: 622/1000,  loss: 0.345, test accuracy: 0.870
# Epoch: 623/1000,  loss: 0.336, test accuracy: 0.870
# Epoch: 624/1000,  loss: 0.354, test accuracy: 0.830
# Epoch: 625/1000,  loss: 0.347, test accuracy: 0.870
# Epoch: 626/1000,  loss: 0.409, test accuracy: 0.850
# Epoch: 627/1000,  loss: 0.382, test accuracy: 0.880
# Epoch: 628/1000,  loss: 0.383, test accuracy: 0.880
# Epoch: 629/1000,  loss: 0.366, test accuracy: 0.890
# Epoch: 630/1000,  loss: 0.358, test accuracy: 0.840
# Epoch: 631/1000,  loss: 0.355, test accuracy: 0.850
# Epoch: 632/1000,  loss: 0.359, test accuracy: 0.870
# Epoch: 633/1000,  loss: 0.357, test accuracy: 0.850
# Epoch: 634/1000,  loss: 0.354, test accuracy: 0.870
# Epoch: 635/1000,  loss: 0.367, test accuracy: 0.830
# Epoch: 636/1000,  loss: 0.352, test accuracy: 0.900
# Epoch: 637/1000,  loss: 0.370, test accuracy: 0.830
# Epoch: 638/1000,  loss: 0.352, test accuracy: 0.870
# Epoch: 639/1000,  loss: 0.343, test accuracy: 0.860
# Epoch: 640/1000,  loss: 0.361, test accuracy: 0.860
# Epoch: 641/1000,  loss: 0.342, test accuracy: 0.880
# Epoch: 642/1000,  loss: 0.340, test accuracy: 0.870
# Epoch: 643/1000,  loss: 0.359, test accuracy: 0.860
# Epoch: 644/1000,  loss: 0.350, test accuracy: 0.890
# Epoch: 645/1000,  loss: 0.346, test accuracy: 0.870
# Epoch: 646/1000,  loss: 0.361, test accuracy: 0.840
# Epoch: 647/1000,  loss: 0.363, test accuracy: 0.900
# Epoch: 648/1000,  loss: 0.365, test accuracy: 0.870
# Epoch: 649/1000,  loss: 0.359, test accuracy: 0.860
# Epoch: 650/1000,  loss: 0.333, test accuracy: 0.880
# Epoch: 651/1000,  loss: 0.336, test accuracy: 0.860
# Epoch: 652/1000,  loss: 0.340, test accuracy: 0.870
# Epoch: 653/1000,  loss: 0.345, test accuracy: 0.880
# Epoch: 654/1000,  loss: 0.352, test accuracy: 0.840
# Epoch: 655/1000,  loss: 0.368, test accuracy: 0.880
# Epoch: 656/1000,  loss: 0.350, test accuracy: 0.840
# Epoch: 657/1000,  loss: 0.368, test accuracy: 0.870
# Epoch: 658/1000,  loss: 0.357, test accuracy: 0.870
# Epoch: 659/1000,  loss: 0.357, test accuracy: 0.830
# Epoch: 660/1000,  loss: 0.361, test accuracy: 0.900
# Epoch: 661/1000,  loss: 0.334, test accuracy: 0.860
# Epoch: 662/1000,  loss: 0.364, test accuracy: 0.860
# Epoch: 663/1000,  loss: 0.354, test accuracy: 0.880
# Epoch: 664/1000,  loss: 0.347, test accuracy: 0.860
# Epoch: 665/1000,  loss: 0.354, test accuracy: 0.860
# Epoch: 666/1000,  loss: 0.379, test accuracy: 0.850
# Epoch: 667/1000,  loss: 0.358, test accuracy: 0.830
# Epoch: 668/1000,  loss: 0.375, test accuracy: 0.880
# Epoch: 669/1000,  loss: 0.356, test accuracy: 0.860
# Epoch: 670/1000,  loss: 0.345, test accuracy: 0.860
# Epoch: 671/1000,  loss: 0.354, test accuracy: 0.880
# Epoch: 672/1000,  loss: 0.364, test accuracy: 0.870
# Epoch: 673/1000,  loss: 0.351, test accuracy: 0.850
# Epoch: 674/1000,  loss: 0.385, test accuracy: 0.870
# Epoch: 675/1000,  loss: 0.365, test accuracy: 0.890
# Epoch: 676/1000,  loss: 0.374, test accuracy: 0.880
# Epoch: 677/1000,  loss: 0.366, test accuracy: 0.850
# Epoch: 678/1000,  loss: 0.344, test accuracy: 0.880
# Epoch: 679/1000,  loss: 0.348, test accuracy: 0.870
# Epoch: 680/1000,  loss: 0.345, test accuracy: 0.870
# Epoch: 681/1000,  loss: 0.334, test accuracy: 0.880
# Epoch: 682/1000,  loss: 0.355, test accuracy: 0.880
# Epoch: 683/1000,  loss: 0.350, test accuracy: 0.900
# Epoch: 684/1000,  loss: 0.360, test accuracy: 0.870
# Epoch: 685/1000,  loss: 0.359, test accuracy: 0.870
# Epoch: 686/1000,  loss: 0.337, test accuracy: 0.870
# Epoch: 687/1000,  loss: 0.352, test accuracy: 0.880
# Epoch: 688/1000,  loss: 0.356, test accuracy: 0.870
# Epoch: 689/1000,  loss: 0.340, test accuracy: 0.880
# Epoch: 690/1000,  loss: 0.363, test accuracy: 0.860
# Epoch: 691/1000,  loss: 0.357, test accuracy: 0.860
# Epoch: 692/1000,  loss: 0.342, test accuracy: 0.890
# Epoch: 693/1000,  loss: 0.360, test accuracy: 0.860
# Epoch: 694/1000,  loss: 0.362, test accuracy: 0.890
# Epoch: 695/1000,  loss: 0.330, test accuracy: 0.880
# Epoch: 696/1000,  loss: 0.356, test accuracy: 0.870
# Epoch: 697/1000,  loss: 0.344, test accuracy: 0.880
# Epoch: 698/1000,  loss: 0.350, test accuracy: 0.860
# Epoch: 699/1000,  loss: 0.361, test accuracy: 0.870
# Epoch: 700/1000,  loss: 0.344, test accuracy: 0.850
# Epoch: 701/1000,  loss: 0.386, test accuracy: 0.880
# Epoch: 702/1000,  loss: 0.385, test accuracy: 0.850
# Epoch: 703/1000,  loss: 0.377, test accuracy: 0.860
# Epoch: 704/1000,  loss: 0.373, test accuracy: 0.890
# Epoch: 705/1000,  loss: 0.342, test accuracy: 0.830
# Epoch: 706/1000,  loss: 0.352, test accuracy: 0.880
# Epoch: 707/1000,  loss: 0.344, test accuracy: 0.870
# Epoch: 708/1000,  loss: 0.352, test accuracy: 0.870
# Epoch: 709/1000,  loss: 0.368, test accuracy: 0.870
# Epoch: 710/1000,  loss: 0.390, test accuracy: 0.860
# Epoch: 711/1000,  loss: 0.366, test accuracy: 0.880
# Epoch: 712/1000,  loss: 0.364, test accuracy: 0.860
# Epoch: 713/1000,  loss: 0.347, test accuracy: 0.870
# Epoch: 714/1000,  loss: 0.354, test accuracy: 0.840
# Epoch: 715/1000,  loss: 0.347, test accuracy: 0.890
# Epoch: 716/1000,  loss: 0.362, test accuracy: 0.860
# Epoch: 717/1000,  loss: 0.335, test accuracy: 0.890
# Epoch: 718/1000,  loss: 0.354, test accuracy: 0.890
# Epoch: 719/1000,  loss: 0.344, test accuracy: 0.840
# Epoch: 720/1000,  loss: 0.344, test accuracy: 0.860
# Epoch: 721/1000,  loss: 0.373, test accuracy: 0.880
# Epoch: 722/1000,  loss: 0.342, test accuracy: 0.860
# Epoch: 723/1000,  loss: 0.337, test accuracy: 0.860
# Epoch: 724/1000,  loss: 0.343, test accuracy: 0.890
# Epoch: 725/1000,  loss: 0.350, test accuracy: 0.890
# Epoch: 726/1000,  loss: 0.360, test accuracy: 0.860
# Epoch: 727/1000,  loss: 0.349, test accuracy: 0.880
# Epoch: 728/1000,  loss: 0.339, test accuracy: 0.870
# Epoch: 729/1000,  loss: 0.348, test accuracy: 0.850
# Epoch: 730/1000,  loss: 0.345, test accuracy: 0.880
# Epoch: 731/1000,  loss: 0.351, test accuracy: 0.830
# Epoch: 732/1000,  loss: 0.353, test accuracy: 0.870
# Epoch: 733/1000,  loss: 0.359, test accuracy: 0.860
# Epoch: 734/1000,  loss: 0.358, test accuracy: 0.870
# Epoch: 735/1000,  loss: 0.338, test accuracy: 0.870
# Epoch: 736/1000,  loss: 0.383, test accuracy: 0.870
# Epoch: 737/1000,  loss: 0.364, test accuracy: 0.840
# Epoch: 738/1000,  loss: 0.365, test accuracy: 0.880
# Epoch: 739/1000,  loss: 0.339, test accuracy: 0.900
# Epoch: 740/1000,  loss: 0.364, test accuracy: 0.870
# Epoch: 741/1000,  loss: 0.358, test accuracy: 0.850
# Epoch: 742/1000,  loss: 0.352, test accuracy: 0.900
# Epoch: 743/1000,  loss: 0.351, test accuracy: 0.860
# Epoch: 744/1000,  loss: 0.350, test accuracy: 0.890
# Epoch: 745/1000,  loss: 0.333, test accuracy: 0.880
# Epoch: 746/1000,  loss: 0.337, test accuracy: 0.870
# Epoch: 747/1000,  loss: 0.343, test accuracy: 0.880
# Epoch: 748/1000,  loss: 0.364, test accuracy: 0.890
# Epoch: 749/1000,  loss: 0.356, test accuracy: 0.860
# Epoch: 750/1000,  loss: 0.346, test accuracy: 0.880
# Epoch: 751/1000,  loss: 0.370, test accuracy: 0.900
# Epoch: 752/1000,  loss: 0.363, test accuracy: 0.830
# Epoch: 753/1000,  loss: 0.377, test accuracy: 0.890
# Epoch: 754/1000,  loss: 0.375, test accuracy: 0.860
# Epoch: 755/1000,  loss: 0.357, test accuracy: 0.880
# Epoch: 756/1000,  loss: 0.352, test accuracy: 0.850
# Epoch: 757/1000,  loss: 0.392, test accuracy: 0.880
# Epoch: 758/1000,  loss: 0.405, test accuracy: 0.850
# Epoch: 759/1000,  loss: 0.388, test accuracy: 0.880
# Epoch: 760/1000,  loss: 0.401, test accuracy: 0.870
# Epoch: 761/1000,  loss: 0.344, test accuracy: 0.890
# Epoch: 762/1000,  loss: 0.370, test accuracy: 0.850
# Epoch: 763/1000,  loss: 0.349, test accuracy: 0.870
# Epoch: 764/1000,  loss: 0.345, test accuracy: 0.880
# Epoch: 765/1000,  loss: 0.341, test accuracy: 0.850
# Epoch: 766/1000,  loss: 0.336, test accuracy: 0.870
# Epoch: 767/1000,  loss: 0.352, test accuracy: 0.880
# Epoch: 768/1000,  loss: 0.336, test accuracy: 0.860
# Epoch: 769/1000,  loss: 0.327, test accuracy: 0.880
# Epoch: 770/1000,  loss: 0.345, test accuracy: 0.880
# Epoch: 771/1000,  loss: 0.352, test accuracy: 0.870
# Epoch: 772/1000,  loss: 0.336, test accuracy: 0.870
# Epoch: 773/1000,  loss: 0.339, test accuracy: 0.860
# Epoch: 774/1000,  loss: 0.336, test accuracy: 0.860
# Epoch: 775/1000,  loss: 0.333, test accuracy: 0.850
# Epoch: 776/1000,  loss: 0.340, test accuracy: 0.900
# Epoch: 777/1000,  loss: 0.350, test accuracy: 0.840
# Epoch: 778/1000,  loss: 0.363, test accuracy: 0.880
# Epoch: 779/1000,  loss: 0.354, test accuracy: 0.880
# Epoch: 780/1000,  loss: 0.327, test accuracy: 0.830
# Epoch: 781/1000,  loss: 0.382, test accuracy: 0.870
# Epoch: 782/1000,  loss: 0.396, test accuracy: 0.890
# Epoch: 783/1000,  loss: 0.355, test accuracy: 0.830
# Epoch: 784/1000,  loss: 0.359, test accuracy: 0.880
# Epoch: 785/1000,  loss: 0.364, test accuracy: 0.880
# Epoch: 786/1000,  loss: 0.346, test accuracy: 0.840
# Epoch: 787/1000,  loss: 0.352, test accuracy: 0.890
# Epoch: 788/1000,  loss: 0.357, test accuracy: 0.870
# Epoch: 789/1000,  loss: 0.356, test accuracy: 0.860
# Epoch: 790/1000,  loss: 0.352, test accuracy: 0.880
# Epoch: 791/1000,  loss: 0.356, test accuracy: 0.860
# Epoch: 792/1000,  loss: 0.357, test accuracy: 0.870
# Epoch: 793/1000,  loss: 0.341, test accuracy: 0.890
# Epoch: 794/1000,  loss: 0.364, test accuracy: 0.880
# Epoch: 795/1000,  loss: 0.340, test accuracy: 0.890
# Epoch: 796/1000,  loss: 0.346, test accuracy: 0.860
# Epoch: 797/1000,  loss: 0.338, test accuracy: 0.870
# Epoch: 798/1000,  loss: 0.357, test accuracy: 0.880
# Epoch: 799/1000,  loss: 0.344, test accuracy: 0.860
# Epoch: 800/1000,  loss: 0.344, test accuracy: 0.880
# Epoch: 801/1000,  loss: 0.358, test accuracy: 0.870
# Epoch: 802/1000,  loss: 0.353, test accuracy: 0.860
# Epoch: 803/1000,  loss: 0.353, test accuracy: 0.860
# Epoch: 804/1000,  loss: 0.337, test accuracy: 0.880
# Epoch: 805/1000,  loss: 0.345, test accuracy: 0.860
# Epoch: 806/1000,  loss: 0.333, test accuracy: 0.860
# Epoch: 807/1000,  loss: 0.342, test accuracy: 0.880
# Epoch: 808/1000,  loss: 0.344, test accuracy: 0.890
# Epoch: 809/1000,  loss: 0.353, test accuracy: 0.860
# Epoch: 810/1000,  loss: 0.347, test accuracy: 0.880
# Epoch: 811/1000,  loss: 0.358, test accuracy: 0.840
# Epoch: 812/1000,  loss: 0.356, test accuracy: 0.890
# Epoch: 813/1000,  loss: 0.384, test accuracy: 0.870
# Epoch: 814/1000,  loss: 0.360, test accuracy: 0.860
# Epoch: 815/1000,  loss: 0.360, test accuracy: 0.870
# Epoch: 816/1000,  loss: 0.353, test accuracy: 0.860
# Epoch: 817/1000,  loss: 0.383, test accuracy: 0.870
# Epoch: 818/1000,  loss: 0.423, test accuracy: 0.870
# Epoch: 819/1000,  loss: 0.415, test accuracy: 0.890
# Epoch: 820/1000,  loss: 0.373, test accuracy: 0.840
# Epoch: 821/1000,  loss: 0.388, test accuracy: 0.850
# Epoch: 822/1000,  loss: 0.365, test accuracy: 0.850
# Epoch: 823/1000,  loss: 0.349, test accuracy: 0.880
# Epoch: 824/1000,  loss: 0.345, test accuracy: 0.870
# Epoch: 825/1000,  loss: 0.353, test accuracy: 0.900
# Epoch: 826/1000,  loss: 0.347, test accuracy: 0.860
# Epoch: 827/1000,  loss: 0.337, test accuracy: 0.870
# Epoch: 828/1000,  loss: 0.369, test accuracy: 0.890
# Epoch: 829/1000,  loss: 0.339, test accuracy: 0.870
# Epoch: 830/1000,  loss: 0.353, test accuracy: 0.870
# Epoch: 831/1000,  loss: 0.332, test accuracy: 0.900
# Epoch: 832/1000,  loss: 0.333, test accuracy: 0.860
# Epoch: 833/1000,  loss: 0.345, test accuracy: 0.860
# Epoch: 834/1000,  loss: 0.365, test accuracy: 0.890
# Epoch: 835/1000,  loss: 0.352, test accuracy: 0.870
# Epoch: 836/1000,  loss: 0.344, test accuracy: 0.890
# Epoch: 837/1000,  loss: 0.344, test accuracy: 0.840
# Epoch: 838/1000,  loss: 0.351, test accuracy: 0.880
# Epoch: 839/1000,  loss: 0.336, test accuracy: 0.870
# Epoch: 840/1000,  loss: 0.338, test accuracy: 0.870
# Epoch: 841/1000,  loss: 0.340, test accuracy: 0.890
# Epoch: 842/1000,  loss: 0.365, test accuracy: 0.890
# Epoch: 843/1000,  loss: 0.349, test accuracy: 0.870
# Epoch: 844/1000,  loss: 0.337, test accuracy: 0.890
# Epoch: 845/1000,  loss: 0.335, test accuracy: 0.880
# Epoch: 846/1000,  loss: 0.328, test accuracy: 0.880
# Epoch: 847/1000,  loss: 0.334, test accuracy: 0.870
# Epoch: 848/1000,  loss: 0.332, test accuracy: 0.880
# Epoch: 849/1000,  loss: 0.355, test accuracy: 0.870
# Epoch: 850/1000,  loss: 0.332, test accuracy: 0.890
# Epoch: 851/1000,  loss: 0.349, test accuracy: 0.880
# Epoch: 852/1000,  loss: 0.348, test accuracy: 0.870
# Epoch: 853/1000,  loss: 0.350, test accuracy: 0.870
# Epoch: 854/1000,  loss: 0.335, test accuracy: 0.880
# Epoch: 855/1000,  loss: 0.351, test accuracy: 0.870
# Epoch: 856/1000,  loss: 0.344, test accuracy: 0.880
# Epoch: 857/1000,  loss: 0.342, test accuracy: 0.870
# Epoch: 858/1000,  loss: 0.354, test accuracy: 0.880
# Epoch: 859/1000,  loss: 0.336, test accuracy: 0.880
# Epoch: 860/1000,  loss: 0.366, test accuracy: 0.890
# Epoch: 861/1000,  loss: 0.337, test accuracy: 0.870
# Epoch: 862/1000,  loss: 0.354, test accuracy: 0.900
# Epoch: 863/1000,  loss: 0.368, test accuracy: 0.880
# Epoch: 864/1000,  loss: 0.335, test accuracy: 0.860
# Epoch: 865/1000,  loss: 0.346, test accuracy: 0.870
# Epoch: 866/1000,  loss: 0.354, test accuracy: 0.870
# Epoch: 867/1000,  loss: 0.359, test accuracy: 0.860
# Epoch: 868/1000,  loss: 0.350, test accuracy: 0.870
# Epoch: 869/1000,  loss: 0.340, test accuracy: 0.860
# Epoch: 870/1000,  loss: 0.345, test accuracy: 0.880
# Epoch: 871/1000,  loss: 0.338, test accuracy: 0.870
# Epoch: 872/1000,  loss: 0.346, test accuracy: 0.880
# Epoch: 873/1000,  loss: 0.349, test accuracy: 0.890
# Epoch: 874/1000,  loss: 0.337, test accuracy: 0.880
# Epoch: 875/1000,  loss: 0.353, test accuracy: 0.850
# Epoch: 876/1000,  loss: 0.342, test accuracy: 0.880
# Epoch: 877/1000,  loss: 0.343, test accuracy: 0.890
# Epoch: 878/1000,  loss: 0.335, test accuracy: 0.870
# Epoch: 879/1000,  loss: 0.341, test accuracy: 0.880
# Epoch: 880/1000,  loss: 0.344, test accuracy: 0.870
# Epoch: 881/1000,  loss: 0.339, test accuracy: 0.840
# Epoch: 882/1000,  loss: 0.343, test accuracy: 0.870
# Epoch: 883/1000,  loss: 0.367, test accuracy: 0.890
# Epoch: 884/1000,  loss: 0.346, test accuracy: 0.870
# Epoch: 885/1000,  loss: 0.339, test accuracy: 0.870
# Epoch: 886/1000,  loss: 0.345, test accuracy: 0.870
# Epoch: 887/1000,  loss: 0.377, test accuracy: 0.870
# Epoch: 888/1000,  loss: 0.363, test accuracy: 0.890
# Epoch: 889/1000,  loss: 0.347, test accuracy: 0.860
# Epoch: 890/1000,  loss: 0.371, test accuracy: 0.870
# Epoch: 891/1000,  loss: 0.343, test accuracy: 0.890
# Epoch: 892/1000,  loss: 0.344, test accuracy: 0.870
# Epoch: 893/1000,  loss: 0.366, test accuracy: 0.860
# Epoch: 894/1000,  loss: 0.347, test accuracy: 0.850
# Epoch: 895/1000,  loss: 0.352, test accuracy: 0.850
# Epoch: 896/1000,  loss: 0.351, test accuracy: 0.880
# Epoch: 897/1000,  loss: 0.384, test accuracy: 0.860
# Epoch: 898/1000,  loss: 0.344, test accuracy: 0.890
# Epoch: 899/1000,  loss: 0.339, test accuracy: 0.890
# Epoch: 900/1000,  loss: 0.350, test accuracy: 0.880
# Epoch: 901/1000,  loss: 0.326, test accuracy: 0.880
# Epoch: 902/1000,  loss: 0.347, test accuracy: 0.890
# Epoch: 903/1000,  loss: 0.338, test accuracy: 0.900
# Epoch: 904/1000,  loss: 0.371, test accuracy: 0.850
# Epoch: 905/1000,  loss: 0.339, test accuracy: 0.900
# Epoch: 906/1000,  loss: 0.355, test accuracy: 0.870
# Epoch: 907/1000,  loss: 0.384, test accuracy: 0.890
# Epoch: 908/1000,  loss: 0.375, test accuracy: 0.870
# Epoch: 909/1000,  loss: 0.359, test accuracy: 0.840
# Epoch: 910/1000,  loss: 0.342, test accuracy: 0.870
# Epoch: 911/1000,  loss: 0.362, test accuracy: 0.890
# Epoch: 912/1000,  loss: 0.342, test accuracy: 0.870
# Epoch: 913/1000,  loss: 0.342, test accuracy: 0.900
# Epoch: 914/1000,  loss: 0.346, test accuracy: 0.860
# Epoch: 915/1000,  loss: 0.340, test accuracy: 0.870
# Epoch: 916/1000,  loss: 0.335, test accuracy: 0.880
# Epoch: 917/1000,  loss: 0.335, test accuracy: 0.880
# Epoch: 918/1000,  loss: 0.351, test accuracy: 0.860
# Epoch: 919/1000,  loss: 0.339, test accuracy: 0.890
# Epoch: 920/1000,  loss: 0.356, test accuracy: 0.860
# Epoch: 921/1000,  loss: 0.341, test accuracy: 0.880
# Epoch: 922/1000,  loss: 0.342, test accuracy: 0.880
# Epoch: 923/1000,  loss: 0.329, test accuracy: 0.860
# Epoch: 924/1000,  loss: 0.343, test accuracy: 0.870
# Epoch: 925/1000,  loss: 0.331, test accuracy: 0.880
# Epoch: 926/1000,  loss: 0.336, test accuracy: 0.880
# Epoch: 927/1000,  loss: 0.332, test accuracy: 0.890
# Epoch: 928/1000,  loss: 0.330, test accuracy: 0.870
# Epoch: 929/1000,  loss: 0.356, test accuracy: 0.870
# Epoch: 930/1000,  loss: 0.349, test accuracy: 0.860
# Epoch: 931/1000,  loss: 0.369, test accuracy: 0.890
# Epoch: 932/1000,  loss: 0.393, test accuracy: 0.880
# Epoch: 933/1000,  loss: 0.345, test accuracy: 0.890
# Epoch: 934/1000,  loss: 0.344, test accuracy: 0.880
# Epoch: 935/1000,  loss: 0.358, test accuracy: 0.870
# Epoch: 936/1000,  loss: 0.350, test accuracy: 0.880
# Epoch: 937/1000,  loss: 0.378, test accuracy: 0.880
# Epoch: 938/1000,  loss: 0.374, test accuracy: 0.890
# Epoch: 939/1000,  loss: 0.340, test accuracy: 0.830
# Epoch: 940/1000,  loss: 0.346, test accuracy: 0.890
# Epoch: 941/1000,  loss: 0.354, test accuracy: 0.860
# Epoch: 942/1000,  loss: 0.353, test accuracy: 0.900
# Epoch: 943/1000,  loss: 0.340, test accuracy: 0.880
# Epoch: 944/1000,  loss: 0.360, test accuracy: 0.880
# Epoch: 945/1000,  loss: 0.351, test accuracy: 0.870
# Epoch: 946/1000,  loss: 0.369, test accuracy: 0.890
# Epoch: 947/1000,  loss: 0.346, test accuracy: 0.860
# Epoch: 948/1000,  loss: 0.355, test accuracy: 0.880
# Epoch: 949/1000,  loss: 0.337, test accuracy: 0.880
# Epoch: 950/1000,  loss: 0.347, test accuracy: 0.880
# Epoch: 951/1000,  loss: 0.338, test accuracy: 0.880
# Epoch: 952/1000,  loss: 0.345, test accuracy: 0.860
# Epoch: 953/1000,  loss: 0.338, test accuracy: 0.880
# Epoch: 954/1000,  loss: 0.339, test accuracy: 0.900
# Epoch: 955/1000,  loss: 0.357, test accuracy: 0.870
# Epoch: 956/1000,  loss: 0.335, test accuracy: 0.860
# Epoch: 957/1000,  loss: 0.342, test accuracy: 0.890
# Epoch: 958/1000,  loss: 0.346, test accuracy: 0.880
# Epoch: 959/1000,  loss: 0.359, test accuracy: 0.880
# Epoch: 960/1000,  loss: 0.343, test accuracy: 0.890
# Epoch: 961/1000,  loss: 0.365, test accuracy: 0.860
# Epoch: 962/1000,  loss: 0.348, test accuracy: 0.880
# Epoch: 963/1000,  loss: 0.356, test accuracy: 0.870
# Epoch: 964/1000,  loss: 0.321, test accuracy: 0.840
# Epoch: 965/1000,  loss: 0.344, test accuracy: 0.870
# Epoch: 966/1000,  loss: 0.338, test accuracy: 0.870
# Epoch: 967/1000,  loss: 0.351, test accuracy: 0.880
# Epoch: 968/1000,  loss: 0.353, test accuracy: 0.890
# Epoch: 969/1000,  loss: 0.401, test accuracy: 0.880
# Epoch: 970/1000,  loss: 0.367, test accuracy: 0.870
# Epoch: 971/1000,  loss: 0.341, test accuracy: 0.870
# Epoch: 972/1000,  loss: 0.348, test accuracy: 0.880
# Epoch: 973/1000,  loss: 0.336, test accuracy: 0.890
# Epoch: 974/1000,  loss: 0.354, test accuracy: 0.890
# Epoch: 975/1000,  loss: 0.354, test accuracy: 0.870
# Epoch: 976/1000,  loss: 0.354, test accuracy: 0.890
# Epoch: 977/1000,  loss: 0.334, test accuracy: 0.880
# Epoch: 978/1000,  loss: 0.331, test accuracy: 0.880
# Epoch: 979/1000,  loss: 0.362, test accuracy: 0.880
# Epoch: 980/1000,  loss: 0.349, test accuracy: 0.870
# Epoch: 981/1000,  loss: 0.320, test accuracy: 0.880
# Epoch: 982/1000,  loss: 0.342, test accuracy: 0.880
# Epoch: 983/1000,  loss: 0.337, test accuracy: 0.880
# Epoch: 984/1000,  loss: 0.343, test accuracy: 0.870
# Epoch: 985/1000,  loss: 0.359, test accuracy: 0.870
# Epoch: 986/1000,  loss: 0.347, test accuracy: 0.890
# Epoch: 987/1000,  loss: 0.358, test accuracy: 0.870
# Epoch: 988/1000,  loss: 0.334, test accuracy: 0.890
# Epoch: 989/1000,  loss: 0.336, test accuracy: 0.880
# Epoch: 990/1000,  loss: 0.352, test accuracy: 0.840
# Epoch: 991/1000,  loss: 0.325, test accuracy: 0.900
# Epoch: 992/1000,  loss: 0.332, test accuracy: 0.870
# Epoch: 993/1000,  loss: 0.347, test accuracy: 0.870
# Epoch: 994/1000,  loss: 0.335, test accuracy: 0.880
# Epoch: 995/1000,  loss: 0.342, test accuracy: 0.880
# Epoch: 996/1000,  loss: 0.334, test accuracy: 0.870
# Epoch: 997/1000,  loss: 0.368, test accuracy: 0.890
# Epoch: 998/1000,  loss: 0.339, test accuracy: 0.870
# Epoch: 999/1000,  loss: 0.346, test accuracy: 0.880
# Epoch: 1000/1000,  loss: 0.331, test accuracy: 0.870
# Finished Training in 47 seconds

# %%
plot_cost_accuracy(relu_costs, relu_accuracies)
# Out:
# best_accuracy: 0.92 achieved at epoch: 183
# 0.92

# %% [markdown]
# #### Visualize the posterior of the network trained above

# %%
visualize_posterior(posterior,relu_net)
# Out:
# /home/nick/.local/lib/python3.5/site-packages/ipykernel_launcher.py:10: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# <a id='question 3'></a>
# # Cross Validation to pick number of nodes for the hidden layers and the weight decay parameter $\lambda$

# %% [markdown]
# In this part we are going to use cross validation to try and find the best values for the number of nodes of the hidden layers as well as for the weight decay. We'll use again relu activations.
# * <b>Question 3:</b> Add the necessary lines inside `__init__` and `forward` in order to define a network that can have a variable number of nodes N. The number of nodes for each layer will be [2, N, N, 2]. Notice that this time the constructor function `__init()__` has a extra argument N, that will allow us to specify the number of nodes when creating an object of this class.

# %%
class ReluNetVariableNodes(nn.Module):
    def __init__(self,N):
        super().__init__()
        ###### TODO QUESTION 3 ########
        self.N = N
        self.fc1 = nn.Linear(2, self.N)
        self.fc2 = nn.Linear(self.N, self.N)
        self.fc3 = nn.Linear(self.N, 2)
        ###### TODO QUESTION 3 ########
    
    def forward(self, x):
        ###### TODO QUESTION 3 ########
        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)
        x = F.relu(x)
        x = self.fc3(x)
        
        ###### TODO QUESTION 3 ########
        return x

# %% [markdown]
# The following cell is only conveniently wrapping the whole training procedure inside a function in order to better organize our code. The function returns the best accuracy achieved.

# %%
def train_network(training_features, training_labels, test_features, test_labels, lamda, num_of_nodes, epochs = 1000, learning_rate =0.01):   
    start = time.time()
    net = ReluNetVariableNodes(num_of_nodes)
    
    training_features_tensor = torch.FloatTensor(training_features)
    training_labels_tensor = torch.FloatTensor(training_labels)
    testing_features_tensor = torch.FloatTensor(test_features)
    testing_labels_tensor = torch.FloatTensor(test_labels)
    
    trainset = torch.utils.data.TensorDataset(training_features_tensor, training_labels_tensor)
    trainloader = torch.utils.data.DataLoader(trainset, batch_size=40, shuffle=True, num_workers=2)
    
    optimizer = optim.SGD(net.parameters(), lr=learning_rate, weight_decay=lamda, momentum=0.9)
    
    costs = []
    accuracies = []
    
    for epoch in range(epochs):  # loop over the dataset multiple times

        running_loss = 0.0
        num_of_batches = 0 
        for i, data in enumerate(trainloader, 0):
            # get the inputs
            inputs, labels = data
            # wrap them in Variable
            inputs, labels = Variable(inputs), Variable(labels)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            logits = net(inputs)
            loss = criterion(logits, labels.type(torch.LongTensor))

            loss.backward()
            optimizer.step()

            # print statistics
            running_loss += loss.data[0]
            num_of_batches +=1

        # calculate test accuracy 
        test_logits = net(Variable(testing_features_tensor))
        _, test_predictions = torch.max(test_logits.data, 1)    
        correct_predictions = (test_predictions.int() == testing_labels_tensor.int()).sum()
        test_length = testing_labels_tensor.size()[0]
        accuracy = correct_predictions/test_length
        if epoch%(epochs//10) == 0:
            print('Epoch: %d/%d,  loss: %.3f, test accuracy: %.3f'%(epoch + 1,epochs, running_loss / num_of_batches, accuracy))
        costs.append(running_loss/num_of_batches)
        accuracies.append(accuracy)
    
    end = time.time()
    duration = end-start
    print('Finished Training in %d seconds'%(end-start))
    best_accuracy = plot_cost_accuracy(costs, accuracies)
    
    return best_accuracy, net

# %%
def logsample(start, end, num):
    return np.logspace(np.log10(start), np.log10(end), num, base=10.0)

num_of_lamdas = 3
lamda_range = logsample(1e-5, 1e-2, num_of_lamdas)
#lamda_range = [0.0001, 0.001, 0.01, 0.1, 1]
nodes_range = [5, 10, 20]

# %% [markdown]
# <a id='question 4'></a>
# ### Compute the cross-validation accuracy for each parameter combination
#
# Now we are going to again use cross-validation (see assignment 3) in order to find the optimal hyperparameters for our network. However instead of splitting our training set into K-Folds, we'll create a single training/validation split which we'll use for our hyperparameter grid search and therefore the *KFold* class from scikit-learn that we used in assignment 3 won't be necessary here.
#
# Be warned that this part might take about 10 minutes to run. Try it out for less epochs (maybe 100) to check if everything is working and only then run it for more epochs to improve your results.
#
# * <b>Question 4:</b> Fill in the necessary lines in the double loop iterating over the weight decay and number of nodes (parameter grid-search) in order to perform cross-validation. For each combination of hyperparameters, retrain the network calling the function `train_network()` with the right arguments.

# %%
cv_start = time.time()

split_percentage = 0.2
length_training = len(training_labels)
validation_split = np.int(np.ceil(split_percentage*length_training))
random_indices = np.random.permutation(np.arange(length_training))
cv_training_set_features = training_features[random_indices[validation_split:]]
cv_training_set_targets = training_labels[random_indices[validation_split:]]
cv_validation_set_features = training_features[random_indices[:validation_split]]
cv_validation_set_targets = training_labels[random_indices[:validation_split]]
cv_accuracy = np.zeros((len(nodes_range), num_of_lamdas))  # error matrix

learning_rate = 0.05
epochs = 1000

###### TODO QUESTION 4 ########

## loop hyperparameter num_of_nodes
##    loop hyperparameter lamda (i.e. weight decay)
for i , num_of_nodes in enumerate(nodes_range):
    for j , lamda in enumerate(lamda_range):
        print('\nCROSS VALIDATION for num_of_nodes = %d and lamda = %f '%(num_of_nodes, lamda))        
        
        ## add the right arguments for function train_network
        best_accuracy,_ = train_network(cv_training_set_features, cv_training_set_targets,
                                        cv_validation_set_features, cv_validation_set_targets, lamda, num_of_nodes) 

        # Save the best cv_accuracy for the current combination of parameters 
        cv_accuracy[i, j] = best_accuracy

###### TODO QUESTION 4 ########
cv_end = time.time()
print('Finished Grid Search in %d seconds'%(cv_end-cv_start))
# Out:
# CROSS VALIDATION for num_of_nodes = 5 and lamda = 0.000010
# Epoch: 1/1000,  loss: 0.692, test accuracy: 0.417
# Epoch: 101/1000,  loss: 0.623, test accuracy: 0.550
# Epoch: 201/1000,  loss: 0.526, test accuracy: 0.750
# Epoch: 301/1000,  loss: 0.490, test accuracy: 0.817
# Epoch: 401/1000,  loss: 0.490, test accuracy: 0.817
# Epoch: 501/1000,  loss: 0.489, test accuracy: 0.817
# Epoch: 601/1000,  loss: 0.489, test accuracy: 0.817
# Epoch: 701/1000,  loss: 0.482, test accuracy: 0.800
# Epoch: 801/1000,  loss: 0.484, test accuracy: 0.800
# Epoch: 901/1000,  loss: 0.484, test accuracy: 0.800
# Finished Training in 31 seconds
# best_accuracy: 0.8166666666666667 achieved at epoch: 249
#
# CROSS VALIDATION for num_of_nodes = 5 and lamda = 0.000316
# Epoch: 1/1000,  loss: 0.697, test accuracy: 0.417
# Epoch: 101/1000,  loss: 0.692, test accuracy: 0.417
# Epoch: 201/1000,  loss: 0.686, test accuracy: 0.467
# Epoch: 301/1000,  loss: 0.638, test accuracy: 0.483
# Epoch: 401/1000,  loss: 0.636, test accuracy: 0.517
# Epoch: 501/1000,  loss: 0.635, test accuracy: 0.483
# Epoch: 601/1000,  loss: 0.635, test accuracy: 0.517
# Epoch: 701/1000,  loss: 0.634, test accuracy: 0.500
# Epoch: 801/1000,  loss: 0.634, test accuracy: 0.483
# Epoch: 901/1000,  loss: 0.630, test accuracy: 0.483
# Finished Training in 36 seconds
# best_accuracy: 0.55 achieved at epoch: 213
#
# CROSS VALIDATION for num_of_nodes = 5 and lamda = 0.010000
# Epoch: 1/1000,  loss: 0.697, test accuracy: 0.417
# Epoch: 101/1000,  loss: 0.677, test accuracy: 0.533
# Epoch: 201/1000,  loss: 0.635, test accuracy: 0.600
# Epoch: 301/1000,  loss: 0.622, test accuracy: 0.650
# Epoch: 401/1000,  loss: 0.602, test accuracy: 0.783
# Epoch: 501/1000,  loss: 0.566, test accuracy: 0.783
# Epoch: 601/1000,  loss: 0.546, test accuracy: 0.783
# Epoch: 701/1000,  loss: 0.537, test accuracy: 0.783
# Epoch: 801/1000,  loss: 0.535, test accuracy: 0.783
# Epoch: 901/1000,  loss: 0.532, test accuracy: 0.783
# Finished Training in 32 seconds
# best_accuracy: 0.8166666666666667 achieved at epoch: 933
#
# CROSS VALIDATION for num_of_nodes = 10 and lamda = 0.000010
# Epoch: 1/1000,  loss: 0.718, test accuracy: 0.583
# Epoch: 101/1000,  loss: 0.631, test accuracy: 0.483
# Epoch: 201/1000,  loss: 0.585, test accuracy: 0.733
# Epoch: 301/1000,  loss: 0.510, test accuracy: 0.817
# Epoch: 401/1000,  loss: 0.504, test accuracy: 0.783
# Epoch: 501/1000,  loss: 0.483, test accuracy: 0.817
# Epoch: 601/1000,  loss: 0.480, test accuracy: 0.817
# Epoch: 701/1000,  loss: 0.464, test accuracy: 0.817
# Epoch: 801/1000,  loss: 0.465, test accuracy: 0.833
# Epoch: 901/1000,  loss: 0.461, test accuracy: 0.833
# Finished Training in 33 seconds
# best_accuracy: 0.8333333333333334 achieved at epoch: 597
#
# CROSS VALIDATION for num_of_nodes = 10 and lamda = 0.000316
# Epoch: 1/1000,  loss: 0.698, test accuracy: 0.367
# Epoch: 101/1000,  loss: 0.635, test accuracy: 0.500
# Epoch: 201/1000,  loss: 0.613, test accuracy: 0.667
# Epoch: 301/1000,  loss: 0.524, test accuracy: 0.783
# Epoch: 401/1000,  loss: 0.511, test accuracy: 0.700
# Epoch: 501/1000,  loss: 0.495, test accuracy: 0.817
# Epoch: 601/1000,  loss: 0.492, test accuracy: 0.783
# Epoch: 701/1000,  loss: 0.500, test accuracy: 0.800
# Epoch: 801/1000,  loss: 0.488, test accuracy: 0.800
# Epoch: 901/1000,  loss: 0.490, test accuracy: 0.800
# Finished Training in 32 seconds
# best_accuracy: 0.8333333333333334 achieved at epoch: 362
#
# CROSS VALIDATION for num_of_nodes = 10 and lamda = 0.010000
# Epoch: 1/1000,  loss: 0.697, test accuracy: 0.417
# Epoch: 101/1000,  loss: 0.660, test accuracy: 0.500
# Epoch: 201/1000,  loss: 0.640, test accuracy: 0.483
# Epoch: 301/1000,  loss: 0.639, test accuracy: 0.483
# Epoch: 401/1000,  loss: 0.638, test accuracy: 0.483
# Epoch: 501/1000,  loss: 0.636, test accuracy: 0.467
# Epoch: 601/1000,  loss: 0.628, test accuracy: 0.550
# Epoch: 701/1000,  loss: 0.606, test accuracy: 0.617
# Epoch: 801/1000,  loss: 0.573, test accuracy: 0.733
# Epoch: 901/1000,  loss: 0.545, test accuracy: 0.750
# Finished Training in 32 seconds
# best_accuracy: 0.8166666666666667 achieved at epoch: 976
#
# CROSS VALIDATION for num_of_nodes = 20 and lamda = 0.000010
# Epoch: 1/1000,  loss: 0.696, test accuracy: 0.367
# Epoch: 101/1000,  loss: 0.615, test accuracy: 0.500
# Epoch: 201/1000,  loss: 0.492, test accuracy: 0.800
# Epoch: 301/1000,  loss: 0.417, test accuracy: 0.833
# Epoch: 401/1000,  loss: 0.376, test accuracy: 0.817
# Epoch: 501/1000,  loss: 0.353, test accuracy: 0.900
# Epoch: 601/1000,  loss: 0.372, test accuracy: 0.883
# Epoch: 701/1000,  loss: 0.378, test accuracy: 0.900
# Epoch: 801/1000,  loss: 0.369, test accuracy: 0.900
# Epoch: 901/1000,  loss: 0.411, test accuracy: 0.883
# Finished Training in 33 seconds
# best_accuracy: 0.9166666666666666 achieved at epoch: 518
#
# CROSS VALIDATION for num_of_nodes = 20 and lamda = 0.000316
# Epoch: 1/1000,  loss: 0.722, test accuracy: 0.583
# Epoch: 101/1000,  loss: 0.606, test accuracy: 0.500
# Epoch: 201/1000,  loss: 0.503, test accuracy: 0.800
# Epoch: 301/1000,  loss: 0.458, test accuracy: 0.833
# Epoch: 401/1000,  loss: 0.390, test accuracy: 0.883
# Epoch: 501/1000,  loss: 0.378, test accuracy: 0.867
# Epoch: 601/1000,  loss: 0.366, test accuracy: 0.867
# Epoch: 701/1000,  loss: 0.386, test accuracy: 0.867
# Epoch: 801/1000,  loss: 0.364, test accuracy: 0.883
# Epoch: 901/1000,  loss: 0.357, test accuracy: 0.883
# Finished Training in 33 seconds
# best_accuracy: 0.9166666666666666 achieved at epoch: 725
#
# CROSS VALIDATION for num_of_nodes = 20 and lamda = 0.010000
# Epoch: 1/1000,  loss: 0.690, test accuracy: 0.417
# Epoch: 101/1000,  loss: 0.627, test accuracy: 0.517
# Epoch: 201/1000,  loss: 0.592, test accuracy: 0.667
# Epoch: 301/1000,  loss: 0.543, test accuracy: 0.750
# Epoch: 401/1000,  loss: 0.531, test accuracy: 0.767
# Epoch: 501/1000,  loss: 0.524, test accuracy: 0.800
# Epoch: 601/1000,  loss: 0.522, test accuracy: 0.783
# Epoch: 701/1000,  loss: 0.521, test accuracy: 0.783
# Epoch: 801/1000,  loss: 0.520, test accuracy: 0.783
# Epoch: 901/1000,  loss: 0.522, test accuracy: 0.783
# Finished Training in 33 seconds
# best_accuracy: 0.8166666666666667 achieved at epoch: 470
# Finished Grid Search in 301 seconds

# %%
# Display accuracies
fig = plt.figure(figsize=plt.figaspect(0.25))

ax = fig.add_subplot(1, 1, 1)
ax.set_title("Cross-validation accuracy")
ax.set_xlabel("weight decay parameter")
ax.set_ylabel("Number of nodes")
#plt.xticks
plt.imshow(cv_accuracy, cmap='gray', origin='lower')
plt.yticks(range(len(nodes_range)),nodes_range)
plt.xticks(range(len(lamda_range)),np.round(lamda_range,5))
# Out:
# ([<matplotlib.axis.XTick at 0x7feda13f3390>,
#   <matplotlib.axis.XTick at 0x7feda3478b38>,
#   <matplotlib.axis.XTick at 0x7feda13ebda0>],
#  <a list of 3 Text xticklabel objects>)

# %%
# Find weight decay  and number of nodes giving the highest accuracy
max_ind = cv_accuracy.argmax()  # index of the max in the flattened array
node_ind, lamda_ind = np.unravel_index(max_ind, cv_accuracy.shape)  # matrix indices
best_lamda = lamda_range[lamda_ind]
best_node_num = nodes_range[node_ind]

print( 'Highest accuracy give by lamda = %f and num_of_nodes=%d'%(best_lamda, best_node_num))
# Out:
# Highest accuracy give by lamda = 0.000010 and num_of_nodes=20

# %% [markdown]
# ## Finally train a network on the full training set using the best combination of parameters

# %%
best_accuracy, final_net = train_network(training_features, training_labels, 
                                             test_features, test_labels, 
                                             best_lamda, best_node_num, learning_rate = learning_rate, epochs = epochs)
# Out:
# Epoch: 1/1000,  loss: 0.697, test accuracy: 0.720
# Epoch: 101/1000,  loss: 0.456, test accuracy: 0.870
# Epoch: 201/1000,  loss: 0.369, test accuracy: 0.890
# Epoch: 301/1000,  loss: 0.348, test accuracy: 0.840
# Epoch: 401/1000,  loss: 0.343, test accuracy: 0.850
# Epoch: 501/1000,  loss: 0.358, test accuracy: 0.880
# Epoch: 601/1000,  loss: 0.356, test accuracy: 0.860
# Epoch: 701/1000,  loss: 0.351, test accuracy: 0.880
# Epoch: 801/1000,  loss: 0.353, test accuracy: 0.860
# Epoch: 901/1000,  loss: 0.336, test accuracy: 0.850
# Finished Training in 35 seconds
# best_accuracy: 0.92 achieved at epoch: 177
