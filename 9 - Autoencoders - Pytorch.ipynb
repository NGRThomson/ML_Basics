# %% [markdown]
# This code is my assignment 9 for my machine learning module at UCL 2017/18. For this assignment I received 100% mark.

# %% [markdown]
# # Autoencoders
#
# In this assignment, we will look at autoencoders and compare their performance with an autoencoder-based PCA model. For this, we will continue to use the MNIST dataset that we have seen in the previous assignments.
#
# As usual, the structure of the code is given to you, and you need to fill in the parts corresponding to the questions below.
#
# __PART A__: In this part we will build three models: an autoencoder-based PCA, a shallow and a deeper autoencoder. We will then train and test these models on the MNIST dataset and compare their performance visually as well as by ccomputing the test set recontruction error.
# - <a href='#question 1'>Question 1</a> Autoencoder-based PCA: implement an autoencoder-based PCA model formed of two linear layers, using a structure similar to the shallow autoencoder model.
# - <a href='#question 2'>Question 2</a> Shallow autoencoder: Use different number of nodes (e.g.\[128,16\]), in hidden layers and compare the results.
# - <a href='#question 3'>Question 3</a> Deep autoencoder: after reading the basic autoencoder provided as an example, build a deeper autoencoder. Use different number of nodes (e.g.\[128,64,16\]), in hidden layers and compare the results.
#
# __PART B__: In this part we will interpolate between two images in the latent space. This is done by first obtaining the encoded images:
#
# \begin{align}
# latent\_1 = encoder(image\_1)
# \end{align}
#
# \begin{align}
# latent\_2 = encoder(image\_2)
# \end{align}
#
# and then generating the new interpolated image using the following equation:
#
# \begin{align}
# interpolated\_image\_\lambda = decoder[\lambda* latent\_1 + (1- \lambda) * latent\_2]
# \end{align}
#
# We will do this using the PCA model and then the autoencoder model and look at the differences between the two interpolations. Then, we need to get the image space representation and to verify that the interpolation generated using the deep autoenconder is better.
# - <a href='#question 1'>Question 1</a> Interpolate between an image corresponding to digit 1 and an image corresponding to digit 7 using the latent space representation obtained using the PCA-based autoenconder.
# - <a href='#question 1'>Question 2</a>  Interpolate between an image corresponding to digit 1 and an image corresponding to digit 7 using the latent space representation obtained using the deep autoenconder.

# %%
# Import libraries

import os
import torch
import torchvision
from torch import nn
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms
import torchvision.datasets as dset
from torchvision.utils import save_image

# %%
# Import dataset
batch_size = 128

# Convert the data to Tensor and normalise by the mean and std  of the data set
transform = transforms.Compose([transforms.ToTensor(), 
                                transforms.Normalize((0.5,), (0.5,))])

# Import and normalize the train set in mini-batches 
train_set = torchvision.datasets.MNIST(root='./data', train=True,
                                        download=True, transform=transform)
train_set_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size,
                                              shuffle=True)

# Import and normalize the test set in mini-batches
test_set = torchvision.datasets.MNIST(root='./data', train=False,
                                        download=True, transform=transform)
test_set_loader = torch.utils.data.DataLoader(test_set, batch_size=batch_size,
                                              shuffle=True)

# %% [markdown]
# #### Visualise
# Visualise examples of the images from the dataset.

# %%
# Import libraries for visualising
import matplotlib.pyplot as plt
import numpy as np

# Load a batch of training images for visualising
data_iterator = iter(train_set_loader)
images, labels = data_iterator.next()

# Create function for visualisation
def show_image(img):
    # revert the normalisation for displaying the images in their original form
    img = img * 0.5 + 0.5
    # Convert to numpy for visualisation
    npimg = img.numpy()
    # Plot each image
    plt.imshow(np.transpose(npimg, (1, 2, 0)))


# Plot images as a grid using the 'make_grid' function
show_image(torchvision.utils.make_grid(images,10,5))
plt.show()

# %% [markdown]
# ## PART A:
#
# ## Models
# In this section we will implements three models as three different classes:
#
# 1. An autoencoder-based PCA
# 2. A shallow autoencoder
# 3. A deep autoencoder

# %% [markdown]
# #### 1. Autoencoder-based PCA model
# Build an autoencoder-based PCA model. This will be made of two linear layers. The first linear layer is the encoder part. It receives as an input the image and has an output of shape num_hidden_1, where num_hidden_1 the number of hidden units in layer _L1_ . The second linear layer is the decoder and has an output of the same shape as the images in the dataset, since its role is to reconstruct the image.

# %%
class autoencoder_PCA(nn.Module):
    def __init__(self,num_in,num_hidden_1,num_out):
        super(autoencoder_PCA, self).__init__()
        # The layers of the encoder
        self.encoder = nn.Linear(num_in, num_hidden_1)
        # The layers of the decoder   
        self.decoder = nn.Sequential(
            nn.Linear(num_hidden_1, num_out),
            nn.Tanh())
        
    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

# %% [markdown]
# #### 2. Shallow autoencoder model
# This model is made of two parts:
#
# a. __the encoder__: a layer that takes as an input the image and has an output of shape num_hidden_1 and a __ReLU__ activation function. A second layer that has an output of shape num_hidden_2 and no activation function.
#
# b. __the decoder__: this takes as an input the output of the encoder and has the same structure as a decoder, but in inverse order (the mirror image of the decoder). Additionally, the decoder applies a __tanh__ activation function to the final layer.
#
# This function is already given to you as an example of a basic autoencoder.

# %%
class shallow_autoencoder(nn.Module):
    def __init__(self,num_in,num_hidden_1,num_hidden_2,num_out):
        super(shallow_autoencoder, self).__init__()
        # The layers of the encoder
        self.encoder = nn.Sequential(
            nn.Linear(num_in, num_hidden_1),
            nn.ReLU(True),
            nn.Linear(num_hidden_1, num_hidden_2))
        # The layers of the decoder   
        self.decoder = nn.Sequential(
            nn.Linear(num_hidden_2, num_hidden_1),
            nn.ReLU(True), 
            nn.Linear(num_hidden_1, num_out), 
            nn.Tanh())
        
    # The forward pass    
    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

# %% [markdown]
# #### 2. Deep autoencoder model
# This model is similar to the previous one, but with a deeper structure:
#
# a. __the encoder__: a layer that takes as an input the image and has an output of shape num_hidden_1 and a __ReLU__ activation function. A second layer that has an output of shape num_hidden_2 and a __ReLU__ activation function. A final linear layer with output of shape num_hidden_3 and no activation function
#
# b. __the decoder__: this takes as an input the output of the encoder and has the same structure as a decoder, but in inverse order (the mirror image of the decoder). Additionally, the decoder applies a __tanh__ activation function to the final layer.

# %%
class deep_autoencoder(nn.Module):
    def __init__(self,num_in,num_hidden_1,num_hidden_2,num_hidden_3,num_out):
        super(deep_autoencoder, self).__init__()
        # The layers of the encoder
        self.encoder = nn.Sequential(
            nn.Linear(num_in, num_hidden_1),
            nn.ReLU(True),
            nn.Linear(num_hidden_1, num_hidden_2),
            nn.ReLU(True),
            nn.Linear(num_hidden_2, num_hidden_3))
        # The layers of the decoder   
        self.decoder = nn.Sequential(
            nn.Linear(num_hidden_3, num_hidden_2),
            nn.ReLU(True),
            nn.Linear(num_hidden_2, num_hidden_1),
            nn.ReLU(True), 
            nn.Linear(num_hidden_1, num_out), 
            nn.Tanh())
        
    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

# %% [markdown]
# ## Train and test the models
#
# #### Train function
#
# Now that we have build the models, let's define a function which performs the training. this function has the following parameters: the train set, the batch size, the number of epochs for which to perform the trainig, the learning rate, and the model to train.

# %%
def train(train_set, batch_size, num_epochs, learning_rate, model):

    no_batches = int(np.round((len(train_set) / batch_size)))
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(
    model.parameters(), lr=learning_rate, weight_decay=1e-5)

    losses = []
    for epoch in range(num_epochs):
        train_loss = 0
        for data in train_set_loader:
            img, _ = data
            img = img.view(img.size(0), -1)
            img = Variable(img)
            
            output = model(img)
            loss = criterion(output, img)
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            train_loss += loss.data[0]
            
        print('====> Epoch: {} Average loss: {:.4f}'.format(epoch, train_loss / no_batches))
        losses.append(train_loss / no_batches)   
    return losses

# %% [markdown]
# #### Test function
# Similarly to the train function, build a test function that evaluates the performance of the models on the test set

# %%
def evaluate_test(test_set, test_set_loader, batch_size, model):
    
    test_loss = 0
    criterion = nn.MSELoss()
    test_no_batches = np.round(int(len(test_set)/batch_size))
    
    for data in test_set_loader:
            img, _ = data
            img = img.view(img.size(0), -1)
            img = Variable(img)
            
            output = model(img)
            loss = criterion(output, img)
            test_loss += loss.data[0]
            
    test_loss = test_loss/test_no_batches
    print('====> Test loss: {:.4f}'.format(test_loss))
    return test_loss

# %% [markdown]
# Now that we have written the train and test functions, let's train and then compare the reconstruction error on the train and test set of the three models. For each model, plot the training error.
#
# ### 1. PCA based autoenconder model

# %%
#define the model
num_input=28*28
num_hidden_1=16
num_output=28*28
model1 = autoencoder_PCA(num_input,num_hidden_1,num_output)

#train the model
model1_loss_train = train(train_set= train_set, batch_size = 128, num_epochs = 100, learning_rate=1e-3, model = model1)

# Plot the training error
fig = plt.figure()
plt.plot(model1_loss_train)
plt.xlabel('Epochs')
plt.ylabel('Reconstruction error')
plt.show()

# Calculate the loss in test set
model1_loss_test= evaluate_test(test_set = test_set, test_set_loader=  test_set_loader,batch_size = 128, model=model1)
# Out:
# ====> Epoch: 0 Average loss: 0.2604
# ====> Epoch: 1 Average loss: 0.1323
# ====> Epoch: 2 Average loss: 0.1087
# ====> Epoch: 3 Average loss: 0.0987
# ====> Epoch: 4 Average loss: 0.0940
# ====> Epoch: 5 Average loss: 0.0914
# ====> Epoch: 6 Average loss: 0.0897
# ====> Epoch: 7 Average loss: 0.0885
# ====> Epoch: 8 Average loss: 0.0877
# ====> Epoch: 9 Average loss: 0.0869
# ====> Epoch: 10 Average loss: 0.0864
# ====> Epoch: 11 Average loss: 0.0860
# ====> Epoch: 12 Average loss: 0.0856
# ====> Epoch: 13 Average loss: 0.0854
# ====> Epoch: 14 Average loss: 0.0852
# ====> Epoch: 15 Average loss: 0.0850
# ====> Epoch: 16 Average loss: 0.0849
# ====> Epoch: 17 Average loss: 0.0848
# ====> Epoch: 18 Average loss: 0.0847
# ====> Epoch: 19 Average loss: 0.0846
# ====> Epoch: 20 Average loss: 0.0846
# ====> Epoch: 21 Average loss: 0.0845
# ====> Epoch: 22 Average loss: 0.0844
# ====> Epoch: 23 Average loss: 0.0844
# ====> Epoch: 24 Average loss: 0.0844
# ====> Epoch: 25 Average loss: 0.0843
# ====> Epoch: 26 Average loss: 0.0843
# ====> Epoch: 27 Average loss: 0.0843
# ====> Epoch: 28 Average loss: 0.0843
# ====> Epoch: 29 Average loss: 0.0842
# ====> Epoch: 30 Average loss: 0.0842
# ====> Epoch: 31 Average loss: 0.0842
# ====> Epoch: 32 Average loss: 0.0842
# ====> Epoch: 33 Average loss: 0.0841
# ====> Epoch: 34 Average loss: 0.0841
# ====> Epoch: 35 Average loss: 0.0842
# ====> Epoch: 36 Average loss: 0.0841
# ====> Epoch: 37 Average loss: 0.0841
# ====> Epoch: 59 Average loss: 0.0721
# ====> Epoch: 60 Average loss: 0.0719
# ====> Epoch: 61 Average loss: 0.0717
# ====> Epoch: 62 Average loss: 0.0708
# ====> Epoch: 63 Average loss: 0.0704
# ====> Epoch: 64 Average loss: 0.0702
# ====> Epoch: 65 Average loss: 0.0700
# ====> Epoch: 66 Average loss: 0.0699
# ====> Epoch: 67 Average loss: 0.0698
# ====> Epoch: 68 Average loss: 0.0697
# ====> Epoch: 69 Average loss: 0.0696
# ====> Epoch: 70 Average loss: 0.0695
# ====> Epoch: 71 Average loss: 0.0694
# ====> Epoch: 72 Average loss: 0.0693
# ====> Epoch: 73 Average loss: 0.0693
# ====> Epoch: 74 Average loss: 0.0692
# ====> Epoch: 75 Average loss: 0.0692
# ====> Epoch: 76 Average loss: 0.0691
# ====> Epoch: 77 Average loss: 0.0691
# ====> Epoch: 78 Average loss: 0.0690
# ====> Epoch: 79 Average loss: 0.0690
# ====> Epoch: 80 Average loss: 0.0689
# ====> Epoch: 81 Average loss: 0.0688
# ====> Epoch: 82 Average loss: 0.0688
# ====> Epoch: 83 Average loss: 0.0687
# ====> Epoch: 84 Average loss: 0.0687
# ====> Epoch: 85 Average loss: 0.0687
# ====> Epoch: 86 Average loss: 0.0686
# ====> Epoch: 87 Average loss: 0.0685
# ====> Epoch: 88 Average loss: 0.0685
# ====> Epoch: 89 Average loss: 0.0682
# ====> Epoch: 90 Average loss: 0.0682
# ====> Epoch: 91 Average loss: 0.0681
# ====> Epoch: 92 Average loss: 0.0681
# ====> Epoch: 93 Average loss: 0.0681
# ====> Epoch: 94 Average loss: 0.0680
# ====> Epoch: 95 Average loss: 0.0679
# ====> Epoch: 96 Average loss: 0.0679
# ====> Epoch: 97 Average loss: 0.0678
# ====> Epoch: 98 Average loss: 0.0678
# ====> Epoch: 99 Average loss: 0.0677
# ====> Test loss: 0.0667

# %%
#define the model
num_input=28*28
num_hidden_1=128
num_hidden_2=16
num_output=28*28

model2 = shallow_autoencoder(num_input,num_hidden_1,num_hidden_2,num_output)

#train the model
model2_loss_train = train(train_set=train_set, batch_size=128, num_epochs=100, learning_rate=1e-3, model=model2)

# Plot the error 
fig = plt.figure()
plt.plot(model2_loss_train)
plt.xlabel('Epochs')
plt.ylabel('Reconstruction error')
plt.show()

#calculate the loss in test set
model2_loss_test= evaluate_test(test_set=test_set, test_set_loader=test_set_loader,batch_size=128, model=model2)
# Out:
# ====> Epoch: 0 Average loss: 0.1722
# ====> Epoch: 1 Average loss: 0.0945
# ====> Epoch: 2 Average loss: 0.0843
# ====> Epoch: 3 Average loss: 0.0798
# ====> Epoch: 4 Average loss: 0.0769
# ====> Epoch: 5 Average loss: 0.0750
# ====> Epoch: 6 Average loss: 0.0733
# ====> Epoch: 7 Average loss: 0.0719
# ====> Epoch: 8 Average loss: 0.0708
# ====> Epoch: 9 Average loss: 0.0698
# ====> Epoch: 10 Average loss: 0.0688
# ====> Epoch: 11 Average loss: 0.0681
# ====> Epoch: 12 Average loss: 0.0671
# ====> Epoch: 13 Average loss: 0.0662
# ====> Epoch: 14 Average loss: 0.0656
# ====> Epoch: 82 Average loss: 0.0536
# ====> Epoch: 83 Average loss: 0.0536
# ====> Epoch: 84 Average loss: 0.0536
# ====> Epoch: 85 Average loss: 0.0535
# ====> Epoch: 86 Average loss: 0.0534
# ====> Epoch: 87 Average loss: 0.0535
# ====> Epoch: 88 Average loss: 0.0534
# ====> Epoch: 89 Average loss: 0.0533
# ====> Epoch: 90 Average loss: 0.0533
# ====> Epoch: 91 Average loss: 0.0532
# ====> Epoch: 92 Average loss: 0.0532
# ====> Epoch: 93 Average loss: 0.0531
# ====> Epoch: 94 Average loss: 0.0531
# ====> Epoch: 95 Average loss: 0.0531
# ====> Epoch: 96 Average loss: 0.0531
# ====> Epoch: 97 Average loss: 0.0531
# ====> Epoch: 98 Average loss: 0.0530
# ====> Epoch: 99 Average loss: 0.0530
# ====> Test loss: 0.0523

# %% [markdown]
# ## Compare the results ##
#
# The second model has a lower error, this is due to the larger size of the intermediate hidden layer size. The larger size means that there is more information being provided to the final layer of the encoder. This means that less information is lost from the original image and therefore the decoding of the image back to the original will have a smaller recontruction error, hence the lower overall error. The most apparent case of this would be to compare a PCA autoencoder with 784 middle layer size vs 1 middle layer size. There is more information carried forward in the 784 middle layer size encoder, therefore it should recreate the original image better than the 1 middle layer size. The downside to having bigger hidden layers is there are more parameters so they take longer to compute and more ram.

# %% [markdown]
# ### 3. Deep autoencoder

# %%
#define the model
num_input=28*28
num_hidden_1=64
num_hidden_2=32
num_hidden_3=16
num_output=28*28

model3 = deep_autoencoder(num_input,num_hidden_1,num_hidden_2,num_hidden_3,num_output)

#train the model
model3_loss_train = train(train_set= train_set, batch_size = 128, num_epochs = 100, learning_rate=1e-3, model = model3)

# Plot the error 
fig = plt.figure()
plt.plot(model3_loss_train)
plt.xlabel('Epochs')
plt.ylabel('Reconstruction error')
plt.show()

#calculate the loss in test set
model3_loss_test= evaluate_test(test_set = test_set, test_set_loader=  test_set_loader,batch_size = 128, model=model3)
# Out:
# ====> Epoch: 0 Average loss: 0.2362
# ====> Epoch: 1 Average loss: 0.1340
# ====> Epoch: 2 Average loss: 0.1150
# ====> Epoch: 3 Average loss: 0.1041
# ====> Epoch: 4 Average loss: 0.0968
# ====> Epoch: 5 Average loss: 0.0903
# ====> Epoch: 6 Average loss: 0.0863
# ====> Epoch: 7 Average loss: 0.0834
# ====> Epoch: 8 Average loss: 0.0803
# ====> Epoch: 9 Average loss: 0.0781
# ====> Epoch: 10 Average loss: 0.0765
# ====> Epoch: 11 Average loss: 0.0753
# ====> Epoch: 12 Average loss: 0.0742
# ====> Epoch: 13 Average loss: 0.0728
# ====> Epoch: 14 Average loss: 0.0714
# ====> Epoch: 15 Average loss: 0.0704
# ====> Epoch: 16 Average loss: 0.0695
# ====> Epoch: 17 Average loss: 0.0689
# ====> Epoch: 18 Average loss: 0.0682
# ====> Epoch: 19 Average loss: 0.0677
# ====> Epoch: 20 Average loss: 0.0672
# ====> Epoch: 21 Average loss: 0.0666
# ====> Epoch: 22 Average loss: 0.0662
# ====> Epoch: 23 Average loss: 0.0658
# ====> Epoch: 24 Average loss: 0.0653
# ====> Epoch: 92 Average loss: 0.0533
# ====> Epoch: 93 Average loss: 0.0534
# ====> Epoch: 94 Average loss: 0.0533
# ====> Epoch: 95 Average loss: 0.0533
# ====> Epoch: 96 Average loss: 0.0532
# ====> Epoch: 97 Average loss: 0.0533
# ====> Epoch: 98 Average loss: 0.0532
# ====> Epoch: 99 Average loss: 0.0532
# ====> Test loss: 0.0527

# %%
#define the model
num_input=28*28
num_hidden_1=128
num_hidden_2=64
num_hidden_3=16
num_output=28*28

model3 = deep_autoencoder(num_input,num_hidden_1,num_hidden_2,num_hidden_3,num_output)

#train the model
model3_loss_train = train(train_set= train_set, batch_size = 128, num_epochs = 100, learning_rate=1e-3, model = model3)

# Plot the error 
fig = plt.figure()
plt.plot(model3_loss_train)
plt.xlabel('Epochs')
plt.ylabel('Reconstruction error')
plt.show()

#calculate the loss in test set
model3_loss_test= evaluate_test(test_set = test_set, test_set_loader=  test_set_loader,batch_size = 128, model=model3)
# Out:
# ====> Epoch: 0 Average loss: 0.1918
# ====> Epoch: 1 Average loss: 0.1005
# ====> Epoch: 2 Average loss: 0.0843
# ====> Epoch: 3 Average loss: 0.0763
# ====> Epoch: 4 Average loss: 0.0711
# ====> Epoch: 5 Average loss: 0.0672
# ====> Epoch: 6 Average loss: 0.0634
# ====> Epoch: 7 Average loss: 0.0607
# ====> Epoch: 8 Average loss: 0.0589
# ====> Epoch: 9 Average loss: 0.0573
# ====> Epoch: 10 Average loss: 0.0562
# ====> Epoch: 11 Average loss: 0.0552
# ====> Epoch: 12 Average loss: 0.0542
# ====> Epoch: 13 Average loss: 0.0536
# ====> Epoch: 14 Average loss: 0.0528
# ====> Epoch: 15 Average loss: 0.0522
# ====> Epoch: 16 Average loss: 0.0517
# ====> Epoch: 17 Average loss: 0.0511
# ====> Epoch: 18 Average loss: 0.0506
# ====> Epoch: 19 Average loss: 0.0502
# ====> Epoch: 20 Average loss: 0.0498
# ====> Epoch: 21 Average loss: 0.0494
# ====> Epoch: 22 Average loss: 0.0491
# ====> Epoch: 23 Average loss: 0.0487
# ====> Epoch: 24 Average loss: 0.0484
# ====> Epoch: 25 Average loss: 0.0481
# ====> Epoch: 26 Average loss: 0.0479
# ====> Epoch: 27 Average loss: 0.0476
# ====> Epoch: 28 Average loss: 0.0474
# ====> Epoch: 29 Average loss: 0.0472
# ====> Epoch: 30 Average loss: 0.0470
# ====> Epoch: 31 Average loss: 0.0468
# ====> Epoch: 32 Average loss: 0.0466
# ====> Epoch: 33 Average loss: 0.0464
# ====> Epoch: 34 Average loss: 0.0462
# ====> Epoch: 35 Average loss: 0.0461
# ====> Epoch: 36 Average loss: 0.0459
# ====> Epoch: 37 Average loss: 0.0457
# ====> Epoch: 38 Average loss: 0.0457
# ====> Epoch: 39 Average loss: 0.0454
# ====> Epoch: 40 Average loss: 0.0453
# ====> Epoch: 41 Average loss: 0.0452
# ====> Epoch: 42 Average loss: 0.0450
# ====> Epoch: 43 Average loss: 0.0449
# ====> Epoch: 44 Average loss: 0.0448
# ====> Epoch: 45 Average loss: 0.0448
# ====> Epoch: 46 Average loss: 0.0446
# ====> Epoch: 47 Average loss: 0.0445
# ====> Epoch: 48 Average loss: 0.0444
# ====> Epoch: 49 Average loss: 0.0443
# ====> Epoch: 50 Average loss: 0.0442
# ====> Epoch: 51 Average loss: 0.0441
# ====> Epoch: 52 Average loss: 0.0440
# ====> Epoch: 53 Average loss: 0.0440
# ====> Epoch: 54 Average loss: 0.0439
# ====> Epoch: 55 Average loss: 0.0437
# ====> Epoch: 56 Average loss: 0.0436
# ====> Epoch: 57 Average loss: 0.0436
# ====> Epoch: 58 Average loss: 0.0435
# ====> Epoch: 59 Average loss: 0.0434
# ====> Epoch: 60 Average loss: 0.0433
# ====> Epoch: 61 Average loss: 0.0433
# ====> Epoch: 62 Average loss: 0.0432
# ====> Epoch: 63 Average loss: 0.0431
# ====> Epoch: 64 Average loss: 0.0431
# ====> Epoch: 65 Average loss: 0.0430
# ====> Epoch: 66 Average loss: 0.0429
# ====> Epoch: 67 Average loss: 0.0429
# ====> Epoch: 68 Average loss: 0.0428
# ====> Epoch: 69 Average loss: 0.0428
# ====> Epoch: 70 Average loss: 0.0426
# ====> Epoch: 71 Average loss: 0.0426
# ====> Epoch: 72 Average loss: 0.0425
# ====> Epoch: 73 Average loss: 0.0425
# ====> Epoch: 74 Average loss: 0.0424
# ====> Epoch: 75 Average loss: 0.0424
# ====> Epoch: 76 Average loss: 0.0423
# ====> Epoch: 77 Average loss: 0.0423
# ====> Epoch: 78 Average loss: 0.0422
# ====> Epoch: 79 Average loss: 0.0421
# ====> Epoch: 80 Average loss: 0.0421
# ====> Epoch: 81 Average loss: 0.0420
# ====> Epoch: 82 Average loss: 0.0420
# ====> Epoch: 83 Average loss: 0.0420
# ====> Epoch: 84 Average loss: 0.0419
# ====> Epoch: 85 Average loss: 0.0418
# ====> Epoch: 86 Average loss: 0.0417
# ====> Epoch: 87 Average loss: 0.0417
# ====> Epoch: 88 Average loss: 0.0417
# ====> Epoch: 89 Average loss: 0.0416
# ====> Epoch: 90 Average loss: 0.0416
# ====> Epoch: 91 Average loss: 0.0416
# ====> Epoch: 92 Average loss: 0.0415
# ====> Epoch: 93 Average loss: 0.0414
# ====> Epoch: 94 Average loss: 0.0414
# ====> Epoch: 95 Average loss: 0.0414
# ====> Epoch: 96 Average loss: 0.0414
# ====> Epoch: 97 Average loss: 0.0413
# ====> Epoch: 98 Average loss: 0.0412
# ====> Epoch: 99 Average loss: 0.0412
# ====> Test loss: 0.0414

# %% [markdown]
# ## Compare the results ##
#
# Similar to the above result(which I have already discussed), the autoencoder with larger intermediate layers will have a smaller error. This is reflected in the plot.

# %% [markdown]
# ### Visualise the reconstructions obtained from the three models

# %%
data_iterator = iter(test_set_loader)
images, labels = data_iterator.next()

# This function takes as an input the images to reconstruct
# and the name of the model with which the reconstructions
# are performed
def to_img(x):
    x = 0.5 * (x + 1)
    x = x.clamp(0, 1)
    x = x.view(x.size(0), 1, 28, 28)
    return x

def visualise_output(images, model):
    data = images
    img = data
    img = img.view(img.size(0), -1)
    img = Variable(img)
    out = model(img)
    pic = out.data.view(out.data.size(0), 1, 28, 28)
    pic = pic * 0.5 + 0.5
    np_pic = torchvision.utils.make_grid(pic[1:50], 10, 5).numpy()
    plt.imshow(np.transpose(np_pic, (1, 2, 0)))
    plt.show()

# %%
# First visualise the original images
print('Original images')
show_image(torchvision.utils.make_grid(images[1:50],10,5))
plt.show()
# model1 = autoencoder_PCA(num_input,num_hidden_1,num_output)
# Reconstruct and visualise the images using the first model
print('PCA based autoencoder reconstruction:')
visualise_output(images, model1)

# Reconstruct and visualise the images using the second model
print('Shallow autoencoder reconstruction:')
visualise_output(images, model2)

# Reconstruct and visualise the images using the third model
print('Deep autoencoder reconstruction:')
visualise_output(images, model3)
# Out:
# Original images
# PCA based autoencoder reconstruction:
# Shallow autoencoder reconstruction:
# Deep autoencoder reconstruction:

# %% [markdown]
# ## Part B
#
# In this part of the assignment we need to interpolate between two images using the latent space representation obtained by the PCA-based autoenconder and the deep autoenconder and subsequently to verify that the interpolation generated using the deep autoencoder is better.

# %%
#Extract images to apply interpolation 
one = []
four = []
seven = []
eight = []

for i in range(len(train_set)):
    if (train_set[i][1]==1):
        one.append(train_set[i])
    
    if (train_set[i][1]==4):
        four.append(train_set[i])

    if (train_set[i][1]==7):
        seven.append(train_set[i])
    
    if (train_set[i][1]==8):
        eight.append(train_set[i])
    
img1= seven[0][0]
npimg = img1.numpy()
im7 = npimg.reshape(28, 28)

img2 = one[0][0]
npimg = img2.numpy()
im1 = npimg.reshape(28, 28)

img3 = four[0][0]
npimg = img3.numpy()
im4 = npimg.reshape(28, 28)

img4 = eight[0][0]
npimg = img4.numpy()
im8 = npimg.reshape(28, 28)

# %%
f, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4)
ax1.imshow(im1, cmap='gray')
ax1.axis('off')
ax2.imshow(im4, cmap='gray')
ax2.axis('off')
ax3.imshow(im7, cmap='gray')
ax3.axis('off')
ax4.imshow(im8, cmap='gray')
ax4.axis('off')
plt.show()

# %%
sevens = torch.Tensor(seven[0][0])
ones = torch.Tensor(one[0][0])
fours = torch.Tensor(four[0][0])
eights = torch.Tensor(eight[0][0])

# %% [markdown]
# __interpolation()__ function initially obtains the latent space representation of _image1_ and _image2_ and apply interpolation. Then, it obtains and returns the interpolated image space representation.

# %%
def interpolation(lambda1, model, image1, image2):
    
    img1= image1
    img1 = img1.view(img1.size(0), -1)
    img1 = Variable(img1)
    #Latent space interpretation of image1 
    latent_1 = model.encoder(img1)
    
    img2= image2
    img2 = img2.view(img1.size(0), -1)
    img2 = Variable(img2)
    #Latent space interpretation of image2
    latent_2 = model.encoder(img2)
    
    #Interpolation of the two images
    inter_image_lat = lambda1*latent_1 + (1-lambda1)*latent_2
    
    inter_image = model.decoder(inter_image_lat)
    
    pic = to_img(inter_image)
    image = pic.data.numpy()
    image = image.reshape(28,28)
    plt.imshow(image, cmap='gray')
    plt.show()

# %% [markdown]
# Interpolation between digits _seven_ and _one_ using the PCA based autoenconder.

# %%
interpolation(0.4, model1, sevens, ones)

# %% [markdown]
# Interpolation between digits _seven_ and _one_ using the deep autoenconder.

# %%
interpolation(0.4, model3, sevens, ones)

# %% [markdown]
# Interpolation between digits _four_ and _eight_ using the PCA based autoenconder.

# %%
interpolation(0.4, model1, fours, eights)

# %% [markdown]
# Interpolation between digits _four_ and _eight_ using the deep autoenconder.

# %%
interpolation(0.4, model3, fours, eights)
